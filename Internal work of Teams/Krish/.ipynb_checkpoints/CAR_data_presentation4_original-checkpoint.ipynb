# %% [markdown]
# Author: Krish

# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import date

# %%
data_path = "C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Spring 2025\\STAT390\\LegalAid\\Data\\CAR_-_EP_Flow_Activity_Queue__Agent_Names\\"
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))
df_main = pd.DataFrame(columns=['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name', 'Activity Start Timestamp', 
                                'Queue Name', 'Agent Name', 'Termination Reason'])
df_main
# Out:
# Empty DataFrame
# Columns: [Contact Session ID, EP Name, Flow Name, Activity Name, Activity Start Timestamp, Queue Name, Agent Name, Termination Reason]
# Index: []

# %%
i=0
for f in files:
    i = i + 1
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=2, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=2, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df.shape)
# Out:
# 1 CAR - EP, Flow, Activity, Queue, & Agent Names (01-12-25 - 01-18-25) (52010, 7)
# 2 CAR - EP, Flow, Activity, Queue, & Agent Names (01-19-25 - 02-01-25) (95495, 7)
# 3 CAR - EP, Flow, Activity, Queue, & Agent Names (02-02-25 - 02-15-25) (90056, 7)
# 4 CAR - EP, Flow, Activity, Queue, & Agent Names (02-16-25 - 03-01-25) (88186, 7)
# 5 CAR - EP, Flow, Activity, Queue, & Agent Names (03-02-25 - 03-15-25) (86377, 7)
# 6 CAR - EP, Flow, Activity, Queue, & Agent Names (04-07-24 - 04-20-24) (88766, 7)
# 7 CAR - EP, Flow, Activity, Queue, & Agent Names (04-21-24 - 05-04-24) (89643, 7)
# 8 CAR - EP, Flow, Activity, Queue, & Agent Names (05-05-24 - 05-18-24) (82575, 7)
# 9 CAR - EP, Flow, Activity, Queue, & Agent Names (05-19-24 - 06-01-24) (71103, 7)
# 10 CAR - EP, Flow, Activity, Queue, & Agent Names (06-02-24 - 06-15-24) (84354, 7)
# 11 CAR - EP, Flow, Activity, Queue, & Agent Names (06-16-24 - 06-29-24) (82124, 7)
# 12 CAR - EP, Flow, Activity, Queue, & Agent Names (06-30-24 - 07-13-24) (79752, 7)
# 13 CAR - EP, Flow, Activity, Queue, & Agent Names (07-14-24 - 07-27-24) (85110, 7)
# 14 CAR - EP, Flow, Activity, Queue, & Agent Names (07-28-24 - 08-10-24) (84627, 7)
# 15 CAR - EP, Flow, Activity, Queue, & Agent Names (08-11-24 - 08-24-24) (91622, 7)
# 16 CAR - EP, Flow, Activity, Queue, & Agent Names (08-24-24 - 09-07-24) (90040, 7)
# 17 CAR - EP, Flow, Activity, Queue, & Agent Names (09-08-24 - 09-21-24) (96581, 7)
# 18 CAR - EP, Flow, Activity, Queue, & Agent Names (09-22-24 - 10-05-24) (89446, 7)
# 19 CAR - EP, Flow, Activity, Queue, & Agent Names (10-06-24 - 10-19-24) (81700, 7)
# 20 CAR - EP, Flow, Activity, Queue, & Agent Names (10-20-24 - 11-02-24) (88430, 7)
# 21 CAR - EP, Flow, Activity, Queue, & Agent Names (11-03-24 - 11-16-24) (81614, 7)
# 22 CAR - EP, Flow, Activity, Queue, & Agent Names (11-17-24 - 11-30-24) (66216, 7)
# 23 CAR - EP, Flow, Activity, Queue, & Agent Names (12-01-24 - 12-14-24) (92220, 7)
# 24 CAR - EP, Flow, Activity, Queue, & Agent Names (12-15-24 - 12-28-24) (62143, 7)
# 25 CAR - EP, Flow, Activity, Queue, & Agent Names (12-29-24 - 01-11-25) (75356, 7)
# 26 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-16 to 3-22-25 (45326, 8)
# 27 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-30 to 4-5-25 (45072, 8)
# 28 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-13 to 4-19-25 (41088, 8)
# 29 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-20 to 4-26-25 (46686, 8)
# 30 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-27 to 5-3-25 (44169, 8)
# 31 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-6 to 4-12-25 (46630, 8)
# 32 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-11 to 5-17-25 (43268, 8)
# 33 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-18 to 5-24-25 (45104, 8)
# 34 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-25 to 5-31-25 (36851, 8)
# 35 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-4 to 5-10-25 (43955, 8)
# 36 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-1 to 6-7-25 (44523, 8)
# 37 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-15 to 6-21-25 (37234, 8)
# 38 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-22 to 6-28-25 (45394, 8)
# 39 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-29 to 7-5-25 (38300, 8)
# 40 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-8 to 6-14-25 (46728, 8)
# 41 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-13 to 7-19-25 (45706, 8)
# 42 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-20 to 7-26-25 (45328, 8)
# 43 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-28 ro 8-2-25 (46237, 8)
# 44 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-6 to 7-12-25 (48707, 8)
# 45 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-10 to 8-16-25 (44095, 8)
# 46 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-17 to 8-23-25 (47062, 8)
# 47 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-24 to 8-30-25 (45113, 8)
# 48 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-3 to 8-9-25 (44706, 8)
# 49 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-31 to 9-6-25 (36177, 8)
# 50 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-14 to 9-20-25 (45958, 8)
# 51 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-21 to 9-30-25 (60381, 8)
# 52 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-7 to 9-13-25 (45304, 8)
# 53 CAR - EP, Flow, Activity, Queue, &amp; Agent Names3-23 to 3-29-25 (47978, 8)

# %%
df_main["Activity Start Timestamp"] = df_main["Activity Start Timestamp"].apply(
    lambda x: datetime.strptime(x, "%Y/%m/%d %I:%M:%S %p"))

# %%
df_main.shape
# Out:
# (3328626, 8)

# %%
df_main.dtypes
# Out:
# Contact Session ID                  object
# EP Name                             object
# Flow Name                           object
# Activity Name                       object
# Activity Start Timestamp    datetime64[ns]
# Queue Name                          object
# Agent Name                          object
# Termination Reason                  object
# dtype: object

# %%
df_main["hour"] = df_main["Activity Start Timestamp"].dt.hour

# %%
df_main.sort_values(by = ['Contact Session ID', 'Activity Start Timestamp'], inplace=True)

# %%
df_main.reset_index(inplace = True, drop = True)

# %%
df_main.head()
# Out:
#                      Contact Session ID                   EP Name Flow Name  \
# 0  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 1  00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN   LACMain
# 2  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 3  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP   LACMain
# 4  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
#
#            Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 0                    NaN      2025-03-13 12:51:21        NaN        NaN
# 1                    NaN      2025-03-13 12:51:21        NaN        NaN
# 2  LanguageSelectionMenu      2025-03-13 12:51:21        NaN        NaN
# 3                    NaN      2025-03-13 12:51:21        NaN        NaN
# 4               MainMenu      2025-03-13 12:51:31        NaN        NaN
#
#   Termination Reason  hour
# 0                NaN    12
# 1                NaN    12
# 2                NaN    12
# 3                NaN    12
# 4                NaN    12

# %%
def custdata(id):
    return df_main.loc[df_main['Contact Session ID'] == id,:]
def act_rows(act):
    return df_main.loc[df_main['Activity Name'] == act,:]
def act_data(act):
    get_act_rows = act_rows(act)
    return df_main.loc[df_main['Contact Session ID'].isin(get_act_rows['Contact Session ID']),:]
def data_rows(act, data):
    return data.loc[data['Activity Name'] == act,:]
def col_data(col, val):
    get_col_rows = df_main.loc[df_main[col] == val,:]
    return df_main.loc[df_main['Contact Session ID'].isin(get_col_rows['Contact Session ID']),:]
def col_rows(col, val):
    return df_main.loc[df_main[col] == val,:]

# %%
def calls_for_activity(act_name):
    return df_main.loc[df_main['Activity Name'] == act_name,'Contact Session ID'].nunique()

# %%
df_main['Contact Session ID'].nunique()
# Out:
# 248442

# %%
df_main.shape
# Out:
# (3328626, 9)

# %%
df_main_copy = df_main.copy()

# %%
df_main_copy = df_main_copy.loc[~df_main['Activity Name'].isna(),:]

# %%
df_main_copy.groupby('Contact Session ID').tail(1)['Activity Name'].value_counts()[:30]
# Out:
# Activity Name
# ClosedQueueMenu                     39892
# StaffDirectoryEnglishTransfer       28035
# LanguageSelectionMenu               27545
# ClinicVoicemailTransfer             25721
# MainMenu                            13075
# DisconnectContact1                  12010
# LegalMenu2                          11987
# FarmworkerMainMenu                   9640
# SetCallerID                          9358
# LegalServerScreenPop                 8939
# FrontDeskTransfer1                   7890
# ClosedMenu                           7765
# FrontDeskTransfer2                   6895
# OtherLegalMenu                       6863
# StaffDirectorySpanishTransfer        3959
# FrontDeskTransfer                    2545
# TenantMenu                           2394
# CriminalRecordsVoicemailTransfer     2267
# OtherLegalOtherMenu                  2136
# DivorceOrParentingMenu               1462
# QueueMenu1                           1287
# LegalMenu1                           1267
# SeniorsMenu                          1209
# TenantDeterrenceMenu                  870
# HousingMenu                           837
# HIVVoicemailTransfer                  836
# PlayMOH300s                           785
# HIVMenu                               771
# ScreenPopProcessComplete              694
# AddressFaxHoursMenu                   672
# Name: count, dtype: int64

# %%
3
# Out:
# 3

# %% [markdown]
# ## 19 Nov

# %% [markdown]
# ### Main menu only
# Calls that stay in the main menu only

# %%
df_main['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    1239571
# Legal Menu Telephony EP                      245849
# Pre-Legal Menu Seniors Menu Telephony EP     232691
# Closed Queue Menu Telephony EP               174367
# All LAC Queues Telephony EP                  131109
# Courtesy Callback Telephony EP                88625
# Closed Hours-Holidays Menu Telephony EP       79720
# Other Legal Menu Telephony EP                 72372
# Legal Housing Menu Telephony EP               68447
# Intake Outdial EP                             65456
# Legal Family Menu Telephony EP                54772
# Farmworker Main Number Telephony EP           52968
# Legal Benefits Menu Telephony EP               9253
# Legal HIV Menu Telephony EP                    8463
# Legal Immigration Menu Telephony EP            7861
# Legal Employment Menu Telephony EP             5694
# Name: count, dtype: int64

# %%
num_EPs = df_main.groupby('Contact Session ID')['EP Name'].nunique()

# %%
num_EPs.value_counts()
# Out:
# EP Name
# 1    117611
# 5     40056
# 4     37458
# 2     25394
# 3     20271
# 6      7423
# 7       220
# 8         9
# Name: count, dtype: int64

# %%
one_ep_data = df_main.loc[df_main['Contact Session ID'].isin(num_EPs[num_EPs == 1].index),:]
one_ep_data['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP               732487
# Intake Outdial EP                       65456
# Farmworker Main Number Telephony EP     50824
# Name: count, dtype: int64

# %%
main_menu_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Main Number Telephony EP',:]
main_menu_data = df_main.loc[df_main['Contact Session ID'].isin(main_menu_rows['Contact Session ID']),:]
main_menu_data.shape
# Out:
# (863400, 9)

# %%
main_menu_data['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP    732487
# Name: count, dtype: int64

# %%
main_menu_data['Contact Session ID'].nunique()
# Out:
# 98352

# %%
main_menu_data['Activity Name'].value_counts()
# Out:
# Activity Name
# LanguageSelectionMenu             126165
# MainMenu                           78694
# StaffDirectoryEnglishTransfer      25904
# ClinicVoicemailTransfer            12922
# FrontDeskTransfer1                  7912
# FrontDeskTransfer2                  6869
# HelpWithLegalorOtherReasonMenu      6149
# AppointmentMenu                     4847
# StaffDirectorySpanishTransfer       3391
# AddressFaxHoursMenu                 1115
# ComplimentOrComplaintMenu            793
# FrontDeskTransfer3                   540
# PlayErrorMessage                      22
# Name: count, dtype: int64

# %%
main_menu_data['caller_type'] = 'Main menu only'

# %% [markdown]
# ### Non-seniors legal menu
# Calls that reach LegalMenu2, but never reach SuburbsOrCityMenu

# %%
legmen2_data = act_data('LegalMenu2')

# %%
legmen2_data['Contact Session ID'].nunique()
# Out:
# 92696

# %%
num_act = legmen2_data.groupby('Contact Session ID')['Activity Name'].nunique()

# %%
leg_senior_data_rows = data_rows('SuburbsOrCityMenu',legmen2_data)

# %% [markdown]
# Non-seniors never reach teh suburbs or city menu

# %%
leg_non_senior_data = legmen2_data.loc[~legmen2_data['Contact Session ID'].isin(leg_senior_data_rows['Contact Session ID']),:]

# %%
leg_non_senior_data['Activity Name'].value_counts().to_csv(adhoc_data_path + 'non-senior-activities.csv')

# %%
leg_non_senior_data['Contact Session ID'].nunique()
# Out:
# 76583

# %%
leg_non_senior_data['caller_type'] = 'Non-senior legal issue'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data])
all_data['Contact Session ID'].nunique()
# Out:
# 174935

# %% [markdown]
# ## Seniors

# %% [markdown]
# ### Suburban seniors
# Calls that reach SuburbanSeniorsMenu menu

# %%
suburban_seniors_data = act_data('SuburbanSeniorsMenu')
suburban_seniors_data['Contact Session ID'].nunique()
# Out:
# 8319

# %%
suburban_seniors_data['caller_type'] = 'Suburban senior'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data])
all_data['Contact Session ID'].nunique()
# Out:
# 183254

# %% [markdown]
# ### City Seniors

# %%
seniors_adapt_data = act_data('SeniorsADAPTMenu')
city_seniors = seniors_adapt_data.loc[~seniors_adapt_data['Contact Session ID'].isin(suburban_seniors_data['Contact Session ID']),:]
city_seniors['Contact Session ID'].nunique()
# Out:
# 18028

# %%
city_seniors['caller_type'] = 'Chicago senior'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors])
all_data['Contact Session ID'].nunique()
# Out:
# 201282

# %%
#city_seniors = seniors_adapt_data.loc[seniors_adapt_data['Contact Session ID'].isin(suburban_seniors_data['Contact Session ID']),:]
#city_seniors['Contact Session ID'].nunique()

# %% [markdown]
# Two calls have identfied the callers as both suburban and Chicago Seniors

# %% [markdown]
# ### Non cook county seniors

# %%
noncook_data = act_data('SeniorNotCookCoMenu')
noncook_seniors = noncook_data.loc[(~noncook_data['Contact Session ID'].isin(suburban_seniors_data['Contact Session ID'])) & \
(~noncook_data['Contact Session ID'].isin(city_seniors['Contact Session ID'])),:]
noncook_seniors['Contact Session ID'].nunique()
# Out:
# 1311

# %%
noncook_seniors['caller_type'] = 'Non-Cook County Senior'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors])
all_data['Contact Session ID'].nunique()
# Out:
# 202593

# %% [markdown]
# ### Unclassified seniors

# %%
uns_data = act_data('SuburbsOrCityMenu')
unclassified_seniors = uns_data.loc[(~uns_data['Contact Session ID'].isin(suburban_seniors_data['Contact Session ID'])) & \
(~uns_data['Contact Session ID'].isin(city_seniors['Contact Session ID'])) & (~uns_data['Contact Session ID'].isin(noncook_seniors['Contact Session ID'])),:]
unclassified_seniors['Contact Session ID'].nunique()
# Out:
# 444

# %%
unclassified_seniors['caller_type'] = 'Unclassified seniors'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors])
all_data['Contact Session ID'].nunique()
# Out:
# 203037

# %%
nonmiss = unclassified_seniors.loc[~unclassified_seniors['Activity Name'].isna(),:]
nonmiss.groupby('Contact Session ID').tail(1)['Activity Name'].value_counts()
# Out:
# Activity Name
# SuburbsOrCityMenu    444
# Name: count, dtype: int64

# %% [markdown]
# All these seniors abandoned call before making a choice

# %% [markdown]
# ### Farmworker only

# %%
farmworker_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Farmworker Main Number Telephony EP',:]
farmworker_data = df_main.loc[df_main['Contact Session ID'].isin(farmworker_rows['Contact Session ID']),:]
farmworker_data.shape
# Out:
# (60721, 9)

# %%
farmworker_data['caller_type'] = 'Farmworker menu only'

# %%
farmworker_data['Activity Name'].value_counts()
# Out:
# Activity Name
# LanguageSelectionMenu       9863
# FarmworkerMainMenu          9707
# MigrantVoicemailTransfer      67
# Name: count, dtype: int64

# %%
farmworker_data['Contact Session ID'].nunique()
# Out:
# 9864

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data])
all_data['Contact Session ID'].nunique()
# Out:
# 212901

# %% [markdown]
# ## closed hours

# %%
closed_hours_data = df_main.loc[df_main['EP Name'] == 'Closed Hours-Holidays Menu Telephony EP',:]
closed_hours_data['Activity Name'].value_counts()
# Out:
# Activity Name
# ClosedMenu                       23629
# DisconnectContact1                9394
# AddressFaxHoursMenu               2506
# HolidayPrompt                     2394
# StaffDirectoryEnglishTransfer     2075
# ClinicVoicemailTransfer           1329
# StaffDirectorySpanishTransfer      560
# Name: count, dtype: int64

# %%
closed_hours_data['Contact Session ID'].nunique()
# Out:
# 21861

# %%
closed_hours_data['caller_type'] = 'Closed hours callers'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data,closed_hours_data])
all_data['Contact Session ID'].nunique()
# Out:
# 234669

# %%
234669+93
# Out:
# 234762

# %%
custdata('6fdc5331-6555-48d1-a002-aed93ce515af');

# %%
# List of all dataframes you want to check
datasets = {
    "leg_non_senior_data": leg_non_senior_data,
    "main_menu_data": main_menu_data,
    "suburban_seniors_data": suburban_seniors_data,
    "city_seniors": city_seniors,
    "noncook_seniors": noncook_seniors,
    "unclassified_seniors": unclassified_seniors,
    "farmworker_data": farmworker_data
}

closed_ids = set(closed_hours_data["Contact Session ID"])

total_overlap_set = set()

print("Overlap with closed_hours_data:\n")

for name, df in datasets.items():
    ids = set(df["Contact Session ID"])
    overlap = ids.intersection(closed_ids)

    # Keep track of all overlaps
    total_overlap_set.update(overlap)

    if overlap:
        print(f"{name}: {len(overlap)} overlapping IDs")
    else:
        print(f"{name}: NO overlap")

print("\nTotal unique overlapping Contact Session IDs across all datasets:")
print(len(total_overlap_set))
# Out:
# Overlap with closed_hours_data:
#
# leg_non_senior_data: 44 overlapping IDs
# main_menu_data: NO overlap
# suburban_seniors_data: 4 overlapping IDs
# city_seniors: 44 overlapping IDs
# noncook_seniors: 1 overlapping IDs
# unclassified_seniors: NO overlap
# farmworker_data: NO overlap
#
# Total unique overlapping Contact Session IDs across all datasets:
# 93

# %%
closed_hours_data['Contact Session ID'].nunique()-93
# Out:
# 21768

# %%
#custdata(farm_with_otheract_data['Contact Session ID'].unique()[1])

# %% [markdown]
# #### All accounted data till now

# %%
all_data = pd.concat([farmworker_data,nonmiss,noncook_seniors,city_seniors,suburban_seniors_data,leg_non_senior_data,main_menu_data,closed_hours_data])

# %% [markdown]
# ### Farmworker (rest)

# %%
farm_all_data = act_data('FarmworkerMainMenu')
farm_with_otheract_data = farm_all_data.loc[~farm_all_data['Contact Session ID'].isin(farmworker_data['Contact Session ID']),:]
farm_with_otheract_data['Contact Session ID'].nunique()
# Out:
# 536

# %%
chck = farm_with_otheract_data.loc[~farm_with_otheract_data['Contact Session ID'].isin(all_data['Contact Session ID']),:]
chck['Contact Session ID'].nunique()
# Out:
# 32

# %%
chck['Activity Name'].value_counts()
# Out:
# Activity Name
# SeniorsMenu                39
# LanguageSelectionMenu      32
# FarmworkerMainMenu         32
# LegalMenu1                 24
# FrontDeskTransfer          18
# SeniorsConfirmationMenu     2
# Name: count, dtype: int64

# %%
farm_rest = chck.loc[~chck['Activity Name'].isna(),:]
farm_rest.groupby('Contact Session ID').tail(1)['Activity Name'].value_counts()
# Out:
# Activity Name
# FrontDeskTransfer          18
# SeniorsMenu                 7
# LegalMenu1                  6
# SeniorsConfirmationMenu     1
# Name: count, dtype: int64

# %%
farm_rest['caller_type'] = 'Farmworker (FDT/legal)'

# %%
#custdata(chck['Contact Session ID'].unique()[1])

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data,closed_hours_data,farm_rest])
all_data['Contact Session ID'].nunique()
# Out:
# 234701

# %% [markdown]
# ## Intake outdial EP

# %%
intake_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Intake Outdial EP',:]
intake_outdial_data = df_main.loc[df_main['Contact Session ID'].isin(intake_rows['Contact Session ID']),:]
intake_outdial_data.shape
# Out:
# (90590, 9)

# %%
intake_outdial_data['Contact Session ID'].nunique()
# Out:
# 9395

# %%
intake_outdial_data['Activity Name'].value_counts()
# Out:
# Activity Name
# SetCallerID          18734
# DisconnectContact     9390
# Name: count, dtype: int64

# %%
intake_outdial_data['caller_type'] = 'Intake Outdial'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data,closed_hours_data,farm_rest,intake_outdial_data])
all_data['Contact Session ID'].nunique()
# Out:
# 244096

# %%
all_data['Contact Session ID'].nunique()
# Out:
# 244096

# %% [markdown]
# 98% data captured

# %% [markdown]
# ### Rest

# %%
rest_data = df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),:]
rest_data['Activity Name'].value_counts()
# Out:
# Activity Name
# SeniorsMenu                       5915
# LanguageSelectionMenu             3647
# MainMenu                          3578
# LegalMenu1                        2932
# FrontDeskTransfer                 1848
# AppointmentMenu                    618
# SeniorsConfirmationMenu            338
# HelpWithLegalorOtherReasonMenu     202
# ComplimentOrComplaintMenu           12
# AddressFaxHoursMenu                 10
# Name: count, dtype: int64

# %%
rest_data_nomissact = rest_data.loc[~rest_data['Activity Name'].isna(),:]
last_act = rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Contact Session ID', 'Activity Name']]
rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Activity Name']].value_counts()
# Out:
# Activity Name
# FrontDeskTransfer          1848
# SeniorsMenu                1197
# LegalMenu1                 1084
# SeniorsConfirmationMenu     211
# MainMenu                      1
# Name: count, dtype: int64

# %%
fdt_csid = last_act.loc[last_act['Activity Name'] == 'FrontDeskTransfer',:]
fdt_data = df_main.loc[df_main['Contact Session ID'].isin(fdt_csid['Contact Session ID']),:]

# %%
fdt_data['caller_type'] = 'FDT (LegalMenu1)'

# %%
fdt_data_nomissact = fdt_data.loc[~fdt_data['Activity Name'].isna(),:]
fdt_data_nomissact.groupby('Contact Session ID').tail(2)['Activity Name'].value_counts()
# Out:
# Activity Name
# LegalMenu1           1848
# FrontDeskTransfer    1848
# Name: count, dtype: int64

# %%
custdata('001d8080-ee77-4689-8e0a-db79c88148b5');

# %%
abandon_csid = last_act.loc[last_act['Activity Name'].isin(['SeniorsMenu','LegalMenu1','SeniorsConfirmationMenu']),:]

# %%
abandon_csid_data = df_main.loc[df_main['Contact Session ID'].isin(abandon_csid['Contact Session ID']),:]

# %%
abandon_csid_data['caller_type'] = 'Abandoned callers'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data,closed_hours_data,farm_rest,intake_outdial_data,fdt_data,abandon_csid_data])
all_data['Contact Session ID'].nunique()
# Out:
# 248436

# %% [markdown]
# ### 5 calls remaning

# %%
df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),'Contact Session ID'].nunique()
# Out:
# 6

# %%
rem = df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),:]
rem['caller_type'] = 'Main menu only'

# %%
all_data = pd.concat([leg_non_senior_data,main_menu_data,suburban_seniors_data,city_seniors,noncook_seniors,unclassified_seniors,
                     farmworker_data,closed_hours_data,farm_rest,intake_outdial_data,fdt_data,abandon_csid_data,rem])
all_data['Contact Session ID'].nunique()
# Out:
# 248442

# %%
#df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),:]

# %% [markdown]
# ## student code check - frontdesk

# %%
# Get next activity within same Contact Session ID
df_sorted = df_main.loc[~df_main['Activity Name'].isna(),:]
df_sorted["Next_Activity"] = df_sorted.groupby("Contact Session ID")["Activity Name"].shift(-1)

# Replace missing next activities for the target rows
df_sorted.loc[
    (df_sorted["Activity Name"] == "LanguageSelectionMenu") & 
    (df_sorted["Next_Activity"].isna()),
    "Next_Activity"
] = "LanguageSelectionMenu was the last activity"

# Filter only FrontDeskTransfer1 rows and return the next activity
result = df_sorted[df_sorted["Activity Name"] == "LanguageSelectionMenu"][[
    "Contact Session ID",
    "Activity Name",
    "Next_Activity"
]]

result['Next_Activity'].value_counts()
# Out:
# Next_Activity
# MainMenu                                       165680
# LanguageSelectionMenu                           37767
# LanguageSelectionMenu was the last activity     27545
# ClosedMenu                                      16121
# FarmworkerMainMenu                              10243
# FrontDeskTransfer1                               7912
# HolidayPrompt                                    2388
# Name: count, dtype: int64

# %%
df_sorted = df_main.loc[~df_main['Activity Name'].isna(),:]
df_sorted["Next_Activity_1"] = df_sorted.groupby("Contact Session ID")["Activity Name"].shift(-1)
df_sorted["Next_Activity_2"] = df_sorted.groupby("Contact Session ID")["Activity Name"].shift(-2)

# Fill missing values with a message
df_sorted["Next_Activity_1"] = df_sorted["Next_Activity_1"].fillna("No activity (session ended)")
df_sorted["Next_Activity_2"] = df_sorted["Next_Activity_2"].fillna("No activity (session ended)")

# Filter only rows where the activity is FrontDeskTransfer1
result = df_sorted[df_sorted["Activity Name"] == "LanguageSelectionMenu"][[
    "Contact Session ID",
    "Activity Name",
    "Next_Activity_1",
    "Next_Activity_2"
]]

result['Next_Activity_1'].value_counts()
# Out:
# Next_Activity_1
# MainMenu                       165680
# LanguageSelectionMenu           37767
# No activity (session ended)     27545
# ClosedMenu                      16121
# FarmworkerMainMenu              10243
# FrontDeskTransfer1               7912
# HolidayPrompt                    2388
# Name: count, dtype: int64

# %%
result['Next_Activity_2'].value_counts()
# Out:
# Next_Activity_2
# SeniorsMenu                       85864
# No activity (session ended)       69845
# StaffDirectoryEnglishTransfer     25364
# MainMenu                          21404
# ClinicVoicemailTransfer           13398
# AppointmentMenu                   11697
# HelpWithLegalorOtherReasonMenu    11273
# FrontDeskTransfer1                 7912
# ClosedMenu                         6908
# DisconnectContact1                 6498
# StaffDirectorySpanishTransfer      3115
# AddressFaxHoursMenu                2960
# ComplimentOrComplaintMenu          1068
# HolidayPrompt                       261
# MigrantVoicemailTransfer             67
# PlayErrorMessage                     22
# Name: count, dtype: int64

# %%
result.loc[result['Next_Activity_1'] == 'LanguageSelectionMenu','Next_Activity_2'].value_counts()
# Out:
# Next_Activity_2
# No activity (session ended)    15452
# MainMenu                       11567
# FrontDeskTransfer1              7912
# ClosedMenu                      2579
# HolidayPrompt                    257
# Name: count, dtype: int64

# %%
result.loc[result['Next_Activity_1'] == 'FrontDeskTransfer1',:]
# Out:
#                            Contact Session ID          Activity Name  \
# 71       0002606f-910e-43e5-aac5-d93fefc1cead  LanguageSelectionMenu
# 1234     001a83ae-3c29-4041-bbea-80785b1f9c90  LanguageSelectionMenu
# 1272     001b588d-f1a7-4225-9953-9e8e667bab56  LanguageSelectionMenu
# 1494     001fa09e-636e-4a99-9c18-2e245ccc2594  LanguageSelectionMenu
# 1537     001fe3cd-7637-4130-ba68-a398cdbce9d3  LanguageSelectionMenu
# ...                                       ...                    ...
# 3326565  ffdaf306-9951-4521-9c1c-5ad3d22e91a1  LanguageSelectionMenu
# 3326677  ffdc1694-e1de-4314-8dca-d910697f6921  LanguageSelectionMenu
# 3326717  ffdd40d5-d343-48ee-ac65-bbfb47091771  LanguageSelectionMenu
# 3328001  fff3d9e0-058f-4ce0-8a87-a45929fba933  LanguageSelectionMenu
# 3328592  fffe91b1-c54d-4b1e-b19d-1ef78e4a8871  LanguageSelectionMenu
#
#             Next_Activity_1              Next_Activity_2
# 71       FrontDeskTransfer1  No activity (session ended)
# 1234     FrontDeskTransfer1  No activity (session ended)
# 1272     FrontDeskTransfer1  No activity (session ended)
# 1494     FrontDeskTransfer1  No activity (session ended)
# 1537     FrontDeskTransfer1  No activity (session ended)
# ...                     ...                          ...
# 3326565  FrontDeskTransfer1  No activity (session ended)
# 3326677  FrontDeskTransfer1  No activity (session ended)
# 3326717  FrontDeskTransfer1  No activity (session ended)
# 3328001  FrontDeskTransfer1  No activity (session ended)
# 3328592  FrontDeskTransfer1  No activity (session ended)
#
# [7912 rows x 4 columns]

# %%
result.loc[result['Next_Activity_2'] == 'FrontDeskTransfer1',:]
# Out:
#                            Contact Session ID          Activity Name  \
# 69       0002606f-910e-43e5-aac5-d93fefc1cead  LanguageSelectionMenu
# 1232     001a83ae-3c29-4041-bbea-80785b1f9c90  LanguageSelectionMenu
# 1270     001b588d-f1a7-4225-9953-9e8e667bab56  LanguageSelectionMenu
# 1492     001fa09e-636e-4a99-9c18-2e245ccc2594  LanguageSelectionMenu
# 1535     001fe3cd-7637-4130-ba68-a398cdbce9d3  LanguageSelectionMenu
# ...                                       ...                    ...
# 3326563  ffdaf306-9951-4521-9c1c-5ad3d22e91a1  LanguageSelectionMenu
# 3326675  ffdc1694-e1de-4314-8dca-d910697f6921  LanguageSelectionMenu
# 3326715  ffdd40d5-d343-48ee-ac65-bbfb47091771  LanguageSelectionMenu
# 3327999  fff3d9e0-058f-4ce0-8a87-a45929fba933  LanguageSelectionMenu
# 3328590  fffe91b1-c54d-4b1e-b19d-1ef78e4a8871  LanguageSelectionMenu
#
#                Next_Activity_1     Next_Activity_2
# 69       LanguageSelectionMenu  FrontDeskTransfer1
# 1232     LanguageSelectionMenu  FrontDeskTransfer1
# 1270     LanguageSelectionMenu  FrontDeskTransfer1
# 1492     LanguageSelectionMenu  FrontDeskTransfer1
# 1535     LanguageSelectionMenu  FrontDeskTransfer1
# ...                        ...                 ...
# 3326563  LanguageSelectionMenu  FrontDeskTransfer1
# 3326675  LanguageSelectionMenu  FrontDeskTransfer1
# 3326715  LanguageSelectionMenu  FrontDeskTransfer1
# 3327999  LanguageSelectionMenu  FrontDeskTransfer1
# 3328590  LanguageSelectionMenu  FrontDeskTransfer1
#
# [7912 rows x 4 columns]

# %%
custdata('0002606f-910e-43e5-aac5-d93fefc1cead');

# %%
custdata('0002606f-910e-43e5-aac5-d93fefc1cead');

# %%
result.loc[result['Next_Activity_1'] == 'FrontDeskTransfer1','Next_Activity_2'].value_counts()
# Out:
# Next_Activity_2
# No activity (session ended)    7890
# PlayErrorMessage                 22
# Name: count, dtype: int64

# %%
result
# Out:
#                            Contact Session ID          Activity Name  \
# 2        00002422-f51f-458b-82d6-cfa5a3f36fd9  LanguageSelectionMenu
# 13       0000a8d5-cecb-46b1-82cf-b7ce07d85b24  LanguageSelectionMenu
# 21       00011655-35de-476f-9a8c-dd48ed4d914a  LanguageSelectionMenu
# 23       00011655-35de-476f-9a8c-dd48ed4d914a  LanguageSelectionMenu
# 34       00014a58-a6ce-4cb2-a529-d55e2c9c304d  LanguageSelectionMenu
# ...                                       ...                    ...
# 3328599  fffed0e4-d57d-42dc-8d9e-725ce451fa9e  LanguageSelectionMenu
# 3328601  fffed0e4-d57d-42dc-8d9e-725ce451fa9e  LanguageSelectionMenu
# 3328617  fffeef9f-11f2-42c8-80e3-511a9a01d66f  LanguageSelectionMenu
# 3328622  ffffa50d-6d02-4281-9141-087a806a8343  LanguageSelectionMenu
# 3328624  ffffa50d-6d02-4281-9141-087a806a8343  LanguageSelectionMenu
#
#                      Next_Activity_1                 Next_Activity_2
# 2                           MainMenu   StaffDirectoryEnglishTransfer
# 13                          MainMenu                      ClosedMenu
# 21             LanguageSelectionMenu                        MainMenu
# 23                          MainMenu  HelpWithLegalorOtherReasonMenu
# 34                          MainMenu                     SeniorsMenu
# ...                              ...                             ...
# 3328599        LanguageSelectionMenu                        MainMenu
# 3328601                     MainMenu                     SeniorsMenu
# 3328617  No activity (session ended)     No activity (session ended)
# 3328622        LanguageSelectionMenu     No activity (session ended)
# 3328624  No activity (session ended)     No activity (session ended)
#
# [267656 rows x 4 columns]

# %% [markdown]
# ## check - agent direct connect

# %%
agent_rows = df_main.loc[((~df_main['Agent Name'].isna()) & (df_main['Agent Name']!= 'CBT Agent')),:]
agent_rows['Agent Name'].value_counts()
# Out:
# Agent Name
# Ana Franco            16790
# Monica Grubbs         15531
# Amanda Palacios       10746
# Flora Fell            10026
# Marisol Guadarrama     8750
# Darriane Sarabia       8224
# Delvan Willis          7320
# Ana Reynoso            3317
# Sylvia Lozano-Haas     2650
# Mona Green             2157
# Alyssa Funk            2002
# Meganne Enright        1563
# Jessica Parent          930
# Name: count, dtype: int64

# %%
9158+9395+716
# Out:
# 19269

# %%
agent_rows['Contact Session ID'].nunique()
# Out:
# 19061

# %%
no_agent = df_main.loc[~df_main['Contact Session ID'].isin(agent_rows['Contact Session ID']),:]
no_agent['Contact Session ID'].nunique()
# Out:
# 229381

# %%
716/(9158+9395)
# Out:
# 0.0385921414326524

# %%
52/8
# Out:
# 6.5

# %%
229381-49933
# Out:
# 179448

# %%
callback_outdial_data = df_main.loc[df_main['EP Name'].isin(['Courtesy Callback Telephony EP','Intake Outdial EP']),:]

# %%
callback_rows = df_main.loc[df_main['EP Name'] == 'Courtesy Callback Telephony EP',:]
callback_data = df_main.loc[df_main['Contact Session ID'].isin(callback_rows['Contact Session ID']),:]
callback_data['Contact Session ID'].nunique()
# Out:
# 9158

# %%
callback_data
# Out:
#                            Contact Session ID                         EP Name  \
# 535      000cce29-1c76-4991-9445-bb5f9028f47d        Main Number Telephony EP
# 536      000cce29-1c76-4991-9445-bb5f9028f47d                             NaN
# 537      000cce29-1c76-4991-9445-bb5f9028f47d        Main Number Telephony EP
# 538      000cce29-1c76-4991-9445-bb5f9028f47d        Main Number Telephony EP
# 539      000cce29-1c76-4991-9445-bb5f9028f47d        Main Number Telephony EP
# ...                                       ...                             ...
# 3328375  fff898b5-9df2-40f4-a421-2dac3dc04194  Courtesy Callback Telephony EP
# 3328376  fff898b5-9df2-40f4-a421-2dac3dc04194  Courtesy Callback Telephony EP
# 3328377  fff898b5-9df2-40f4-a421-2dac3dc04194                             NaN
# 3328378  fff898b5-9df2-40f4-a421-2dac3dc04194  Courtesy Callback Telephony EP
# 3328379  fff898b5-9df2-40f4-a421-2dac3dc04194                             NaN
#
#         Flow Name          Activity Name Activity Start Timestamp Queue Name  \
# 535           NaN                    NaN      2024-05-29 13:14:07        NaN
# 536       LACMain                    NaN      2024-05-29 13:14:07        NaN
# 537           NaN  LanguageSelectionMenu      2024-05-29 13:14:07        NaN
# 538       LACMain                    NaN      2024-05-29 13:14:07        NaN
# 539           NaN               MainMenu      2024-05-29 13:14:20        NaN
# ...           ...                    ...                      ...        ...
# 3328375       NaN   LegalServerScreenPop      2025-08-01 14:50:05        NaN
# 3328376       NaN                    NaN      2025-08-01 14:50:38   Consumer
# 3328377       NaN                    NaN      2025-08-01 14:50:54   Consumer
# 3328378       NaN                    NaN      2025-08-01 14:50:54   Consumer
# 3328379       NaN                    NaN      2025-08-01 14:50:59   Consumer
#
#                  Agent Name    Termination Reason  hour
# 535                     NaN                   NaN    13
# 536                     NaN                   NaN    13
# 537                     NaN                   NaN    13
# 538                     NaN                   NaN    13
# 539                     NaN                   NaN    13
# ...                     ...                   ...   ...
# 3328375                 NaN                   NaN    14
# 3328376  Sylvia Lozano-Haas  NO_ANSWER_FROM_AGENT    14
# 3328377  Sylvia Lozano-Haas                   NaN    14
# 3328378                 NaN            Agent Left    14
# 3328379  Sylvia Lozano-Haas                   NaN    14
#
# [343785 rows x 9 columns]

# %%
import pandas as pd

# Ensure proper sorting
df_sorted = callback_data.copy()

# 1. Get last occurrence of LegalServerScreenPop per Contact Session ID
last_pop = (
    df_sorted[df_sorted["Activity Name"] == "LegalServerScreenPop"]
    .groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 2. Get last timestamp per Contact Session ID
last_ts = (
    df_sorted.groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 3. Combine, keeping only IDs that have LegalServerScreenPop
merged = pd.concat([last_pop, last_ts], axis=1)
merged.columns = ["Last_LegalServerScreenPop", "Last_Timestamp"]

# Drop Contact Session IDs with no LegalServerScreenPop
merged = merged.dropna()

# 4. Compute time difference in seconds
merged["Duration_seconds"] = (
    merged["Last_Timestamp"] - merged["Last_LegalServerScreenPop"]
).dt.total_seconds()

# 5. Average time difference in minutes
average_minutes = merged["Duration_seconds"].mean() / 60

print("Average time difference (minutes):", average_minutes)
# Out:
# Average time difference (minutes): 13.363325901151988

# %%
df_sorted = outdial_data.copy()

# 1. Last occurrence of SetCallerID per Contact Session ID
last_setcaller = (
    df_sorted[df_sorted["Activity Name"] == "SetCallerID"]
    .groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 2. Last timestamp per Contact Session ID
last_ts = (
    df_sorted.groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 3. Combine and keep only sessions that contain SetCallerID
merged = pd.concat([last_setcaller, last_ts], axis=1)
merged.columns = ["Last_SetCallerID", "Last_Timestamp"]
merged = merged.dropna()

# 4. Compute duration in seconds
merged["Duration_seconds"] = (
    merged["Last_Timestamp"] - merged["Last_SetCallerID"]
).dt.total_seconds()

# 5. Compute average duration in minutes
average_minutes = merged["Duration_seconds"].mean() / 60

print("Average time difference (minutes):", average_minutes)
# Out:
# Average time difference (minutes): 6.687093788930414

# %%
import pandas as pd

# Ensure proper sorting
df_sorted = agent_data.copy()

# 1. Get last occurrence of LegalServerScreenPop per Contact Session ID
last_pop = (
    df_sorted[df_sorted["Activity Name"] == "LegalServerScreenPop"]
    .groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 2. Get last timestamp per Contact Session ID
last_ts = (
    df_sorted.groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 3. Combine, keeping only IDs that have LegalServerScreenPop
merged = pd.concat([last_pop, last_ts], axis=1)
merged.columns = ["Last_LegalServerScreenPop", "Last_Timestamp"]

# Drop Contact Session IDs with no LegalServerScreenPop
merged = merged.dropna()

# 4. Compute time difference in seconds
merged["Duration_seconds"] = (
    merged["Last_Timestamp"] - merged["Last_LegalServerScreenPop"]
).dt.total_seconds()

# 5. Average time difference in minutes
average_minutes = merged["Duration_seconds"].mean() / 60

print("Average time difference (minutes):", average_minutes)
# Out:
# Average time difference (minutes): 12.546348980559507

# %%
custdata('0004529f-0f07-421c-9d72-4baed1a8559e');

# %%
outdial_data;

# %%
outdial_rows = df_main.loc[df_main['EP Name'] == 'Intake Outdial EP',:]
outdial_data = df_main.loc[df_main['Contact Session ID'].isin(outdial_rows['Contact Session ID']),:]
outdial_data['Contact Session ID'].nunique()
# Out:
# 9395

# %%
9158/248442
# Out:
# 0.0368617222530812

# %%
9395/248442
# Out:
# 0.03781566723822864

# %%
cq_tag = tagged_data.loc[tagged_data['Outcome'] == 'Closed Queue',:]

# %%
cq_data = act_data('ClosedQueueMenu')
cq_data['Contact Session ID'].nunique()
chck = cq_data.loc[~cq_data['Contact Session ID'].isin(cq_tag['Contact Session ID']),:]
chck['Contact Session ID'].nunique()
# Out:
# 7894

# %%
custdata('0007108a-5d96-44c6-b0b0-70b248af81b5');

# %%
outdial_data.loc[outdial_data['Activity Name'] == 'ClosedQueueMenu',:]
# Out:
# Empty DataFrame
# Columns: [Contact Session ID, EP Name, Flow Name, Activity Name, Activity Start Timestamp, Queue Name, Agent Name, Termination Reason, hour]
# Index: []

# %%
agent_data = df_main.loc[df_main['Contact Session ID'].isin(agent_rows['Contact Session ID']) & \
(~df_main['Contact Session ID'].isin(callback_outdial_data['Contact Session ID'])),:]

# %%
agent_data['EP Name'].value_counts()
# Out:
# EP Name
# All LAC Queues Telephony EP                 17381
# Main Number Telephony EP                     2901
# Pre-Legal Menu Seniors Menu Telephony EP     2275
# Legal Menu Telephony EP                       698
# Legal Housing Menu Telephony EP               352
# Legal Family Menu Telephony EP                151
# Legal Benefits Menu Telephony EP               48
# Legal Employment Menu Telephony EP             32
# Other Legal Menu Telephony EP                  25
# Legal Immigration Menu Telephony EP             4
# Farmworker Main Number Telephony EP             4
# Name: count, dtype: int64

# %%
agent_data['Contact Session ID'].nunique()
# Out:
# 716

# %%
custdata('0095d75b-7e36-43bd-90a9-965e3c4722ed')
# Out:
#                         Contact Session ID  \
# 7957  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7958  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7959  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7960  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7961  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7962  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7963  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7964  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7965  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7966  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7967  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7968  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7969  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7970  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7971  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7972  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7973  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7974  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7975  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7976  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7977  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7978  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7979  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7980  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7981  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7982  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7983  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7984  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7985  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7986  0095d75b-7e36-43bd-90a9-965e3c4722ed
# 7987  0095d75b-7e36-43bd-90a9-965e3c4722ed
#
#                                        EP Name                Flow Name  \
# 7957                  Main Number Telephony EP                      NaN
# 7958                                       NaN                  LACMain
# 7959                  Main Number Telephony EP                      NaN
# 7960                  Main Number Telephony EP                  LACMain
# 7961                  Main Number Telephony EP                      NaN
# 7962                                       NaN  PreLegalMenuSeniorsMenu
# 7963  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 7964  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 7965  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 7966  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 7967                                       NaN                   Queues
# 7968               All LAC Queues Telephony EP                      NaN
# 7969               All LAC Queues Telephony EP                      NaN
# 7970               All LAC Queues Telephony EP                      NaN
# 7971               All LAC Queues Telephony EP                      NaN
# 7972               All LAC Queues Telephony EP                      NaN
# 7973               All LAC Queues Telephony EP                      NaN
# 7974               All LAC Queues Telephony EP                      NaN
# 7975               All LAC Queues Telephony EP                      NaN
# 7976               All LAC Queues Telephony EP                      NaN
# 7977               All LAC Queues Telephony EP                      NaN
# 7978               All LAC Queues Telephony EP                      NaN
# 7979                                       NaN                      NaN
# 7980               All LAC Queues Telephony EP                      NaN
# 7981               All LAC Queues Telephony EP                      NaN
# 7982               All LAC Queues Telephony EP                      NaN
# 7983               All LAC Queues Telephony EP                      NaN
# 7984               All LAC Queues Telephony EP                      NaN
# 7985               All LAC Queues Telephony EP                      NaN
# 7986                                       NaN                      NaN
# 7987               All LAC Queues Telephony EP                      NaN
#
#                            Activity Name Activity Start Timestamp  \
# 7957                                 NaN      2024-06-12 15:05:39
# 7958                                 NaN      2024-06-12 15:05:39
# 7959               LanguageSelectionMenu      2024-06-12 15:05:39
# 7960                                 NaN      2024-06-12 15:05:40
# 7961                            MainMenu      2024-06-12 15:05:50
# 7962                                 NaN      2024-06-12 15:06:14
# 7963                         SeniorsMenu      2024-06-12 15:06:14
# 7964             SeniorsConfirmationMenu      2024-06-12 15:06:23
# 7965                   SuburbsOrCityMenu      2024-06-12 15:06:40
# 7966                 SuburbanSeniorsMenu      2024-06-12 15:06:54
# 7967                                 NaN      2024-06-12 15:07:42
# 7968  GetLoggedInSubSeniorBenefitsAgents      2024-06-12 15:07:42
# 7969         SubSeniorPreQueueMessage1_1      2024-06-12 15:07:42
# 7970              SubSeniorBenefitsQueue      2024-06-12 15:08:45
# 7971                                 NaN      2024-06-12 15:08:45
# 7972                    PreQueueMessage2      2024-06-12 15:08:45
# 7973                         PlayMOH300s      2024-06-12 15:08:57
# 7974                          QueueMenu1      2024-06-12 15:13:58
# 7975                         PlayMOH300s      2024-06-12 15:14:19
# 7976                                 NaN      2024-06-12 15:15:42
# 7977                LegalServerScreenPop      2024-06-12 15:15:43
# 7978            ScreenPopProcessComplete      2024-06-12 15:15:43
# 7979                                 NaN      2024-06-12 15:15:57
# 7980                                 NaN      2024-06-12 15:15:57
# 7981                         PlayMOH300s      2024-06-12 15:15:57
# 7982                                 NaN      2024-06-12 15:16:03
# 7983                LegalServerScreenPop      2024-06-12 15:16:03
# 7984            ScreenPopProcessComplete      2024-06-12 15:16:03
# 7985                                 NaN      2024-06-12 15:16:07
# 7986                                 NaN      2024-06-12 15:17:18
# 7987                                 NaN      2024-06-12 15:17:18
#
#               Queue Name     Agent Name Termination Reason  hour
# 7957                 NaN            NaN                NaN    15
# 7958                 NaN            NaN                NaN    15
# 7959                 NaN            NaN                NaN    15
# 7960                 NaN            NaN                NaN    15
# 7961                 NaN            NaN                NaN    15
# 7962                 NaN            NaN                NaN    15
# 7963                 NaN            NaN                NaN    15
# 7964                 NaN            NaN                NaN    15
# 7965                 NaN            NaN                NaN    15
# 7966                 NaN            NaN                NaN    15
# 7967                 NaN            NaN                NaN    15
# 7968                 NaN            NaN                NaN    15
# 7969                 NaN            NaN                NaN    15
# 7970                 NaN            NaN                NaN    15
# 7971  SubSenior Benefits            NaN                NaN    15
# 7972                 NaN            NaN                NaN    15
# 7973                 NaN            NaN                NaN    15
# 7974                 NaN            NaN                NaN    15
# 7975                 NaN            NaN                NaN    15
# 7976  SubSenior Benefits  Monica Grubbs                NaN    15
# 7977                 NaN            NaN                NaN    15
# 7978                 NaN            NaN                NaN    15
# 7979  SubSenior Benefits  Monica Grubbs                NaN    15
# 7980  SubSenior Benefits            NaN                NaN    15
# 7981                 NaN            NaN                NaN    15
# 7982  SubSenior Benefits  Monica Grubbs                NaN    15
# 7983                 NaN            NaN                NaN    15
# 7984                 NaN            NaN                NaN    15
# 7985  SubSenior Benefits  Monica Grubbs                NaN    15
# 7986  SubSenior Benefits  Monica Grubbs                NaN    15
# 7987  SubSenior Benefits  Monica Grubbs                NaN    15

# %%
agent_data
# Out:
#                            Contact Session ID                      EP Name  \
# 7957     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7958     0095d75b-7e36-43bd-90a9-965e3c4722ed                          NaN
# 7959     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7960     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7961     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# ...                                       ...                          ...
# 3327617  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327618  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327619  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327620  ffeba08a-2298-40a2-8864-ecb0a414e7e8                          NaN
# 3327621  ffeba08a-2298-40a2-8864-ecb0a414e7e8                          NaN
#
#         Flow Name             Activity Name Activity Start Timestamp  \
# 7957          NaN                       NaN      2024-06-12 15:05:39
# 7958      LACMain                       NaN      2024-06-12 15:05:39
# 7959          NaN     LanguageSelectionMenu      2024-06-12 15:05:39
# 7960      LACMain                       NaN      2024-06-12 15:05:40
# 7961          NaN                  MainMenu      2024-06-12 15:05:50
# ...           ...                       ...                      ...
# 3327617       NaN  ScreenPopProcessComplete      2025-05-29 12:27:26
# 3327618       NaN                       NaN      2025-05-29 12:27:30
# 3327619       NaN                       NaN      2025-05-29 12:40:53
# 3327620       NaN                       NaN      2025-05-29 12:40:53
# 3327621       NaN                       NaN      2025-05-29 12:40:55
#
#                  Queue Name  Agent Name Termination Reason  hour
# 7957                    NaN         NaN                NaN    15
# 7958                    NaN         NaN                NaN    15
# 7959                    NaN         NaN                NaN    15
# 7960                    NaN         NaN                NaN    15
# 7961                    NaN         NaN                NaN    15
# ...                     ...         ...                ...   ...
# 3327617                 NaN         NaN                NaN    12
# 3327618  SubSenior Benefits  Flora Fell                NaN    12
# 3327619  SubSenior Benefits  Flora Fell      Customer Left    12
# 3327620  SubSenior Benefits  Flora Fell                NaN    12
# 3327621  SubSenior Benefits  Flora Fell                NaN    12
#
# [28219 rows x 9 columns]

# %%
716/248442
# Out:
# 0.0028819603770698994

# %%
716/372
# Out:
# 1.924731182795699

# %%
(248442-71859)/372
# Out:
# 474.68548387096774

# %%
49933+9158+9395+716+2657
# Out:
# 71859

# %%
248442/372
# Out:
# 667.8548387096774

# %%
716/372
# Out:
# 1.924731182795699

# %% [markdown]
# Why have a queue - when taking only 2 calls per day without callback?

# %%
cbt_rows = col_rows('Agent Name','CBT Agent')
cbt_rows['Queue Name'].value_counts()
# Out:
# Queue Name
# Staff Directory English Transfer        84092
# Clinic Voicemail Transfer               76190
# Front Desk Transfer                     49466
# Staff Directory Spanish Transfer        11872
# Criminal Records Voicemail Transfer      6736
# HIV Voicemail Transfer                   2495
# Safe Haven Transfer                      1235
# Veterans Benefits Voicemail Transfer      552
# Trafficking Voicemail Transfer            400
# Farmworker Voicemail Transfer             195
# Name: count, dtype: int64

# %%
cbt = col_data('Agent Name','CBT Agent')
cbt.head()
# Out:
#                      Contact Session ID                   EP Name Flow Name  \
# 0  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 1  00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN   LACMain
# 2  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 3  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP   LACMain
# 4  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
#
#            Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 0                    NaN      2025-03-13 12:51:21        NaN        NaN
# 1                    NaN      2025-03-13 12:51:21        NaN        NaN
# 2  LanguageSelectionMenu      2025-03-13 12:51:21        NaN        NaN
# 3                    NaN      2025-03-13 12:51:21        NaN        NaN
# 4               MainMenu      2025-03-13 12:51:31        NaN        NaN
#
#   Termination Reason  hour
# 0                NaN    12
# 1                NaN    12
# 2                NaN    12
# 3                NaN    12
# 4                NaN    12

# %%
custdata('00002422-f51f-458b-82d6-cfa5a3f36fd9')
# Out:
#                       Contact Session ID                   EP Name Flow Name  \
# 0   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 1   00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN   LACMain
# 2   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 3   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP   LACMain
# 4   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 5   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 6   00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN       NaN
# 7   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 8   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 9   00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 10  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
#
#                     Activity Name Activity Start Timestamp  \
# 0                             NaN      2025-03-13 12:51:21
# 1                             NaN      2025-03-13 12:51:21
# 2           LanguageSelectionMenu      2025-03-13 12:51:21
# 3                             NaN      2025-03-13 12:51:21
# 4                        MainMenu      2025-03-13 12:51:31
# 5   StaffDirectoryEnglishTransfer      2025-03-13 12:51:41
# 6                             NaN      2025-03-13 12:51:41
# 7                             NaN      2025-03-13 12:51:41
# 8                             NaN      2025-03-13 12:51:41
# 9                             NaN      2025-03-13 12:51:41
# 10                            NaN      2025-03-13 12:52:15
#
#                           Queue Name Agent Name Termination Reason  hour
# 0                                NaN        NaN                NaN    12
# 1                                NaN        NaN                NaN    12
# 2                                NaN        NaN                NaN    12
# 3                                NaN        NaN                NaN    12
# 4                                NaN        NaN                NaN    12
# 5                                NaN        NaN                NaN    12
# 6   Staff Directory English Transfer        NaN                NaN    12
# 7                                NaN        NaN                NaN    12
# 8   Staff Directory English Transfer  CBT Agent                NaN    12
# 9   Staff Directory English Transfer  CBT Agent                NaN    12
# 10  Staff Directory English Transfer  CBT Agent                NaN    12

# %% [markdown]
# ### Queue

# %% [markdown]
# ## last activity

# %%
nonmiss_act = df_main.loc[~df_main['Activity Name'].isna(),:]
last_act = nonmiss_act.groupby('Contact Session ID').tail(1)

# %%
last_act['Contact Session ID'].nunique()
# Out:
# 248265

# %%
last_act['Activity Name'].value_counts()
# Out:
# Activity Name
# ClosedQueueMenu                     39892
# StaffDirectoryEnglishTransfer       28035
# LanguageSelectionMenu               27545
# ClinicVoicemailTransfer             25721
# MainMenu                            13075
#                                     ...
# SubSeniorConsumerQueue                  1
# PlayCCBConfirmation                     1
# GetLoggedInOtherSubSeniorsAgents        1
# SubSeniorTenantQueue                    1
# ImmigrationSPQueue                      1
# Name: count, Length: 81, dtype: int64

# %% [markdown]
# # Outcome tagging

# %% [markdown]
# ### no activity

# %%
no_activity_csid = df_main.loc[~df_main['Contact Session ID'].isin(last_act['Contact Session ID']),:]
no_activity_csid['Outcome_class'] = 'Negative'
no_activity_csid['Outcome']= 'Abandoned'
no_activity_csid = no_activity_csid[['Contact Session ID','Outcome','Outcome_class']]
no_activity_csid = no_activity_csid.drop_duplicates(subset="Contact Session ID", keep="first")
no_activity_csid.shape
# Out:
# (177, 3)

# %% [markdown]
# ### Closed queue

# %%
last_act.shape
# Out:
# (248265, 9)

# %%
closed_queue_csid = last_act.loc[last_act['Activity Name'] == 'ClosedQueueMenu',:]
closed_queue_csid['Outcome_class'] = 'Negative'
closed_queue_csid['Outcome']= 'Closed Queue'
closed_queue_csid = closed_queue_csid[['Contact Session ID','Outcome','Outcome_class']]
closed_queue_csid = closed_queue_csid.drop_duplicates(subset="Contact Session ID", keep="first")
closed_queue_csid.shape
# Out:
# (39892, 3)

# %%
outcome_tagged = pd.concat([no_activity_csid, closed_queue_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.16128110383912542

# %% [markdown]
# ### Staff Directory transfer

# %%
df_sorted = nonmiss_act.copy()
df_sorted["Prev_Activity"] = df_sorted.groupby("Contact Session ID")["Activity Name"].shift(1)

# Filter only the rows where the activity is StaffDirectoryEnglishTransfer
result = df_sorted[df_sorted["Activity Name"] == "StaffDirectoryEnglishTransfer"][[
    "Contact Session ID",
    "Activity Name",
    "Prev_Activity"
]]

result['Prev_Activity'].value_counts()
# Out:
# Prev_Activity
# MainMenu      25960
# ClosedMenu     2075
# Name: count, dtype: int64

# %%
staff_dir_csid = last_act.loc[(last_act['Activity Name'] == 'StaffDirectoryEnglishTransfer') | \
(last_act['Activity Name'] == 'StaffDirectorySpanishTransfer'),:]
staff_dir_csid['Outcome_class'] = 'Positive'
staff_dir_csid['Outcome']= 'Staff directory transfer'
staff_dir_csid = staff_dir_csid[['Contact Session ID','Outcome','Outcome_class']]
staff_dir_csid = staff_dir_csid.drop_duplicates(subset="Contact Session ID", keep="first")
staff_dir_csid.shape
# Out:
# (31994, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, staff_dir_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.29005965174970416

# %% [markdown]
# ### Abandoment

# %%
languagesel_csid = last_act.loc[last_act['Activity Name'] == 'LanguageSelectionMenu',:]
languagesel_csid['Outcome_class'] = 'Negative'
languagesel_csid['Outcome']= 'Abandoned (Language not selected)'
languagesel_csid = languagesel_csid[['Contact Session ID','Outcome','Outcome_class']]
languagesel_csid = languagesel_csid.drop_duplicates(subset="Contact Session ID", keep="first")
languagesel_csid.shape
# Out:
# (27545, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, languagesel_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.40093059949605947

# %%
abandoned_act = ['MainMenu', 'LegalMenu2', 'FarmworkerMainMenu','TenantMenu','DivorceOrParentingMenu',
                'QueueMenu1', 'LegalMenu1','SeniorsMenu','HousingMenu','PlayMOH300s','HIVMenu','FamilyMenu','ImmigrationMenu',
                'SeniorsADAPTMenu','SuburbsOrCityMenu','SuburbanSeniorsMenu','BenefitsMenu','SeniorsConfirmationMenu','EmploymentMenu'
                'AppointmentMenu','PreQueueMessage2','HelpWithLegalorOtherReasonMenu','SubSeniorPreQueueMessage1_1','IntakePreQueueMessage1']

# %%
abandoned_csid = last_act.loc[last_act['Activity Name'].isin(abandoned_act),:]
abandoned_csid['Outcome_class'] = 'Negative'
abandoned_csid['Outcome']= 'Abandoned'
abandoned_csid = abandoned_csid[['Contact Session ID','Outcome','Outcome_class']]
abandoned_csid = abandoned_csid.drop_duplicates(subset="Contact Session ID", keep="first")
abandoned_csid.shape
# Out:
# (48250, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, abandoned_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.5951409182022364

# %%
outcome_tagged['Outcome'].value_counts()
# Out:
# Outcome
# Abandoned                            48427
# Closed Queue                         39892
# Staff directory transfer             31994
# Abandoned (Language not selected)    27545
# Name: count, dtype: int64

# %% [markdown]
# ### Clinic Voicemail transfer

# %%
clinic_VM_csid = last_act.loc[(last_act['Activity Name'] == 'ClinicVoicemailTransfer'),:]
clinic_VM_csid['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                   12950
# Closed Queue Menu Telephony EP              7894
# Other Legal Menu Telephony EP               2345
# Closed Hours-Holidays Menu Telephony EP     1329
# Legal Housing Menu Telephony EP              776
# Legal Family Menu Telephony EP               427
# Name: count, dtype: int64

# %%
clinic_VM_csid = last_act.loc[(last_act['Activity Name'] == 'ClinicVoicemailTransfer'),:]
clinic_VM_csid.loc[clinic_VM_csid['EP Name'] == 'Closed Queue Menu Telephony EP','Outcome'] = "Closed Queue"
clinic_VM_csid.loc[clinic_VM_csid['EP Name'] == 'Closed Queue Menu Telephony EP','Outcome_class'] = "Negative"
clinic_VM_csid.loc[clinic_VM_csid['EP Name'] == 'Closed Hours-Holidays Menu Telephony EP','Outcome'] = "Closed hours"
clinic_VM_csid.loc[clinic_VM_csid['EP Name'] == 'Closed Hours-Holidays Menu Telephony EP','Outcome_class'] = "Neutral"
clinic_VM_csid.loc[clinic_VM_csid['Outcome'].isna(),'Outcome'] = "Voicemail"
clinic_VM_csid.loc[clinic_VM_csid['Outcome_class'].isna(),'Outcome_class'] = "Neutral"


clinic_VM_csid = clinic_VM_csid[['Contact Session ID','Outcome','Outcome_class']]
clinic_VM_csid = clinic_VM_csid.drop_duplicates(subset="Contact Session ID", keep="first")
clinic_VM_csid.shape
# Out:
# (25721, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, clinic_VM_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.6986701121388493

# %%
clinic_VM_csid['Outcome'].value_counts()
# Out:
# Outcome
# Voicemail       16498
# Closed Queue     7894
# Closed hours     1329
# Name: count, dtype: int64

# %% [markdown]
# ### Disconnect

# %%
disconnect_csid = last_act.loc[(last_act['Activity Name'] == 'DisconnectContact1'),:]
disconnect_csid['EP Name'].value_counts()
# Out:
# EP Name
# Closed Hours-Holidays Menu Telephony EP     9394
# Closed Queue Menu Telephony EP              2147
# Pre-Legal Menu Seniors Menu Telephony EP     451
# Courtesy Callback Telephony EP                18
# Name: count, dtype: int64

# %%
disconnect_csid = last_act.loc[(last_act['Activity Name'] == 'DisconnectContact1'),:]
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Closed Queue Menu Telephony EP','Outcome'] = "Closed Queue"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Closed Queue Menu Telephony EP','Outcome_class'] = "Negative"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Closed Hours-Holidays Menu Telephony EP','Outcome'] = "Closed hours"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Closed Hours-Holidays Menu Telephony EP','Outcome_class'] = "Neutral"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Pre-Legal Menu Seniors Menu Telephony EP','Outcome'] = "LAC does not serve"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Pre-Legal Menu Seniors Menu Telephony EP','Outcome_class'] = "Neutral"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Courtesy Callback Telephony EP','Outcome'] = "Callback not tried"
disconnect_csid.loc[disconnect_csid['EP Name'] == 'Courtesy Callback Telephony EP','Outcome_class'] = "Negative"
disconnect_csid = disconnect_csid[['Contact Session ID','Outcome','Outcome_class']]
disconnect_csid = disconnect_csid.drop_duplicates(subset="Contact Session ID", keep="first")
disconnect_csid.shape
# Out:
# (12010, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, disconnect_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.7470113748883039

# %% [markdown]
# ### Closed menu

# %%
closed_csid = last_act.loc[last_act['Activity Name'].isin(['ClosedMenu','HolidayPrompt']),:]
closed_csid['Outcome_class'] = 'Neutral'
closed_csid['Outcome']= 'Closed hours'
closed_csid = closed_csid[['Contact Session ID','Outcome','Outcome_class']]
closed_csid = closed_csid.drop_duplicates(subset="Contact Session ID", keep="first")
closed_csid.shape
# Out:
# (7850, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, closed_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.7786082868436094

# %% [markdown]
# ### Voicemails

# %%
voicemails_csid = last_act.loc[last_act['Activity Name'].isin(['CriminalRecordsVoicemailTransfer','HIVVoicemailTransfer',
                                                              'VeteransBenefitsVoicemailTransfer','TraffickingVoicemailTransfer',
                                                              'MigrantVoicemailTransfer','AddressFaxHoursMenu','ImmigrationOtherMenu']),:]
voicemails_csid['Outcome_class'] = 'Positive'
voicemails_csid['Outcome']= 'Voicemail'
voicemails_csid = voicemails_csid[['Contact Session ID','Outcome','Outcome_class']]
voicemails_csid = voicemails_csid.drop_duplicates(subset="Contact Session ID", keep="first")
voicemails_csid.shape
# Out:
# (4282, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, voicemails_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.7958436979254715

# %% [markdown]
# ### SetCallerID

# %%
callerid_csid = last_act.loc[(last_act['Activity Name'] == 'SetCallerID'),:]
callerid_csid['Outcome_class'] = 'Positive'
callerid_csid['Outcome']= 'Connected to agent'
callerid_csid = callerid_csid[['Contact Session ID','Outcome','Outcome_class']]
callerid_csid = callerid_csid.drop_duplicates(subset="Contact Session ID", keep="first")
callerid_csid.shape
# Out:
# (9358, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, callerid_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.833510437043656

# %% [markdown]
# ### LegalServerScreenPop

# %%
screenpop_csid = last_act.loc[last_act['Activity Name'].isin(['LegalServerScreenPop','ScreenPopProcessComplete']),:]
screenpop_csid['Outcome_class'] = 'Positive'
screenpop_csid['Outcome']= 'Connected to agent'
screenpop_csid = screenpop_csid[['Contact Session ID','Outcome','Outcome_class']]
screenpop_csid = screenpop_csid.drop_duplicates(subset="Contact Session ID", keep="first")
screenpop_csid.shape
# Out:
# (9633, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, screenpop_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.8722840743513577

# %%
# Ensure data is sorted properly
df_sorted = df_main.loc[df_main['Contact Session ID'].isin(screenpop_csid['Contact Session ID']),:]
import pandas as pd
import matplotlib.pyplot as plt

# Ensure proper sorting

# 1. First LegalServerScreenPop timestamp per Contact Session ID
first_pop = (
    df_sorted[df_sorted["Activity Name"] == "LegalServerScreenPop"]
    .groupby("Contact Session ID")["Activity Start Timestamp"]
    .first()
)

# 2. Last timestamp per Contact Session ID
last_ts = (
    df_sorted.groupby("Contact Session ID")["Activity Start Timestamp"]
    .last()
)

# 3. Merge and keep only IDs that have LegalServerScreenPop
merged = pd.concat([first_pop, last_ts], axis=1).dropna()
merged.columns = ["First_LegalServerScreenPop", "Last_Timestamp"]

# 4. Compute duration in seconds
merged["Duration_seconds"] = (
    merged["Last_Timestamp"] - merged["First_LegalServerScreenPop"]
).dt.total_seconds()

# %%
merged.loc[merged['Duration_seconds']>10,:].shape
# Out:
# (9596, 3)

# %% [markdown]
# ### FrontDeskTransfer1

# %%
fd1_csid = last_act.loc[(last_act['Activity Name'] == 'FrontDeskTransfer1'),:]
fd1_csid['Outcome_class'] = 'Negative'
fd1_csid['Outcome']= 'Could not select language (FDT1)'
fd1_csid = fd1_csid[['Contact Session ID','Outcome','Outcome_class']]
fd1_csid = fd1_csid.drop_duplicates(subset="Contact Session ID", keep="first")
fd1_csid.shape
# Out:
# (7890, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, fd1_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9040419896796837

# %% [markdown]
# ### FrontDeskTransfer2

# %%
fd2_csid = last_act.loc[(last_act['Activity Name'] == 'FrontDeskTransfer2'),:]
fd2_csid['Outcome_class'] = 'Positive'
fd2_csid['Outcome']= 'Appt/Feedback/OtherReason (FDT2)'
fd2_csid = fd2_csid[['Contact Session ID','Outcome','Outcome_class']]
fd2_csid = fd2_csid.drop_duplicates(subset="Contact Session ID", keep="first")
fd2_csid.shape
# Out:
# (6895, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, fd2_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9317949461041208

# %% [markdown]
# ### FrontDeskTransfer

# %%
fd_csid = last_act.loc[(last_act['Activity Name'] == 'FrontDeskTransfer'),:]
fd_csid['Outcome_class'] = 'Negative'
fd_csid['Outcome']= 'LegalMenu language issue (FDT)'
fd_csid = fd_csid[['Contact Session ID','Outcome','Outcome_class']]
fd_csid = fd_csid.drop_duplicates(subset="Contact Session ID", keep="first")
fd_csid.shape
# Out:
# (2545, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, fd_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9420387857125607

# %% [markdown]
# ### FrontDeskTransfer3

# %%
fd3_csid = last_act.loc[(last_act['Activity Name'] == 'FrontDeskTransfer3'),:]
fd3_csid['Outcome_class'] = 'Negative'
fd3_csid['Outcome']= 'Main menu no selection (FDT3)'
fd3_csid = fd3_csid[['Contact Session ID','Outcome','Outcome_class']]
fd3_csid = fd3_csid.drop_duplicates(subset="Contact Session ID", keep="first")
fd3_csid.shape
# Out:
# (541, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, fd3_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9442163563326652

# %% [markdown]
# ### OtherLegalOtherMenu

# %%
olo_csid = last_act.loc[(last_act['Activity Name'] == 'OtherLegalOtherMenu'),:]
olo_csid['Outcome_class'] = 'Neutral'
olo_csid['Outcome']= 'LAC does not serve'
olo_csid = olo_csid[['Contact Session ID','Outcome','Outcome_class']]
olo_csid = olo_csid.drop_duplicates(subset="Contact Session ID", keep="first")
olo_csid.shape
# Out:
# (2136, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, olo_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9528139364519687

# %% [markdown]
# ### OtherLegalMenu

# %%
olm_csid = last_act.loc[(last_act['Activity Name'] == 'OtherLegalMenu'),:]
olm_data = df_main.loc[df_main['Contact Session ID'].isin(olm_csid['Contact Session ID']),:]
olm_in_other = df_main.loc[df_main['Activity Name'].isin(['OtherLegalPersonalInjuryMenu','OtherLegalCriminalCaseMenu',
                                                         'OtherLegalOtherMenu','ClinicVoicemailTransfer']),:]
olm_csid_inside_menu = olm_csid.loc[olm_csid['Contact Session ID'].isin(olm_in_other['Contact Session ID']),:]
olm_csid_inside_menu['Outcome_class'] = 'Neutral'
olm_csid_inside_menu['Outcome']= 'LAC does not serve'
olm_csid_inside_menu = olm_csid_inside_menu[['Contact Session ID','Outcome','Outcome_class']]
olm_csid_inside_menu = olm_csid_inside_menu.drop_duplicates(subset="Contact Session ID", keep="first")
olm_csid_inside_menu.shape
# Out:
# (6499, 3)

# %%
olm_not_csid_inside_menu = olm_csid.loc[~olm_csid['Contact Session ID'].isin(olm_in_other['Contact Session ID']),:]
olm_not_csid_inside_menu['Outcome_class'] = 'Negative'
olm_not_csid_inside_menu['Outcome']= 'Abandoned'
olm_not_csid_inside_menu = olm_not_csid_inside_menu[['Contact Session ID','Outcome','Outcome_class']]
olm_not_csid_inside_menu = olm_not_csid_inside_menu.drop_duplicates(subset="Contact Session ID", keep="first")
olm_not_csid_inside_menu.shape
# Out:
# (364, 3)

# %%
6499+364
# Out:
# 6863

# %%
outcome_tagged = pd.concat([outcome_tagged, olm_csid_inside_menu, olm_not_csid_inside_menu])
outcome_tagged.shape[0]/248442
# Out:
# 0.9804380901779892

# %% [markdown]
# ### TenantDeterrenceMenu

# %%
tenant_deterrence_csid = last_act.loc[(last_act['Activity Name'] == 'TenantDeterrenceMenu'),:]
tenant_deterrence_csid['Outcome_class'] = 'Neutral'
tenant_deterrence_csid['Outcome']= 'LAC does not serve'
tenant_deterrence_csid = tenant_deterrence_csid[['Contact Session ID','Outcome','Outcome_class']]
tenant_deterrence_csid = tenant_deterrence_csid.drop_duplicates(subset="Contact Session ID", keep="first")
tenant_deterrence_csid.shape
# Out:
# (870, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, tenant_deterrence_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9839399135411887

# %% [markdown]
# ### LAC does not serve

# %%
lac_not_serve_csid = last_act.loc[last_act['Activity Name'].isin(['PreTenantMenu','ChildSupportMenu','OtherLegalPersonalInjuryMenu',
                                                                'OtherLegalCriminalCaseMenu','SimpleDivorceMenu','WorkersCompMenu',
                                                                 'ThankYouGoodbye','SeniorNotCookCoMenu','DisconnectContact2']),:]
lac_not_serve_csid['Outcome_class'] = 'Neutral'
lac_not_serve_csid['Outcome']= 'LAC does not serve'
lac_not_serve_csid = lac_not_serve_csid[['Contact Session ID','Outcome','Outcome_class']]
lac_not_serve_csid = lac_not_serve_csid.drop_duplicates(subset="Contact Session ID", keep="first")
lac_not_serve_csid.shape
# Out:
# (2974, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, lac_not_serve_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.9959105143252751

# %% [markdown]
# ### TransferToSafeHaven

# %%
safehaven_csid = last_act.loc[(last_act['Activity Name'] == 'TransferToSafeHaven'),:]
safehaven_csid['Outcome_class'] = 'Positive'
safehaven_csid['Outcome']= 'Safe Haven (bot)'
safehaven_csid = safehaven_csid[['Contact Session ID','Outcome','Outcome_class']]
safehaven_csid = safehaven_csid.drop_duplicates(subset="Contact Session ID", keep="first")
safehaven_csid.shape
# Out:
# (412, 3)

# %%
outcome_tagged = pd.concat([outcome_tagged, safehaven_csid])
outcome_tagged.shape[0]/248442
# Out:
# 0.997568849067388

# %% [markdown]
# 99.7% outcomes identified

# %%
outcome_tagged['Outcome_class'].value_counts()
# Out:
# Outcome_class
# Negative    137263
# Positive     62574
# Neutral      48001
# Name: count, dtype: int64

# %%
outcome_tagged['Outcome'].value_counts()
# Out:
# Outcome
# Abandoned                            48791
# Closed Queue                         42039
# Staff directory transfer             31994
# Voicemail                            28674
# Abandoned (Language not selected)    27545
# Connected to agent                   18991
# Closed hours                         18573
# LAC does not serve                   12930
# Could not select language (FDT1)      7890
# Appt/Feedback/OtherReason (FDT2)      6895
# LegalMenu language issue (FDT)        2545
# Main menu no selection (FDT3)          541
# Safe Haven (bot)                       412
# Callback not tried                      18
# Name: count, dtype: int64

# %%
pd.crosstab( outcome_tagged["Outcome"],outcome_tagged["Outcome_class"])
# Out:
# Outcome_class                      Negative  Neutral  Positive
# Outcome
# Abandoned                             48791        0         0
# Abandoned (Language not selected)     27545        0         0
# Appt/Feedback/OtherReason (FDT2)          0        0      6895
# Callback not tried                       18        0         0
# Closed Queue                          42039        0         0
# Closed hours                              0    18573         0
# Connected to agent                        0        0     18991
# Could not select language (FDT1)       7890        0         0
# LAC does not serve                        0    12930         0
# LegalMenu language issue (FDT)         2545        0         0
# Main menu no selection (FDT3)           541        0         0
# Safe Haven (bot)                          0        0       412
# Staff directory transfer                  0        0     31994
# Voicemail                                 0        0     28674

# %%
outcome_tagged.groupby(['Outcome_class','Outcome'])['Contact Session ID'].nunique()
# Out:
# Outcome_class  Outcome
# Negative       Abandoned                            48791
#                Abandoned (Language not selected)    27545
#                Callback not tried                      18
#                Closed Queue                         42039
#                Could not select language (FDT1)      7890
#                LegalMenu language issue (FDT)        2545
#                Main menu no selection (FDT3)          541
# Neutral        Closed hours                         18573
#                LAC does not serve                   12930
# Positive       Appt/Feedback/OtherReason (FDT2)      6895
#                Connected to agent                   18991
#                Safe Haven (bot)                       412
#                Staff directory transfer             31994
#                Voicemail                            28674
# Name: Contact Session ID, dtype: int64

# %%
all_data.shape
# Out:
# (3188765, 10)

# %% [markdown]
# #### checks

# %%
custdata('f8575f41-f3e3-45fc-a02f-39ea67d024b8');

# %%
subsenior_queue_csid = last_act.loc[(last_act['Activity Name'] == 'DisconnectContact2'),:]
subsenior_queue_csid;

# %% [markdown]
# ### Tagged data

# %%
tagged_data = all_data.merge(outcome_tagged)

# %%
df_main.shape
# Out:
# (3328626, 9)

# %%
all_data.shape
# Out:
# (3209561, 10)

# %%
all_data['Contact Session ID'].nunique()
# Out:
# 248442

# %%
df_main['Contact Session ID'].nunique()
# Out:
# 248442

# %%
outcome_tagged['Contact Session ID'].nunique()
# Out:
# 247838

# %%
tagged_data['Contact Session ID'].nunique()
# Out:
# 247838

# %%
tagged_data.shape
# Out:
# (3197944, 12)

# %%
tagged_data.groupby(['caller_type','Outcome_class','Outcome'])['Contact Session ID'].nunique().to_csv(adhoc_data_path + 'outcome_tagged_data.csv')

# %%
tagged_data.groupby(['caller_type','Outcome_class'])['Contact Session ID'].nunique()
# Out:
# caller_type             Outcome_class
# Abandoned callers       Negative          2492
# Chicago senior          Negative         10488
#                         Neutral           2145
#                         Positive          5359
# Closed hours callers    Negative           135
#                         Neutral          18573
#                         Positive          3153
# Farmworker (FDT/legal)  Negative            32
# Farmworker menu only    Negative          9797
#                         Positive            67
# Intake Outdial          Negative             5
#                         Positive          9358
# Main menu only          Negative         48895
#                         Positive         49239
# No activity callers     Negative             6
# Non-Cook County Senior  Negative           312
#                         Neutral            899
#                         Positive            98
# Non-senior legal issue  Negative         51079
#                         Neutral           9667
#                         Positive         15604
# Suburban senior         Negative          3836
#                         Neutral            291
#                         Positive          4109
# Unclassified seniors    Negative           444
# Name: Contact Session ID, dtype: int64

# %%
tagged_data.groupby(['caller_type'])['Contact Session ID'].nunique()
# Out:
# caller_type
# Abandoned callers          2492
# Chicago senior            17992
# Closed hours callers      21861
# Farmworker (FDT/legal)       32
# Farmworker menu only       9864
# Intake Outdial             9363
# Main menu only            98134
# No activity callers           6
# Non-Cook County Senior     1309
# Non-senior legal issue    76350
# Suburban senior            8236
# Unclassified seniors        444
# Name: Contact Session ID, dtype: int64

# %%
tagged_data["EP Name"] = (
    tagged_data.groupby("Contact Session ID")["EP Name"]
             .ffill()
)

# %%
tagged_last_row = tagged_data.groupby('Contact Session ID').tail(1)

# %%
abandoned = tagged_last_row.loc[tagged_last_row['Outcome'].isin(['Abandoned','Abandoned (Language not selected)']),:]

# %%
abandoned.groupby('EP Name')['Contact Session ID'].nunique().sort_values(ascending = False)
# Out:
# EP Name
# Main Number Telephony EP                    40528
# Legal Menu Telephony EP                     13613
# Farmworker Main Number Telephony EP          9797
# Legal Housing Menu Telephony EP              3094
# Pre-Legal Menu Seniors Menu Telephony EP     2702
# All LAC Queues Telephony EP                  2636
# Legal Family Menu Telephony EP               1874
# Legal HIV Menu Telephony EP                   767
# Legal Immigration Menu Telephony EP           525
# Other Legal Menu Telephony EP                 359
# Legal Benefits Menu Telephony EP              297
# Closed Hours-Holidays Menu Telephony EP       135
# Intake Outdial EP                               5
# Closed Queue Menu Telephony EP                  3
# Legal Employment Menu Telephony EP              1
# Name: Contact Session ID, dtype: int64

# %%
tagged_last_row.groupby('EP Name')['Contact Session ID'].nunique().sort_values(ascending = False)/248422
# Out:
# EP Name
# Main Number Telephony EP                    0.395766
# Closed Queue Menu Telephony EP              0.201025
# Closed Hours-Holidays Menu Telephony EP     0.087999
# Legal Menu Telephony EP                     0.074281
# Other Legal Menu Telephony EP               0.049126
# Farmworker Main Number Telephony EP         0.039707
# Intake Outdial EP                           0.037690
# Courtesy Callback Telephony EP              0.036056
# Legal Housing Menu Telephony EP             0.021149
# Pre-Legal Menu Seniors Menu Telephony EP    0.015144
# Legal Family Menu Telephony EP              0.014516
# All LAC Queues Telephony EP                 0.013529
# Legal HIV Menu Telephony EP                 0.006453
# Legal Immigration Menu Telephony EP         0.003140
# Legal Benefits Menu Telephony EP            0.001940
# Legal Employment Menu Telephony EP          0.000129
# Name: Contact Session ID, dtype: float64

# %%
13613+3094+1874+767

# %%
767/1603
# Out:
# 0.4784778540237056

# %%
1/32
# Out:
# 0.03125

# %%
297/482
# Out:
# 0.6161825726141079

# %%
tagged_last_row['Contact Session ID'].nunique()
# Out:
# 247838

# %%
abandoned.shape
# Out:
# (76336, 12)

# %%
tagged_last_row.shape
# Out:
# (247838, 12)

# %%
76336/247838
# Out:
# 0.30800765015857134

# %%
1874/3606
# Out:
# 0.5196894065446478

# %%
13609/18449
# Out:
# 0.737655157461109

# %%
3094/5254
# Out:
# 0.5888846593071945

# %%
df_main.loc[df_main['EP Name'] == 'Legal Family Menu Telephony EP','Activity Name'].value_counts()
# Out:
# Activity Name
# FamilyMenu                 27415
# DivorceOrParentingMenu     15190
# SimpleDivorceMenu           2601
# ChildSupportMenu            2437
# ClinicVoicemailTransfer      427
# TransferToSafeHaven          412
# Name: count, dtype: int64

# %%
tagged_last_row['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    98316
# Closed Queue Menu Telephony EP              49939
# Closed Hours-Holidays Menu Telephony EP     21861
# Legal Menu Telephony EP                     18449
# Other Legal Menu Telephony EP               12204
# Farmworker Main Number Telephony EP          9864
# Legal Housing Menu Telephony EP              5254
# Pre-Legal Menu Seniors Menu Telephony EP     3762
# Legal Family Menu Telephony EP               3606
# All LAC Queues Telephony EP                  2730
# Legal HIV Menu Telephony EP                  1603
# Intake Outdial EP                            1032
# Legal Immigration Menu Telephony EP           780
# Courtesy Callback Telephony EP                649
# Legal Benefits Menu Telephony EP              482
# Legal Employment Menu Telephony EP             32
# Name: count, dtype: int64

# %%
76636/248442
# Out:
# 0.3084663623702917

# %%
tagged_last_row['Contact Session ID'].nunique()
# Out:
# 247838

# %%
247838
# Out:
# 247838

# %%
tagged_last_row['Outcome'].value_counts()
# Out:
# Outcome
# Closed Queue                         49933
# Abandoned                            48791
# Staff directory transfer             31994
# Abandoned (Language not selected)    27545
# Voicemail                            20780
# Connected to agent                   18991
# Closed hours                         18573
# LAC does not serve                   12930
# Could not select language (FDT1)      7890
# Appt/Feedback/OtherReason (FDT2)      6895
# LegalMenu language issue (FDT)        2545
# Main menu no selection (FDT3)          541
# Safe Haven (bot)                       412
# Callback not tried                      18
# Name: count, dtype: int64

# %%
tagged_last_row['Outcome'].value_counts()/247838
# Out:
# Outcome
# Closed Queue                         0.201474
# Abandoned                            0.196867
# Staff directory transfer             0.129092
# Abandoned (Language not selected)    0.111141
# Voicemail                            0.083845
# Connected to agent                   0.076627
# Closed hours                         0.074940
# LAC does not serve                   0.052171
# Could not select language (FDT1)     0.031835
# Appt/Feedback/OtherReason (FDT2)     0.027821
# LegalMenu language issue (FDT)       0.010269
# Main menu no selection (FDT3)        0.002183
# Safe Haven (bot)                     0.001662
# Callback not tried                   0.000073
# Name: count, dtype: float64

# %%
tagged_last_row['Outcome'].value_counts()/372
# Out:
# Outcome
# Closed Queue                         134.228495
# Abandoned                            131.158602
# Staff directory transfer              86.005376
# Abandoned (Language not selected)     74.045699
# Voicemail                             55.860215
# Connected to agent                    51.051075
# Closed hours                          49.927419
# LAC does not serve                    34.758065
# Could not select language (FDT1)      21.209677
# Appt/Feedback/OtherReason (FDT2)      18.534946
# LegalMenu language issue (FDT)         6.841398
# Main menu no selection (FDT3)          1.454301
# Safe Haven (bot)                       1.107527
# Callback not tried                     0.048387
# Name: count, dtype: float64

# %%
42039/247838
# Out:
# 0.16962289882907383

# %%
 48791+27545
# Out:
# 76336

# %%
76636/372
# Out:
# 206.01075268817203
