# %% [markdown]
# Author: Krish

# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import date

# %%
data_path = "C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Spring 2025\\STAT390\\LegalAid\\Data\\CAR_-_EP_Flow_Activity_Queue__Agent_Names\\"
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))
df_main = pd.DataFrame(columns=['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name', 'Activity Start Timestamp', 
                                'Queue Name', 'Agent Name', 'Termination Reason'])
df_main
# Out:
# Empty DataFrame
# Columns: [Contact Session ID, EP Name, Flow Name, Activity Name, Activity Start Timestamp, Queue Name, Agent Name, Termination Reason]
# Index: []

# %%
i=0
for f in files:
    i = i + 1
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=2, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=2, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df.shape)
# Out:
# 1 CAR - EP, Flow, Activity, Queue, & Agent Names (01-12-25 - 01-18-25) (52010, 7)
# 2 CAR - EP, Flow, Activity, Queue, & Agent Names (01-19-25 - 02-01-25) (95495, 7)
# 3 CAR - EP, Flow, Activity, Queue, & Agent Names (02-02-25 - 02-15-25) (90056, 7)
# 4 CAR - EP, Flow, Activity, Queue, & Agent Names (02-16-25 - 03-01-25) (88186, 7)
# 5 CAR - EP, Flow, Activity, Queue, & Agent Names (03-02-25 - 03-15-25) (86377, 7)
# 6 CAR - EP, Flow, Activity, Queue, & Agent Names (04-07-24 - 04-20-24) (88766, 7)
# 7 CAR - EP, Flow, Activity, Queue, & Agent Names (04-21-24 - 05-04-24) (89643, 7)
# 8 CAR - EP, Flow, Activity, Queue, & Agent Names (05-05-24 - 05-18-24) (82575, 7)
# 9 CAR - EP, Flow, Activity, Queue, & Agent Names (05-19-24 - 06-01-24) (71103, 7)
# 10 CAR - EP, Flow, Activity, Queue, & Agent Names (06-02-24 - 06-15-24) (84354, 7)
# 11 CAR - EP, Flow, Activity, Queue, & Agent Names (06-16-24 - 06-29-24) (82124, 7)
# ...

# %%
df_main["Activity Start Timestamp"] = df_main["Activity Start Timestamp"].apply(
    lambda x: datetime.strptime(x, "%Y/%m/%d %I:%M:%S %p"))

# %%
df_main.shape
# Out:
# (3328626, 8)

# %%
df_main.dtypes
# Out:
# Contact Session ID                  object
# EP Name                             object
# Flow Name                           object
# Activity Name                       object
# Activity Start Timestamp    datetime64[ns]
# Queue Name                          object
# Agent Name                          object
# Termination Reason                  object
# dtype: object

# %%
df_main["hour"] = df_main["Activity Start Timestamp"].dt.hour

# %%
df_main.sort_values(by = ['Contact Session ID', 'Activity Start Timestamp'], inplace=True)

# %%
df_main.reset_index(inplace = True, drop = True)

# %%
df_main.head()
# Out:
#                      Contact Session ID                   EP Name Flow Name  \
# 0  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 1  00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN   LACMain
# 2  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
# 3  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP   LACMain
# 4  00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP       NaN
#
#            Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 0                    NaN      2025-03-13 12:51:21        NaN        NaN
# 1                    NaN      2025-03-13 12:51:21        NaN        NaN
# 2  LanguageSelectionMenu      2025-03-13 12:51:21        NaN        NaN
# 3                    NaN      2025-03-13 12:51:21        NaN        NaN
# 4               MainMenu      2025-03-13 12:51:31        NaN        NaN
#
#   Termination Reason  hour
# 0                NaN    12
# ...

# %%
def custdata(id):
    return df_main.loc[df_main['Contact Session ID'] == id,:]

# %% [markdown]
# # 12 niv

# %%
df_main.loc[df_main['Activity Name'] == 'ComplimentOrComplaintMenu','Contact Session ID'].nunique()
# Out:
# 1154

# %%
df_main.loc[df_main['Activity Name'] == 'AddressFaxHoursMenu','Contact Session ID'].nunique()
# Out:
# 3540

# %% [markdown]
# ## 10 Nov

# %%
custdata('00748cda-3757-4816-8009-6b0f05186c34')[30:];

# %%
df_main.loc[(df_main['Activity Name'] == 'CallbackRetry') & ((df_main.hour == 2) | (df_main.hour == 5)),
'Contact Session ID'].nunique()
# Out:
# 873

# %%
pd.DataFrame(df_main.loc[(df_main['Activity Name'] == 'CallbackRetry') & ((df_main.hour == 2) | (df_main.hour == 5)),
'Contact Session ID'].unique())
# Out:
#                                         0
# 0    00748cda-3757-4816-8009-6b0f05186c34
# 1    00e5ee6f-5073-42fd-9fd2-7466b9b8f51e
# 2    0198b67b-df21-4678-a440-e43c8a531c97
# 3    01ec9cb9-3a91-462c-8323-8cdd3c76d09a
# 4    020ef1ea-04ef-4624-a75d-4ed838f052a1
# ..                                    ...
# 868  fea712a9-ddb0-417e-9ca9-68b610fc3461
# 869  fecc0791-c1ae-4e9e-87b0-8c487b19c038
# 870  ff2d9a2c-ff33-4e2a-961c-4c65bfdeb63a
# 871  ffc8f728-d545-4637-ab2b-e5f44d5b55a4
# 872  ffd82a4b-a4b5-41d6-bc29-f1612d1c307e
#
# [873 rows x 1 columns]

# %%
pd.DataFrame(df_main.loc[(df_main['Activity Name'] == 'CallbackRetry') & ((df_main.hour == 2) | (df_main.hour == 5)),
'Contact Session ID'].unique()).to_csv(adhoc_data_path + 'callbacks_2am_or_5am.csv', index = False)

# %%
873/377
# Out:
# 2.315649867374005

# %%
closedqrows = df_main.loc[df_main['Activity Name'] == 'ClosedQueueMenu',:]
closedqdata = df_main.loc[df_main['Contact Session ID'].isin(closedqrows['Contact Session ID']),:]
closedqdata['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    198667
# Closed Queue Menu Telephony EP              174361
# Legal Menu Telephony EP                      99300
# Pre-Legal Menu Seniors Menu Telephony EP     97805
# Legal Family Menu Telephony EP               29063
# Legal Housing Menu Telephony EP              25988
# Legal Benefits Menu Telephony EP              6122
# Legal Employment Menu Telephony EP            4092
# Other Legal Menu Telephony EP                 3565
# Legal Immigration Menu Telephony EP           3500
# All LAC Queues Telephony EP                   2778
# Farmworker Main Number Telephony EP           1012
# Legal HIV Menu Telephony EP                    423
# Name: count, dtype: int64

# %%
df_main.loc[df_main['Activity Name'] == 'HIVMenu','Contact Session ID'].nunique()
# Out:
# 2112

# %%
df_main.loc[df_main['Activity Name'] == 'SeniorsMenu','Contact Session ID'].nunique()
# Out:
# 109184

# %%
df_main.loc[df_main['Activity Name'] == 'SeniorsMenu','Contact Session ID'].count()
# Out:
# 125748

# %%
df_main.loc[df_main['Activity Name'] == 'LegalMenu1','Contact Session ID'].nunique()
# Out:
# 96173

# %%
df_main.loc[df_main['Activity Name'] == 'ThankYouGoodbye','Contact Session ID'].nunique()
# Out:
# 679

# %%
df_main['YearMonth'] = df_main['Activity Start Timestamp'].dt.to_period('M').astype(str)

# %%
df_main.loc[df_main['Activity Name'] == 'HIVMenu',:].groupby('YearMonth')['Contact Session ID'].nunique()
# Out:
# YearMonth
# 2024-04    108
# 2024-05    120
# 2024-06    115
# 2024-07    147
# 2024-08    112
# 2024-09    132
# 2024-10    140
# 2024-11     90
# 2024-12    110
# 2025-01    135
# 2025-02     95
# 2025-03    128
# 2025-04    126
# 2025-05    106
# 2025-06    125
# 2025-07    104
# 2025-08    110
# 2025-09    109
# Name: Contact Session ID, dtype: int64

# %%
df_main['Contact Session ID'].nunique()
# Out:
# 248442

# %%
df_main['Activity Name'].value_counts().to_csv(adhoc_data_path + 'activity_counts.csv')

# %%
df_main[['Contact Session ID', 'Activity Name']].groupby('Activity Name').nunique().sort_values(by = 'Contact Session ID', ascending = False).\
to_csv(adhoc_data_path + 'activity_callcounts.csv')

# %%
# Forward-fill Activity Name within each Contact Session ID
df_main2 = df_main.copy()

df_main2['Activity Name'] = df_main2.groupby('Contact Session ID')['Activity Name'].ffill()

# Get the last non-missing Activity Name for each Contact Session ID
last_activity = df_main2.groupby('Contact Session ID')['Activity Name'].last().reset_index()

# %%
setcallerid_rows = df_main.loc[df_main['Activity Name'] == 'SetCallerID',:]
setcallerid_rows['EP Name'].value_counts()
# Out:
# EP Name
# Intake Outdial EP    18734
# Name: count, dtype: int64

# %%
setcallerid_rows.hour.value_counts();

# %%
last_activity.loc[last_activity['Activity Name'] == 'SetCallerID',:]
# Out:
#                           Contact Session ID Activity Name
# 15      0004529f-0f07-421c-9d72-4baed1a8559e   SetCallerID
# 16      0004ac0b-e969-4444-ad9e-68f540580a5b   SetCallerID
# 36      000a3bc0-45e5-49e5-8bda-3f2141b2bc38   SetCallerID
# 66      001232d0-25a9-4b83-9215-fc053d8077d3   SetCallerID
# 84      001853bf-3199-412f-8c71-e6c29ba451ce   SetCallerID
# ...                                      ...           ...
# 248378  ffeeeb2b-2388-4171-ad94-8579d212788e   SetCallerID
# 248391  fff2d0b9-dafc-4d9e-952a-51b8a30cc4c0   SetCallerID
# 248411  fff67ad3-7935-42db-9e3f-bd8c7d6de5ee   SetCallerID
# 248423  fff98171-31fb-4c91-af7e-9b4676e1c413   SetCallerID
# 248424  fffa0b4e-59dc-4b77-b4eb-42b83390acbb   SetCallerID
#
# [9358 rows x 2 columns]

# %%
custdata('0004529f-0f07-421c-9d72-4baed1a8559e')
# Out:
#                        Contact Session ID            EP Name       Flow Name  \
# 138  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 139  0004529f-0f07-421c-9d72-4baed1a8559e                NaN  Intake_Outdial
# 140  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 141  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 142  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 143  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 144  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 145  0004529f-0f07-421c-9d72-4baed1a8559e  Intake Outdial EP             NaN
# 146  0004529f-0f07-421c-9d72-4baed1a8559e                NaN             NaN
# 147  0004529f-0f07-421c-9d72-4baed1a8559e                NaN             NaN
#
#          Activity Name Activity Start Timestamp            Queue Name  \
# ...

# %%
closedmenurows = df_main.loc[df_main['Activity Name'] == 'ClosedMenu',:]
closedmenurows['EP Name'].value_counts()
# Out:
# EP Name
# Closed Hours-Holidays Menu Telephony EP    23629
# Name: count, dtype: int64

# %%
#custdata('0000a8d5-cecb-46b1-82cf-b7ce07d85b24')

# %%
farmrows = df_main.loc[df_main['EP Name'] == 'Farmworker Main Number Telephony EP',:]
farm_data = df_main.loc[df_main['Contact Session ID'].isin(farmrows['Contact Session ID']),:]
# Forward-fill Activity Name within each Contact Session ID
farm_data2 = farm_data.copy()

farm_data2['Activity Name'] = farm_data2.groupby('Contact Session ID')['Activity Name'].ffill()

# Get the last non-missing Activity Name for each Contact Session ID
last_activity_farm_data = farm_data2.groupby('Contact Session ID')['Activity Name'].last().reset_index()
last_activity_farm_data.groupby('Activity Name').nunique().sort_values(by = 'Contact Session ID', ascending = False)
# Out:
#                                   Contact Session ID
# Activity Name
# FarmworkerMainMenu                              9640
# ClosedQueueMenu                                  199
# LanguageSelectionMenu                            156
# MigrantVoicemailTransfer                          67
# ClinicVoicemailTransfer                           64
# DisconnectContact1                                53
# LegalMenu2                                        44
# ClosedMenu                                        29
# LegalServerScreenPop                              21
# FrontDeskTransfer                                 19
# ImmigrationMenu                                   12
# OtherLegalMenu                                    10
# TenantMenu                                        10
# SeniorsMenu                                        7
# LegalMenu1                                         7
# StaffDirectorySpanishTransfer                      6
# ...

# %%
last_activity_farm_data
# Out:
#                          Contact Session ID            Activity Name
# 0      0003aec2-1d09-47d3-8d08-937b92764eee       FarmworkerMainMenu
# 1      0005a285-d65d-4f64-8b6d-a7d2e27dcfdc       FarmworkerMainMenu
# 2      000dfe16-65d2-47b7-ac80-e1bc7770ab1f       FarmworkerMainMenu
# 3      00129031-2896-433f-a826-fdaed2174611       FarmworkerMainMenu
# 4      001b716a-a16c-4e77-b26c-6c96a473b689       FarmworkerMainMenu
# ...                                     ...                      ...
# 10395  ffe3a1e6-43d6-4f03-88a8-7a10a9e6aabe  ClinicVoicemailTransfer
# 10396  ffe4271a-cbae-4307-901e-10200d237541       FarmworkerMainMenu
# 10397  fff32f97-537d-4f5d-8dcb-c7a71cace9c2       FarmworkerMainMenu
# 10398  fff8e577-b64b-41ba-83a9-3286c28dab3b       FarmworkerMainMenu
# 10399  fffe199f-3382-43e1-b8a5-efb9d55bdb23       FarmworkerMainMenu
#
# [10400 rows x 2 columns]

# %%
custdata('0003aec2-1d09-47d3-8d08-937b92764eee')
# Out:
#                        Contact Session ID  \
# 121  0003aec2-1d09-47d3-8d08-937b92764eee
# 122  0003aec2-1d09-47d3-8d08-937b92764eee
# 123  0003aec2-1d09-47d3-8d08-937b92764eee
# 124  0003aec2-1d09-47d3-8d08-937b92764eee
# 125  0003aec2-1d09-47d3-8d08-937b92764eee
# 126  0003aec2-1d09-47d3-8d08-937b92764eee
#
#                                  EP Name       Flow Name  \
# 121  Farmworker Main Number Telephony EP             NaN
# 122                                  NaN  FarmworkerMain
# 123  Farmworker Main Number Telephony EP             NaN
# 124  Farmworker Main Number Telephony EP  FarmworkerMain
# 125  Farmworker Main Number Telephony EP             NaN
# 126  Farmworker Main Number Telephony EP             NaN
#
#              Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 121                    NaN      2024-05-24 13:43:04        NaN        NaN
# 122                    NaN      2024-05-24 13:43:04        NaN        NaN
# ...

# %%
custdata('0005a285-d65d-4f64-8b6d-a7d2e27dcfdc')
# Out:
#                        Contact Session ID  \
# 245  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
# 246  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
# 247  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
# 248  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
# 249  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
# 250  0005a285-d65d-4f64-8b6d-a7d2e27dcfdc
#
#                                  EP Name       Flow Name  \
# 245  Farmworker Main Number Telephony EP             NaN
# 246                                  NaN  FarmworkerMain
# 247  Farmworker Main Number Telephony EP             NaN
# 248  Farmworker Main Number Telephony EP  FarmworkerMain
# 249  Farmworker Main Number Telephony EP             NaN
# 250  Farmworker Main Number Telephony EP             NaN
#
#              Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 245                    NaN      2024-11-02 17:48:07        NaN        NaN
# 246                    NaN      2024-11-02 17:48:07        NaN        NaN
# ...

# %%
custdata('fff32f97-537d-4f5d-8dcb-c7a71cace9c2')
# Out:
#                            Contact Session ID  \
# 3327961  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
# 3327962  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
# 3327963  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
# 3327964  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
# 3327965  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
# 3327966  fff32f97-537d-4f5d-8dcb-c7a71cace9c2
#
#                                      EP Name       Flow Name  \
# 3327961  Farmworker Main Number Telephony EP             NaN
# 3327962                                  NaN  FarmworkerMain
# 3327963  Farmworker Main Number Telephony EP             NaN
# 3327964  Farmworker Main Number Telephony EP  FarmworkerMain
# 3327965  Farmworker Main Number Telephony EP             NaN
# 3327966  Farmworker Main Number Telephony EP             NaN
#
#                  Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 3327961                    NaN      2024-05-01 12:57:26        NaN        NaN
# ...

# %%
last_activity['Activity Name'].isna().sum()
# Out:
# 177

# %%
last_activity.loc[last_activity['Activity Name'].isna(),:]
# Out:
#                           Contact Session ID Activity Name
# 572     00906e65-550d-4190-9add-da5a8d3a452e          None
# 3727    03d6ebbc-1aa0-450b-92bb-33e6ec1055d0          None
# 4748    04d6296e-d77b-4c90-80dd-b194a8e653a7          None
# 4754    04d7e372-6ff6-41b4-813e-bc18dd6dabfe          None
# 7357    077fc423-c9e5-4429-a299-a9d37e23fdc8          None
# ...                                      ...           ...
# 240589  f7e4fe8e-5721-4507-9c19-0ce739f0b7ce          None
# 243269  fab15640-eb9a-40ab-a9ec-e30b8722c04d          None
# 245624  fd139380-0d7f-4c3b-892a-5830484e4d00          None
# 246145  fda7048c-d72a-48d1-8a44-918320016a8a          None
# 247591  ff2d04fc-584d-4669-8900-ffd71100904b          None
#
# [177 rows x 2 columns]

# %%
last_activity.groupby('Activity Name').nunique().sort_values(by = 'Contact Session ID', ascending = False)
# Out:
#                                     Contact Session ID
# Activity Name
# ClosedQueueMenu                                  39892
# StaffDirectoryEnglishTransfer                    28035
# LanguageSelectionMenu                            27545
# ClinicVoicemailTransfer                          25721
# MainMenu                                         13075
# ...                                                ...
# EducationSPQueue                                     1
# PlayCCBConfirmation                                  1
# SubSeniorHomeownerQueue                              1
# SubSeniorConsumerQueue                               1
# GetLoggedInSubSeniorTenantSPAgents                   1
#
# [81 rows x 1 columns]

# %%
last_activity[['Contact Session ID', 'Activity Name']].groupby('Activity Name')['Contact Session ID'].nunique().sort_values(ascending = False)
# Out:
# Activity Name
# ClosedQueueMenu                       39892
# StaffDirectoryEnglishTransfer         28035
# LanguageSelectionMenu                 27545
# ClinicVoicemailTransfer               25721
# MainMenu                              13075
#                                       ...
# EducationSPQueue                          1
# PlayCCBConfirmation                       1
# SubSeniorHomeownerQueue                   1
# SubSeniorConsumerQueue                    1
# GetLoggedInSubSeniorTenantSPAgents        1
# Name: Contact Session ID, Length: 81, dtype: int64

# %%
no_activity_sessions = df_main[['Contact Session ID', 'Activity Name']].groupby('Contact Session ID')['Activity Name'] \
                              .filter(lambda x: x.isna().all()) \
                              .to_frame()

# %%
custdata('fda7048c-d72a-48d1-8a44-918320016a8a')
# Out:
#                            Contact Session ID                   EP Name  \
# 3297985  fda7048c-d72a-48d1-8a44-918320016a8a  Main Number Telephony EP
# 3297986  fda7048c-d72a-48d1-8a44-918320016a8a                       NaN
# 3297987  fda7048c-d72a-48d1-8a44-918320016a8a  Main Number Telephony EP
#
#         Flow Name Activity Name Activity Start Timestamp Queue Name  \
# 3297985       NaN           NaN      2025-04-25 11:42:10        NaN
# 3297986   LACMain           NaN      2025-04-25 11:42:10        NaN
# 3297987       NaN           NaN      2025-04-25 11:42:10        NaN
#
#         Agent Name       Termination Reason  hour
# 3297985        NaN                      NaN    11
# 3297986        NaN                      NaN    11
# 3297987        NaN  NO_ANSWER_FROM_CUSTOMER    11

# %%
no_activity_sessions
# Out:
#         Activity Name
# 7575              NaN
# 7576              NaN
# 7577              NaN
# 49370             NaN
# 49371             NaN
# ...               ...
# 3297986           NaN
# 3297987           NaN
# 3317373           NaN
# 3317374           NaN
# 3317375           NaN
#
# [470 rows x 1 columns]

# %% [markdown]
# ## 6th Nov

# %%
df_main['Contact Session ID'].nunique()/377
# Out:
# 658.9973474801061

# %%
# Ensure timestamp column is datetime
df = df_main.copy()
df = df.loc[df['Activity Name'] == 'EmploymentMenu',:]
df['Activity Start Timestamp'] = pd.to_datetime(df['Activity Start Timestamp'])

# Create Year-Month column
df['year_month'] = df['Activity Start Timestamp'].dt.to_period('M').astype(str)

# Count distinct Contact Session ID per month
monthly_counts = (
    df.groupby('year_month')['Contact Session ID']
    .nunique()
    .rename('count')
)

# Plot
plt.figure(figsize=(12,5))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o')

# Add data labels
for x, y in zip(monthly_counts.index, monthly_counts.values):
    plt.text(x, y, str(y), ha='center', va='bottom', fontsize=10)

plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Year-Month', fontsize=14)
plt.ylabel('Number of Distinct Contact Session IDs', fontsize=14)
plt.title('Monthly Callback Volume Over Time', fontsize=16)
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ## 5th nov

# %%
ccb_rows = df_main.loc[df_main['Activity Name'] == 'PlayCCBConfirmation',:]
ccb_data = df_main.loc[df_main['Contact Session ID'].isin(ccb_rows['Contact Session ID']),:]
ccb_data['Contact Session ID'].nunique()
# Out:
# 9028

# %%
callbackrows = df_main.loc[df_main['EP Name'] == 'Courtesy Callback Telephony EP',:]
callback_data = df_main.loc[df_main['Contact Session ID'].isin(callbackrows['Contact Session ID']),:]

# %%
callback_data['Contact Session ID'].nunique()
# Out:
# 9158

# %%
callback_data_agentrows = callback_data.loc[~callback_data['Agent Name'].isna(),:]
callback_data_agentrows['Contact Session ID'].nunique()
# Out:
# 8980

# %%
callback_data_retryrows = callback_data.loc[callback_data['Activity Name'] == 'CallbackRetry',:]
callback_data_retryrows['Contact Session ID'].nunique()
# Out:
# 1467

# %%
callback_data_screenpoprows = callback_data.loc[callback_data['Activity Name'] == 'LegalServerScreenPop',:]
callback_data_screenpoprows['Contact Session ID'].nunique()
callback_data_screenpoprows.shape
# Out:
# (10922, 11)

# %%
callback_screenpop_data = callback_data.loc[callback_data['Contact Session ID'].isin(callback_data_screenpoprows['Contact Session ID']),:]
# Out:
# 8970

# %%
import pandas as pd

df = callback_screenpop_data.copy()
results = []

for session_id, group in df.groupby('Contact Session ID'):
    
    # Find first LegalServerScreenPop
    lsp_idx = group.index[group['Activity Name'] == 'LegalServerScreenPop']
    if len(lsp_idx) == 0:
        continue
    
    first_lsp_idx = lsp_idx[0]
    
    # Row immediately above it
    start_pos = group.index.get_loc(first_lsp_idx) - 1
    if start_pos < 0:
        continue
    
    start_timestamp = group.iloc[start_pos]['Activity Start Timestamp']
    
    # Last row where Agent Name is not missing
    agent_rows = group[group['Agent Name'].notna()]
    if agent_rows.empty:
        continue
    
    end_timestamp = agent_rows.iloc[-1]['Activity Start Timestamp']
    
    # Duration in minutes
    duration_minutes = (end_timestamp - start_timestamp).total_seconds() / 60
    
    results.append((session_id, start_timestamp, end_timestamp, duration_minutes))

call_durations = pd.DataFrame(results, columns=[
    'Contact Session ID',
    'Start Timestamp',
    'End Timestamp',
    'Call Duration (minutes)'
])

call_durations.head()
# Out:
#                      Contact Session ID     Start Timestamp  \
# 0  000cce29-1c76-4991-9445-bb5f9028f47d 2024-05-29 15:02:22
# 1  00116654-66ea-4582-a109-aacde13a620d 2024-07-25 15:52:42
# 2  001741db-98b4-409f-8646-32ed0ecf6331 2025-07-23 09:13:50
# 3  0018380f-cf12-40f5-b525-af190304c42b 2024-08-20 13:57:18
# 4  0019d572-7f3e-4380-bc1f-274fc63edcb6 2025-09-17 10:52:41
#
#         End Timestamp  Call Duration (minutes)
# 0 2024-05-29 15:04:13                 1.850000
# 1 2024-07-25 15:52:56                 0.233333
# 2 2025-07-23 09:23:39                 9.816667
# 3 2024-08-20 14:00:46                 3.466667
# 4 2025-09-17 11:20:05                27.400000

# %%
call_durations.loc[call_durations['Call Duration (minutes)']<0.5,:].shape
# Out:
# (145, 4)

# %%
import matplotlib.pyplot as plt

# Remove outliers using the 95th percentile
threshold = call_durations['Call Duration (minutes)'].quantile(0.95)
filtered = call_durations[call_durations['Call Duration (minutes)'] <= threshold]

plt.figure(figsize=(6,4))
plt.hist(filtered['Call Duration (minutes)'], bins=20)
plt.xlabel('Call Duration (minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Call Duration (Outliers Removed)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
# Get indexes of rows where Activity Name is LegalServerScreenPop
idx = callback_screenpop_data.index[callback_screenpop_data['Activity Name'] == 'LegalServerScreenPop']

# Subtract 1 to get the row immediately above each one
rows_above = idx - 1

# Filter the original dataframe
df_above = df_main.loc[rows_above]
df_above['Agent Name'].value_counts()
df_above.loc[df_above['Agent Name'].isna(),:]
# Out:
#            index                    Contact Session ID  \
# 2049874  2675668  9d425e60-4b88-4054-9889-5e1ba50178b5
#
#                                 EP Name Flow Name       Activity Name  \
# 2049874  Courtesy Callback Telephony EP       NaN  DisconnectContact1
#
#         Activity Start Timestamp Queue Name Agent Name Termination Reason  \
# 2049874      2025-07-03 13:41:30        NaN        NaN                NaN
#
#          hour
# 2049874    13

# %%
callback_data_screenpoprows[['Contact Session ID', 'Activity Name']].groupby('Contact Session ID').count()
# Out:
#                                       Activity Name
# Contact Session ID
# 000cce29-1c76-4991-9445-bb5f9028f47d              2
# 00116654-66ea-4582-a109-aacde13a620d              1
# 001741db-98b4-409f-8646-32ed0ecf6331              1
# 0018380f-cf12-40f5-b525-af190304c42b              1
# 0019d572-7f3e-4380-bc1f-274fc63edcb6              1
# ...                                             ...
# ffeb3402-17d7-479d-8e63-df8ea36d719d              2
# ffeb379a-6940-4a06-99bd-2c1e5082c251              1
# ffeb818f-1c52-4845-817f-0b9ffe18f7c4              1
# ffebd3d4-6fc7-4922-aa45-849790c12f6a              1
# fff898b5-9df2-40f4-a421-2dac3dc04194              2
#
# [8970 rows x 1 columns]

# %%
1-145/8970
# Out:
# 0.9838350055741361

# %%
ccbconfirm = callback_screenpop_data.loc[callback_screenpop_data['Activity Name'] == 'PlayCCBConfirmation','Contact Session ID'].unique()

# %%
custdata('1a84d523-2650-46e3-840d-79fd24aff370');

# %%
no_ccbconfirm = callback_screenpop_data.loc[~callback_screenpop_data['Contact Session ID'].isin(ccbconfirm),:]
no_ccbconfirm;

# %%
df = callback_screenpop_data.copy()

# Ensure date column is datetime (if not already)
df['date'] = pd.to_datetime(df['date'])

# Get the first time the callback was *requested* (PlayCCBConfirmation)
requested = (
    df[df['Activity Name'] == 'PlayCCBConfirmation']
    .groupby('Contact Session ID')['date']
    .first()
    .rename('request_date')
)

# Get the first time the callback was *answered* (LegalServerScreenPop)
answered = (
    df[df['Activity Name'] == 'LegalServerScreenPop']
    .groupby('Contact Session ID')['date']
    .first()
    .rename('pickup_date')
)

# Merge the two series into a single DataFrame
callback_days = pd.concat([requested, answered], axis=1)

# Calculate days to pickup
callback_days['days_to_pickup'] = (callback_days['pickup_date'] - callback_days['request_date']).dt.days

# Optional: remove cases where pickup never occurred
# callback_days = callback_days.dropna(subset=['pickup_date'])

callback_days.head()
# Out:
#                                      request_date pickup_date  days_to_pickup
# Contact Session ID
# 000cce29-1c76-4991-9445-bb5f9028f47d   2024-05-29  2024-05-29             0.0
# 00116654-66ea-4582-a109-aacde13a620d   2024-07-25  2024-07-25             0.0
# 001741db-98b4-409f-8646-32ed0ecf6331   2025-07-23  2025-07-23             0.0
# 0018380f-cf12-40f5-b525-af190304c42b   2024-08-20  2024-08-20             0.0
# 0019d572-7f3e-4380-bc1f-274fc63edcb6   2025-09-17  2025-09-17             0.0

# %%
callback_days.loc[callback_days['days_to_pickup'].isna(),'days_to_pickup'] = 0

# %%
pickup_counts = callback_days['days_to_pickup'].value_counts().sort_index()

plt.figure(figsize=(6,5))
bars = plt.bar(pickup_counts.index, pickup_counts.values)

# Add data labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f"{height}", ha='center', va='bottom', fontsize=11)

# Axis labels and title
plt.xlabel('Days to Pickup', fontsize=14)
plt.ylabel('Number of calls \n(distinct Contact Session IDs)', fontsize=14)
plt.title('Distribution of Days to Callback Pickup', fontsize=16)

# Increase tick font sizes
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# %%
7467/9158
# Out:
# 0.8153526970954357

# %%
7467/8970
# Out:
# 0.8324414715719064

# %%
callback_data_retryrows['Agent Name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
callbacks_notpickedup = callback_data.loc[~callback_data['Contact Session ID'].isin(callback_data_agentrows['Contact Session ID']),:]

# %%
callbacks_notpickedup['Contact Session ID'].nunique()
# Out:
# 178

# %%
custdata(callbacks_notpickedup['Contact Session ID'].unique()[3]);

# %%
callbacks_notpickedup['Contact Session ID'].unique()[1]
# Out:
# '01fdf433-aacc-4640-a44b-71653cdc12cb'

# %%
8980/9158
# Out:
# 0.9805634417995196

# %%
callback_pickuptime = callback_data_screenpoprows[['Contact Session ID','hour']].groupby('hour').nunique().rename(columns={'Contact Session ID': 'count'})
callback_pickuptime['count'] = callback_pickuptime['count']/377
callback_pickuptime;

# %%
callback_data_request = callback_data.loc[callback_data['Activity Name'] == 'PlayCCBConfirmation',:]
callback_request = (
    callback_data_request[['Contact Session ID','hour']]
    .groupby('hour')['Contact Session ID']
    .nunique()
    .rename('count')
)

callback_request = callback_request / 377  # normalize

plt.figure(figsize=(6.5,4))
bars = plt.bar(callback_request.index, callback_request.values)

# Add data labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f"{height:.2f}",    # show two decimals
             ha='center', va='bottom', fontsize=12)

plt.xticks(callback_request.index, fontsize=12)   # ✅ Correct tick alignment
plt.xlabel('Hour of the day', fontsize=14)
plt.ylabel('Callbacks requested per weekday', fontsize=14)
plt.title('Number of callbacks requested vs hour of the day', fontsize=16)
plt.show()

# %%
callback_data_retryrows = callback_data.loc[callback_data['Activity Name'] == 'CallbackRetry',:]
callback_failed = (
    callback_data_retryrows[['Contact Session ID','hour']]
    .groupby('hour')['Contact Session ID']
    .nunique()
    .rename('count')
)

callback_failed = callback_failed / 377  # normalize

plt.figure(figsize=(16,6))
bars = plt.bar(callback_failed.index, callback_failed.values)

# Add data labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f"{height:.2f}",    # show two decimals
             ha='center', va='bottom', fontsize=12)

plt.xticks(callback_failed.index, fontsize=12)   # ✅ Correct tick alignment
plt.xlabel('Hour of the day', fontsize=14)
plt.ylabel('Failed callbacks per weekday', fontsize=14)
plt.title('Number of failed callbacks vs hour of the day', fontsize=16)
plt.show()

# %%
callback_pickuptime = (
    callback_data_screenpoprows[['Contact Session ID','hour']]
    .groupby('hour')['Contact Session ID']
    .nunique()
    .rename('count')
)

callback_pickuptime = callback_pickuptime / 377  # normalize

plt.figure(figsize=(16,6))
bars = plt.bar(callback_pickuptime.index, callback_pickuptime.values)

# Add data labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f"{height:.2f}",    # show two decimals
             ha='center', va='bottom', fontsize=12)

plt.xticks(callback_pickuptime.index, fontsize=12)   # ✅ Correct tick alignment
plt.xlabel('Hour of the day', fontsize=14)
plt.ylabel('Call pickups per weekday', fontsize=14)
plt.title('Number of call pickups vs hour of the day', fontsize=16)
plt.show()

# %%
callback_time = callback_data[['Contact Session ID','hour']].groupby('hour').nunique().rename(columns={'Contact Session ID': 'count'})
callback_time['count'] = callback_time['count']/377
callback_time;

# %%
#plt.bar(callback_time.index, callback_time['count']);
plt.figure(figsize=(16,6))
bars = plt.bar(callback_time.index, callback_time['count'])
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height,
             f"{height:.1f}",  # format to 1 decimal place
             ha='center', va='bottom')
plt.xticks(range(len(callback_time)), callback_time.index, fontsize=12)  # one tick per bar
plt.xlabel('Hour of the day', fontsize=14)
plt.ylabel('Callbacks per weekday', fontsize=14)
plt.title('Number of callbacks vs hour of the day', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Number of callbacks vs hour of the day')

# %%
callback_failed
# Out:
# hour
# 0     0.079576
# 1     0.071618
# 2     0.976127
# 3     0.100796
# 4     0.114058
# 5     2.315650
# 6     0.302387
# 7     0.267905
# 8     0.705570
# 9     0.275862
# 10    0.177719
# 11    0.119363
# 12    0.092838
# 13    0.098143
# 14    0.087533
# 15    0.092838
# 16    0.037135
# 17    0.143236
# 18    0.010610
# 19    0.007958
# 20    0.336870
# 21    0.026525
# 22    0.021220
# 23    0.620690
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure both are Series named consistently
picked = callback_pickuptime['count'].rename('picked_up')
failed = callback_failed.rename('failed')

# Align by hour
df = picked.to_frame().join(failed, how='outer').fillna(0)

hours = df.index
x = np.arange(len(hours))
width = 0.4

plt.figure(figsize=(11,3.75))
bars1 = plt.bar(x - width/2, df['picked_up'], width, label='Picked up')
bars2 = plt.bar(x + width/2, df['failed'],   width, label='Failed')

# Add value labels only when > 0
for bars in (bars1, bars2):
    for bar in bars:
        height = bar.get_height()
        if height > 0.05:   # ✅ Only label if non-zero
            plt.text(bar.get_x() + bar.get_width()/2, height,
                     f"{height:.2f}", ha='center', va='bottom', fontsize=10)

plt.xticks(x, hours, fontsize=12)
plt.xlabel('Hour of the day', fontsize=14)
plt.ylabel('Number of callbacks per weekday', fontsize=14)
plt.title('Picked Up vs Failed Callbacks by Hour of Day', fontsize=16)
plt.legend(fontsize=12);

# %%
0.08+0.07+0.98+0.1+0.11+2.32+0.3+0.27+0.14+0.34+0.62
# Out:
# 5.33

# %%
df_main.shape
# Out:
# (3328626, 10)

# %%
df_main['Contact Session ID'].nunique()
# Out:
# 248442

# %%
df_legal2_rows = df_main.loc[df_main['Activity Name'] == 'LegalMenu2',:]

# %%
df_queue = df_main[df_main['Activity Name'].str.contains('queue', case=False, na=False)]

# %%
df_queue['Contact Session ID'].nunique()
# Out:
# 62321

# %%
df_queue.loc[df_queue['Activity Name'] == 'ClosedQueueMenu','Contact Session ID'].nunique()
# Out:
# 49933

# %%
d1 = df_queue[['Contact Session ID','hour']].groupby('hour').nunique()/377

# %%
d2 = df_queue.loc[(df_queue['Activity Name'] == 'ClosedQueueMenu'),['Contact Session ID','hour']].groupby('hour').nunique()/377

# %%
d3 = pd.concat([d1, d2], axis=1)

# %%
d1_renamed = d1.add_suffix('_d1')
d2_renamed = d2.add_suffix('_d2')

d3 = pd.concat([d1_renamed, d2_renamed], axis=1)
d3['ratio'] = d3['Contact Session ID_d2']/d3['Contact Session ID_d1']
d3.rename(columns = {'Contact Session ID_d1':'Calls navigating to queue','Contact Session ID_d2':'Calls with closed queue',
                    'ratio':'Proportion of calls with close queue'}, inplace = True)

# %%
d3.head()
# Out:
#       Calls navigating to queue  Calls with closed queue  \
# hour
# 6                      0.002653                 0.002653
# 7                      0.013263                 0.013263
# 8                     32.904509                16.055703
# 9                     25.946950                20.453581
# 10                    22.114058                18.655172
#
#       Proportion of calls with close queue
# hour
# 6                                 1.000000
# 7                                 1.000000
# 8                                 0.487948
# 9                                 0.788285
# 10                                0.843589

# %%
import matplotlib.pyplot as plt
import numpy as np

d3 = d3[(d3.index>=8) & (d3.index<=16)]

# Extract data
x = np.arange(len(d3.index))          # numeric positions
col1 = d3.iloc[:, 0]
col2 = d3.iloc[:, 1]
col3 = d3.iloc[:, 2]

width = 0.35  # width of bars

fig, ax1 = plt.subplots(figsize=(12,6))

bars1 = ax1.bar(x - width/2, col1, width, label=d3.columns[0])
bars2 = ax1.bar(x + width/2, col2, width, label=d3.columns[1])

ax1.set_xlabel("Hour of the day", fontsize=16)
ax1.set_ylabel("Calls per weekday", fontsize=16)
ax1.tick_params(axis='y', labelsize=14)
ax1.set_xticks(x)
ax1.set_xticklabels(d3.index, rotation=45, fontsize=14)


# ✅ Limit x-axis to hours 8 to 16
ax1.set_xlim(d3.index.get_loc(8) - 0.5, d3.index.get_loc(16) + 0.5)

# Secondary axis for line plot
ax2 = ax1.twinx()
ax2.plot(x, col3, color='red', marker='o', linewidth=2, label=d3.columns[2])
ax2.set_ylabel("Proportion of calls with closed queue", fontsize=16)
ax2.tick_params(axis='y', labelsize=14)

ax1.legend(loc="upper left", fontsize=14)
ax2.legend(loc="upper right", fontsize=14)

#plt.title("Side-by-Side Bars and Secondary Axis Line Plot", fontsize=16)
plt.tight_layout()
plt.show()

# %%
49933/62321
# Out:
# 0.8012227018180068

# %%
49933/377
# Out:
# 132.44827586206895

# %%
62321/377
# Out:
# 165.30769230769232

# %%
df_queue['Contact Session ID'].nunique()

# %%
df_queue['Activity Name'].value_counts()
# Out:
# Activity Name
# ClosedQueueMenu                87903
# QueueMenu1                     24299
# PreQueueMessage2               11815
# IntakePreQueueMessage1          7281
# SubSeniorPreQueueMessage1_1     4933
# FamilyQueue                     1945
# ConsumerQueue                   1454
# SubSeniorOtherQueue             1189
# HousingQueue                    1059
# BenefitsQueue                    789
# SubSeniorTenantQueue             684
# SubSeniorBenefitsQueue           683
# EmploymentQueue                  514
# SubSeniorConsumerQueue           508
# SubSeniorFamilyQueue             482
# SubSeniorHomeownerQueue          453
# ADAPTQueue                       379
# SubSeniorADAPTQueue              260
# FamilySPQueue                    257
# SubSeniorPreQueueMessage1_2      174
# ImmigrationSPQueue               166
# SubSeniorEmploymentQueue         146
# ConsumerSPQueue                  119
# BenefitsSPQueue                   95
# EmploymentSPQueue                 82
# ...

# %%
df_main.loc[df_main['Activity Name'] == 'ClosedQueueMenu','Contact Session ID'].nunique()
# Out:
# 49933

# %%
49933/248442
# Out:
# 0.20098453562602137

# %%
callback_data['date'] = callback_data['Activity Start Timestamp'].dt.date

# %%
custdata('ffeb379a-6940-4a06-99bd-2c1e5082c251')
# Out:
#           index                    Contact Session ID  \
# 3327462  690239  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327463  690240  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327464  690241  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327465  690242  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327466  690246  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327467  690267  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327468  690268  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327469  690270  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327470  690279  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327471  690287  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327472  690301  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327473  690302  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327474  690340  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327475  690376  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327476  690377  ffeb379a-6940-4a06-99bd-2c1e5082c251
# 3327477  690378  ffeb379a-6940-4a06-99bd-2c1e5082c251
# ...

# %%
callback_data[['Contact Session ID', 'date']].groupby('Contact Session ID').nunique()
# Out:
#                                       date
# Contact Session ID
# 000cce29-1c76-4991-9445-bb5f9028f47d     1
# 00116654-66ea-4582-a109-aacde13a620d     1
# 001741db-98b4-409f-8646-32ed0ecf6331     1
# 0018380f-cf12-40f5-b525-af190304c42b     1
# 0019d572-7f3e-4380-bc1f-274fc63edcb6     1
# ...                                    ...
# ffeb3402-17d7-479d-8e63-df8ea36d719d     1
# ffeb379a-6940-4a06-99bd-2c1e5082c251     3
# ffeb818f-1c52-4845-817f-0b9ffe18f7c4     1
# ffebd3d4-6fc7-4922-aa45-849790c12f6a     1
# fff898b5-9df2-40f4-a421-2dac3dc04194     1
#
# [9158 rows x 1 columns]

# %%
df_main.loc[(df_main['Activity Name'] == 'LegalMenu2'),
['Contact Session ID']].nunique()
# Out:
# Contact Session ID    92696
# dtype: int64

# %%
df_main.loc[(df_main['Activity Name'] == 'LegalMenu1'),
['Contact Session ID']].nunique()
# Out:
# Contact Session ID    96173
# dtype: int64

# %%
df_main.loc[(df_main['Activity Start Timestamp'].dt.date > date(2025, 3, 15)),
['Contact Session ID']].nunique()
# Out:
# Contact Session ID    90940
# dtype: int64

# %%
df_main.loc[(df_main['Activity Start Timestamp'].dt.date > date(2025, 3, 15)) & (df_main['Activity Name'] == 'LegalMenu2'),
['Contact Session ID']].nunique()
# Out:
# Contact Session ID    35158
# dtype: int64

# %%
df_main.loc[(df_main['Activity Start Timestamp'].dt.date > date(2025, 3, 15)) & (df_main['Activity Name'] == 'FamilyMenu'),
['Contact Session ID']].nunique()
# Out:
# Contact Session ID    9742
# dtype: int64

# %%
first_call_leg = df_main.groupby('Contact Session ID').first().reset_index()

# %%
first_call_leg.head()
# Out:
#                      Contact Session ID    index                   EP Name  \
# 0  00002422-f51f-458b-82d6-cfa5a3f36fd9   401227  Main Number Telephony EP
# 1  0000a8d5-cecb-46b1-82cf-b7ce07d85b24  2084734  Main Number Telephony EP
# 2  00011655-35de-476f-9a8c-dd48ed4d914a  1721915  Main Number Telephony EP
# 3  00014a58-a6ce-4cb2-a529-d55e2c9c304d   237561  Main Number Telephony EP
# 4  00015327-f646-462f-a585-0552331eed4e  2523793  Main Number Telephony EP
#
#   Flow Name          Activity Name Activity Start Timestamp  \
# 0   LACMain  LanguageSelectionMenu      2025-03-13 12:51:21
# 1   LACMain  LanguageSelectionMenu      2025-03-17 16:53:15
# 2   LACMain  LanguageSelectionMenu      2024-11-06 14:39:01
# 3   LACMain  LanguageSelectionMenu      2025-02-28 08:33:40
# 4   LACMain  LanguageSelectionMenu      2025-06-03 07:43:56
#
#                          Queue Name Agent Name Termination Reason  hour
# 0  Staff Directory English Transfer  CBT Agent               None    12
# ...

# %%
first_call_leg_may24_aug35 = first_call_leg.loc[(first_call_leg['Activity Start Timestamp'].dt.date >= date(2024,5,1)) \
& (first_call_leg['Activity Start Timestamp'].dt.date <= date(2025,8,31)),:]

# %%
counts = first_call_leg_may24_aug35['hour'].value_counts().sort_index()
counts.plot(kind = 'bar')
plt.xlabel("Hour of Day")
plt.ylabel("Number of distinct Contact Session IDs");
plt.title("Plot based on CAR Data");

# %%
first_call_leg_may24_aug35.shape
# Out:
# (222284, 9)

# %%
df_main.shape[0]/240592
# Out:
# 13.393159373545256

# %%
df_main['Activity Start Timestamp'].max()
# Out:
# Timestamp('2025-09-13 22:52:02')

# %%
df_main['Activity Start Timestamp'].min()
# Out:
# Timestamp('2024-04-07 00:32:12')

# %%
df_main.hour.value_counts().sort_index()
# Out:
# hour
# 0       2928
# 1       1980
# 2       3005
# 3       1835
# 4       3633
# 5       8674
# 6      12712
# 7      55952
# 8     448484
# 9     410588
# 10    390286
# 11    373629
# 12    332668
# 13    319602
# 14    307205
# 15    280207
# 16    173231
# 17     37838
# 18     19564
# 19     13203
# 20     10131
# 21      6119
# 22      4100
# 23      4713
# Name: count, dtype: int64

# %%
df_main.columns
# Out:
# Index(['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name',
#        'Activity Start Timestamp', 'Queue Name', 'Agent Name',
#        'Termination Reason', 'hour'],
#       dtype='object')

# %%
df_main['Termination Reason'].value_counts().sum()
# Out:
# 100373

# %%
df_main['Termination Reason'].value_counts()
# Out:
# Termination Reason
# Customer Left                       79194
# Agent Left                          12154
# System disconnected the contact      4541
# NO_ANSWER_FROM_AGENT                 1007
# RONA_TIMER_EXPIRED                    776
# Queue Timeout                         670
# NO_ANSWER_FROM_CUSTOMER               573
# RONA Timer Expired                    460
# AGENT_ENDS                            257
# CUSTOMER_UNAVAILABLE                  223
# System Error                          162
# CUSTOMER_BUSY                         112
# USER_UNAVAILABLE                       63
# NO_ANSWER_USER                         46
# USER_BUSY                              30
# MEDIA_MANAGER_INTERNAL_ERROR           30
# AGENT_UNAVAILABLE                      19
# MAX_CALLBACK_RETRY_LIMIT_REACHED       19
# AGENT_BUSY                             19
# USER_DECLINED                           9
# Participant Invite timer expired        4
# CONTACT_CALLBACK_IN_PROGRESS            2
# ...

# %%
df_main['Activity Start Timestamp'].dt.date >= date(2025,3,16)
# Out:
# 401227     False
# 401228     False
# 401229     False
# 401230     False
# 401236     False
#            ...
# 1458735    False
# 1458736    False
# 1458737    False
# 1458738    False
# 1458739    False
# Name: Activity Start Timestamp, Length: 3222287, dtype: bool

# %%
df_main_new_data = df_main.loc[df_main['Activity Start Timestamp'].dt.date >= date(2025,3,16),:]

# %%
df_main_new_data['Contact Session ID'].nunique()
# Out:
# 83090

# %%
df_main_new_data.groupby('Contact Session ID')['Termination Reason'].nunique().sort_values()
# Out:
# Contact Session ID
# 0000a8d5-cecb-46b1-82cf-b7ce07d85b24    1
# a9990d27-e860-4088-b9a5-634c1280c46a    1
# a998d1e0-53b9-4c37-a8ba-0a5bda68157a    1
# a9985de8-3344-4ddb-9f01-8d008cf7bb7f    1
# a997d2cf-e569-4274-a252-cae890d77790    1
#                                        ..
# 21c39a18-e5fe-421e-b2e6-39428f481226    5
# 37e46c47-1a4f-4406-a177-f412ab4fe43b    5
# fa4b154d-1215-4019-8a11-538f6ac994c0    5
# a17a92b3-abd0-49dc-a0e2-ddc2e86fe511    6
# 0b581d44-53d2-4276-87dd-7afcfd4f5248    6
# Name: Termination Reason, Length: 83090, dtype: int64

# %%
df_main.loc[df_main['Contact Session ID'] == '0b581d44-53d2-4276-87dd-7afcfd4f5248',:].to_csv('temp_export.csv')

# %%
df_main.loc[df_main['Contact Session ID'] == '000a3bc0-45e5-49e5-8bda-3f2141b2bc38',:].to_csv('agent_left2.csv')

# %%
df_main.loc[df_main['Contact Session ID'] == '0008d9f3-db30-4cd9-baf1-71baffba9643',:].to_csv('temp_export.csv')

# %%
df_main.loc[df_main['Contact Session ID'] == '0008d9f3-db30-4cd9-baf1-71baffba9643',:]
# Out:
#                            Contact Session ID                   EP Name  \
# 2167449  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167450  0008d9f3-db30-4cd9-baf1-71baffba9643                       NaN
# 2167451  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167452  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167459  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167472  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167476  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167477  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167478  0008d9f3-db30-4cd9-baf1-71baffba9643                       NaN
# 2167479  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167480  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# 2167481  0008d9f3-db30-4cd9-baf1-71baffba9643  Main Number Telephony EP
# ...

# %%
agent_left_rows = df_main.loc[df_main['Termination Reason'] == 'Agent Left',:]

# %%
cust_left_rows = df_main.loc[df_main['Termination Reason'] == 'Customer Left',:]
cust_left_rows.to_csv('temp_export.csv')

# %%
cust_left_journeys = df_main.loc[df_main['Contact Session ID'].isin(cust_left_rows['Contact Session ID']),:]
cust_left_journeys.to_csv('temp_export.csv')

# %%
agent_left_rows
# Out:
#                            Contact Session ID                         EP Name  \
# 2694227  000a3bc0-45e5-49e5-8bda-3f2141b2bc38               Intake Outdial EP
# 2226960  000d510a-4f5d-4ca4-9c05-9db918d11fe3         Legal Menu Telephony EP
# 2584043  000f7898-6a8d-4604-a9e9-d5e6aeb17670        Main Number Telephony EP
# 2210885  0016a2d9-87a1-43a8-880f-5ae4d1ae726d         Legal Menu Telephony EP
# 2793862  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# ...                                       ...                             ...
# 3207738  ffef5316-dfc9-4d55-ba63-65461530a4ed         Legal Menu Telephony EP
# 3068862  ffefc12e-471f-4841-b7ca-e7641323d3b8        Main Number Telephony EP
# 3150014  fff24560-c573-46b8-ad2b-d82fe73399eb        Main Number Telephony EP
# 3153057  fff5ca16-2e1f-4c70-9361-a4ab4bcab275  Closed Queue Menu Telephony EP
# 2861289  fff898b5-9df2-40f4-a421-2dac3dc04194  Courtesy Callback Telephony EP
#
# ...

# %%
df_main.loc[df_main['Contact Session ID'] == '0029a1f0-56ed-47a8-b35f-6460a709c544',:].to_csv('temp_export.csv')

# %%
df_main.loc[df_main['Contact Session ID'] == '0029a1f0-56ed-47a8-b35f-6460a709c544',:]

# %%
sys_discon_rows = df_main.loc[df_main['Termination Reason'] == 'System disconnected the contact',:]
sys_discon_rows
# Out:
#                            Contact Session ID  \
# 2585014  00189604-35e3-42ed-8187-e46fdf1f0bb4
# 2278015  001d4ba0-a384-4c4b-ae8a-bdda3e1119dc
# 2405521  0029a1f0-56ed-47a8-b35f-6460a709c544
# 2800105  00306e56-e09a-4c55-946d-1964145899cf
# 2800106  00306e56-e09a-4c55-946d-1964145899cf
# ...                                       ...
# 2140432  ffa9598d-640c-44e1-b470-ca7d6fa97f1e
# 2246157  ffac6974-cf1f-4f3d-9ad5-8a9c3a53a484
# 2246158  ffac6974-cf1f-4f3d-9ad5-8a9c3a53a484
# 2166291  ffcee247-5ceb-49dc-aed6-ccc99aa08975
# 2736114  ffdd1b59-9c77-496c-8321-dec23cc06bb2
#
#                                           EP Name Flow Name Activity Name  \
# 2585014   Closed Hours-Holidays Menu Telephony EP       NaN           NaN
# 2278015            Closed Queue Menu Telephony EP       NaN           NaN
# 2405521  Pre-Legal Menu Seniors Menu Telephony EP       NaN           NaN
# 2800105   Closed Hours-Holidays Menu Telephony EP       NaN           NaN
# ...

# %%
df_main.loc[df_main['Contact Session ID'] == '0002606f-910e-43e5-aac5-d93fefc1cead',:]
# Out:
#                            Contact Session ID                   EP Name  \
# 2535854  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535855  0002606f-910e-43e5-aac5-d93fefc1cead                       NaN
# 2535856  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535857  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535865  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535880  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535881  0002606f-910e-43e5-aac5-d93fefc1cead                       NaN
# 2535882  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535883  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2535884  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
# 2536083  0002606f-910e-43e5-aac5-d93fefc1cead  Main Number Telephony EP
#
#         Flow Name          Activity Name Activity Start Timestamp  \
# ...

# %%
cust_left_rows['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    26269
# Closed Queue Menu Telephony EP              16365
# Courtesy Callback Telephony EP               9172
# Legal Menu Telephony EP                      5738
# Other Legal Menu Telephony EP                4534
# Closed Hours-Holidays Menu Telephony EP      4366
# Farmworker Main Number Telephony EP          4118
# Legal Housing Menu Telephony EP              1955
# Legal Family Menu Telephony EP               1507
# Pre-Legal Menu Seniors Menu Telephony EP     1166
# All LAC Queues Telephony EP                  1148
# Legal HIV Menu Telephony EP                   527
# Intake Outdial EP                             501
# Legal Immigration Menu Telephony EP           267
# Legal Benefits Menu Telephony EP              152
# Legal Employment Menu Telephony EP             78
# Name: count, dtype: int64

# %%
sys_discon_rows['EP Name'].value_counts()
# Out:
# EP Name
# Closed Hours-Holidays Menu Telephony EP     3370
# Closed Queue Menu Telephony EP               862
# Pre-Legal Menu Seniors Menu Telephony EP     309
# Name: count, dtype: int64

# %%
df_main['Activity Start Timestamp'].max()
# Out:
# Timestamp('2025-09-13 22:52:02')

# %%
cust_left_rows['Activity Start Timestamp'].max()
# Out:
# Timestamp('2025-09-13 22:52:02')

# %%
agent_left_rows['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                   5591
# Courtesy Callback Telephony EP             2443
# Intake Outdial EP                          2299
# Legal Menu Telephony EP                     761
# Closed Queue Menu Telephony EP              360
# Closed Hours-Holidays Menu Telephony EP     278
# All LAC Queues Telephony EP                 160
# Other Legal Menu Telephony EP               120
# Legal Family Menu Telephony EP              101
# Legal Housing Menu Telephony EP              37
# Legal Benefits Menu Telephony EP              2
# Legal HIV Menu Telephony EP                   1
# Legal Immigration Menu Telephony EP           1
# Name: count, dtype: int64

# %%
cust_left_rows['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    26269
# Closed Queue Menu Telephony EP              16365
# Courtesy Callback Telephony EP               9172
# Legal Menu Telephony EP                      5738
# Other Legal Menu Telephony EP                4534
# Closed Hours-Holidays Menu Telephony EP      4366
# Farmworker Main Number Telephony EP          4118
# Legal Housing Menu Telephony EP              1955
# Legal Family Menu Telephony EP               1507
# Pre-Legal Menu Seniors Menu Telephony EP     1166
# All LAC Queues Telephony EP                  1148
# Legal HIV Menu Telephony EP                   527
# Intake Outdial EP                             501
# Legal Immigration Menu Telephony EP           267
# Legal Benefits Menu Telephony EP              152
# Legal Employment Menu Telephony EP             78
# Name: count, dtype: int64

# %%
call_duration = df_main.groupby('Contact Session ID')['Activity Start Timestamp'].agg(start = "first", end = "last").reset_index()
call_duration['duration'] = call_duration['end'] - call_duration['start']

# %%
call_duration.sort_values(by = 'duration', ascending= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 call_duration.sort_values(by = 'duration', ascending= False)
#
# NameError: name 'call_duration' is not defined

# %%
df_main.shape
# Out:
# (3328626, 9)

# %%
df_main.to_csv('C:/Users/akl0407/OneDrive - Northwestern University/Back up/2025-26/Fall 2025/LegalAid/Processed_data/car_appended.csv', index=False)

# %%
pwd
# Out:
# 'C:\\Users\\akl0407\\Desktop\\Academia\\GitHub\\STAT390_LegalAid_Fall2025\\Internal work of Teams\\Krish'

# %%
import numpy as np

# %%
df_main.loc[~df_main['Termination Reason'].isna(),'Activity Start Timestamp'].min()
# Out:
# Timestamp('2025-03-16 00:40:12')

# %%
df_main.loc[~df_main['Termination Reason'].isna(),'Activity Start Timestamp'].max()
# Out:
# Timestamp('2025-09-13 22:52:02')

# %%
df_tr = df_main.loc[df_main['Activity Start Timestamp'].dt.date > date(2025,3,15),:]
df_tr_last = df_tr.groupby('Contact Session ID').tail(1)

# %%
df_tr_last.shape
# Out:
# (83090, 9)

# %%
df_tr_last['Termination Reason'].isna().sum()
# Out:
# 7386

# %%
df_main_check = pd.read_csv('C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Processed_data\\car_appended.csv',
                     index_col = None)

# %%
callback_rows = df_main.loc[df_main['EP Name'] == 'Courtesy Callback Telephony EP',:]

# %%
callback_data = df_main.loc[df_main['Contact Session ID'].isin(callback_rows['Contact Session ID']),:]

# %%
pwd
# Out:
# 'C:\\Users\\akl0407\\Desktop\\Academia\\GitHub\\STAT390_LegalAid_Fall2025\\Internal work of Teams\\Krish'

# %%
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
callback_data.to_csv(adhoc_data_path + 'callback_data.csv')

# %%
adhoc_data_path + 'callback_data.csv'
# Out:
# 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\callback_data.csv'

# %%
df_main_check
# Out:
#                            Contact Session ID                   EP Name  \
# 0        00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP
# 1        00002422-f51f-458b-82d6-cfa5a3f36fd9                       NaN
# 2        00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP
# 3        00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP
# 4        00002422-f51f-458b-82d6-cfa5a3f36fd9  Main Number Telephony EP
# ...                                       ...                       ...
# 3328621  ffffa50d-6d02-4281-9141-087a806a8343                       NaN
# 3328622  ffffa50d-6d02-4281-9141-087a806a8343  Main Number Telephony EP
# 3328623  ffffa50d-6d02-4281-9141-087a806a8343  Main Number Telephony EP
# 3328624  ffffa50d-6d02-4281-9141-087a806a8343  Main Number Telephony EP
# 3328625  ffffa50d-6d02-4281-9141-087a806a8343  Main Number Telephony EP
#
#         Flow Name          Activity Name Activity Start Timestamp Queue Name  \
# ...

# %%
val = "PlayMOH300s"
s = df_main_check["Activity Name"]

has_two_in_a_row = (s.eq(val) & s.shift(-1).eq(val)).any()
print(has_two_in_a_row)  # True if any consecutive pair exists
# Out:
# False

# %%
pair_start_idx = df_main_check.index[s.eq(val) & s.shift(-1).eq(val)]
#print(list(pair_start_idx))

# %%
pairs = []
mask = s.eq(val) & s.shift(-1).eq(val)
for i in df_main.index[mask]:
    pairs.append(df_main.loc[i:i+1])  # assumes a default RangeIndex

# %%
df_main.loc[df_main['Contact Session ID'] == '46f6ce5b-54e4-491b-8a6d-80fbbc6905e0',:]
# Out:
#        Unnamed: 0                    Contact Session ID  \
# 54760       54760  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54761       54761  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54762       54762  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54763       54763  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54779       54779  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54795       54795  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54796       54796  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54806       54806  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54825       54825  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54835       54835  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54854       54854  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54855       54855  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54856       54856  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54890       54890  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54891       54891  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54892       54892  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# ...

# %%
df_main.loc[54985,:]
# Out:
# Unnamed: 0                                                     54985
# Contact Session ID              16124295-2745-4966-99b3-c5d3be129345
# EP Name                     Pre-Legal Menu Seniors Menu Telephony EP
# Flow Name                                                        NaN
# Activity Name                                            SeniorsMenu
# Activity Start Timestamp                         2025-01-21 08:08:13
# Queue Name                                                       NaN
# Agent Name                                                       NaN
# Termination Reason                                               NaN
# hour                                                               8
# Name: 54985, dtype: object

# %%
df_main.loc[54901:54903,:]
# Out:
#        Unnamed: 0                    Contact Session ID  \
# 54901       54901  46f6ce5b-54e4-491b-8a6d-80fbbc6905e0
# 54902       54902  0ddb25ac-3424-4ec4-8163-992f1a7d6516
# 54903       54903  1f7cd0c5-0c37-4494-933f-63cf356a49e4
#
#                               EP Name Flow Name Activity Name  \
# 54901     All LAC Queues Telephony EP       NaN   PlayMOH300s
# 54902     All LAC Queues Telephony EP       NaN   PlayMOH300s
# 54903  Courtesy Callback Telephony EP       NaN           CCB
#
#       Activity Start Timestamp Queue Name Agent Name Termination Reason  hour
# 54901      2025-01-21 08:04:25        NaN        NaN                NaN     8
# 54902      2025-01-21 08:04:30        NaN        NaN                NaN     8
# 54903      2025-01-21 08:04:35        NaN        NaN                NaN     8

# %%
custleft_rows = df_main.loc[df_main['Termination Reason'] == 'Customer Left',:]
custleft_cases = df_main.loc[df_main['Contact Session ID'].isin(custleft_rows['Contact Session ID']),:]

# %%
pwd
# Out:
# 'C:\\Users\\akl0407\\Desktop\\Academia\\GitHub\\STAT390_LegalAid_Fall2025\\Internal work of Teams\\Krish'

# %%
custleft_cases.to_csv(adhoc_data_path + 'custleft_cases.csv')

# %%
df_main_check.loc[df_main_check['Contact Session ID'] == '0019d572-7f3e-4380-bc1f-274fc63edcb6',:]
# Out:
#                         Contact Session ID  \
# 1177  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1178  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1179  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1180  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1181  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1182  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1183  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1184  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1185  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1186  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1187  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1188  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1189  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1190  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1191  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1192  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1193  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1194  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1195  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1196  0019d572-7f3e-4380-bc1f-274fc63edcb6
# 1197  0019d572-7f3e-4380-bc1f-274fc63edcb6
# ...

# %%
df_main_check.loc[df_main_check['Contact Session ID'] == '001853bf-3199-412f-8c71-e6c29ba451ce',:]
# Out:
#                         Contact Session ID            EP Name       Flow Name  \
# 1090  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1091  001853bf-3199-412f-8c71-e6c29ba451ce                NaN  Intake_Outdial
# 1092  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1093  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1094  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1095  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1096  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1097  001853bf-3199-412f-8c71-e6c29ba451ce  Intake Outdial EP             NaN
# 1098  001853bf-3199-412f-8c71-e6c29ba451ce                NaN             NaN
# 1099  001853bf-3199-412f-8c71-e6c29ba451ce                NaN             NaN
#
#           Activity Name Activity Start Timestamp            Queue Name  \
# ...

# %%
df_main.loc[df_main['Contact Session ID'] == '001a3748-8d50-4550-8461-33547983deb0',:]
# Out:
#                       Contact Session ID  \
# 0   001a3748-8d50-4550-8461-33547983deb0
# 1   001a3748-8d50-4550-8461-33547983deb0
# 2   001a3748-8d50-4550-8461-33547983deb0
# 3   001a3748-8d50-4550-8461-33547983deb0
# 4   001a3748-8d50-4550-8461-33547983deb0
# 5   001a3748-8d50-4550-8461-33547983deb0
# 6   001a3748-8d50-4550-8461-33547983deb0
# 7   001a3748-8d50-4550-8461-33547983deb0
# 8   001a3748-8d50-4550-8461-33547983deb0
# 9   001a3748-8d50-4550-8461-33547983deb0
# 10  001a3748-8d50-4550-8461-33547983deb0
# 11  001a3748-8d50-4550-8461-33547983deb0
# 12  001a3748-8d50-4550-8461-33547983deb0
# 13  001a3748-8d50-4550-8461-33547983deb0
# 14  001a3748-8d50-4550-8461-33547983deb0
# 15  001a3748-8d50-4550-8461-33547983deb0
# 16  001a3748-8d50-4550-8461-33547983deb0
#
#                                      EP Name                Flow Name  \
# 0                   Main Number Telephony EP                      NaN
# 1                                        NaN                  LACMain
# ...

# %%
df_main_check.loc[1000:1012,:]
# Out:
#                         Contact Session ID                         EP Name  \
# 1000  001741db-98b4-409f-8646-32ed0ecf6331     All LAC Queues Telephony EP
# 1001  001741db-98b4-409f-8646-32ed0ecf6331                             NaN
# 1002  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1003  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1004  001741db-98b4-409f-8646-32ed0ecf6331                             NaN
# 1005  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1006  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1007  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1008  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1009  001741db-98b4-409f-8646-32ed0ecf6331  Courtesy Callback Telephony EP
# 1010  001741db-98b4-409f-8646-32ed0ecf6331                             NaN
# ...

# %%
df_main_check.loc[df_main_check['Contact Session ID'] == '001741db-98b4-409f-8646-32ed0ecf6331',:]
# Out:
#                         Contact Session ID  \
# 979   001741db-98b4-409f-8646-32ed0ecf6331
# 980   001741db-98b4-409f-8646-32ed0ecf6331
# 981   001741db-98b4-409f-8646-32ed0ecf6331
# 982   001741db-98b4-409f-8646-32ed0ecf6331
# 983   001741db-98b4-409f-8646-32ed0ecf6331
# 984   001741db-98b4-409f-8646-32ed0ecf6331
# 985   001741db-98b4-409f-8646-32ed0ecf6331
# 986   001741db-98b4-409f-8646-32ed0ecf6331
# 987   001741db-98b4-409f-8646-32ed0ecf6331
# 988   001741db-98b4-409f-8646-32ed0ecf6331
# 989   001741db-98b4-409f-8646-32ed0ecf6331
# 990   001741db-98b4-409f-8646-32ed0ecf6331
# 991   001741db-98b4-409f-8646-32ed0ecf6331
# 992   001741db-98b4-409f-8646-32ed0ecf6331
# 993   001741db-98b4-409f-8646-32ed0ecf6331
# 994   001741db-98b4-409f-8646-32ed0ecf6331
# 995   001741db-98b4-409f-8646-32ed0ecf6331
# 996   001741db-98b4-409f-8646-32ed0ecf6331
# 997   001741db-98b4-409f-8646-32ed0ecf6331
# 998   001741db-98b4-409f-8646-32ed0ecf6331
# 999   001741db-98b4-409f-8646-32ed0ecf6331
# ...

# %%
df = df_main.copy()

# %%
target_activities = ["PreQueueMessage1", "PreQueueMessage2", "QueueMenu1", "PlayMOH300s"]

# Assuming your DataFrame is named df and has at least these columns:
# "Call ID" (or whatever uniquely identifies a call) and "Activity Name"

# Step 1: Find all call IDs that hit one of the target activities
call_ids_to_keep = df.loc[df["Activity Name"].isin(target_activities), "Contact Session ID"].unique()

# Step 2: Filter to keep *all* rows of those calls
filtered_df = df[df["Contact Session ID"].isin(call_ids_to_keep)].copy().reset_index(drop = True)

# %%
filtered_df.shape
# Out:
# (422362, 9)

# %%
call_ids_to_keep.shape
# Out:
# (11815,)

# %%
df_main.groupby('Contact Session ID')['Queue Name'].nunique().max()
# Out:
# 1

# %%
# Uses Queue Name
# create queue_name_df similar to menus_df but using 'Queue Name' instead of 'Activity Name'
results = []


for contact_id in filtered_df['Contact Session ID'].unique():
    temp = filtered_df.loc[filtered_df['Contact Session ID'] == contact_id].copy()
    temp = temp.sort_values('Activity Start Timestamp').reset_index(drop=True)
    
    for i in range(1, len(temp)):
        current_row = temp.iloc[i]
        prev_row = temp.iloc[i - 1]
        queue_name = current_row['Queue Name']
        if queue_name not in [np.nan, '']:
            
            results.append({'Contact Session ID': contact_id, 'Queue Name': queue_name})
            break
queue_name_df = pd.DataFrame(results)

# %%
queue_name_df
# Out:
#                          Contact Session ID          Queue Name
# 0      000cce29-1c76-4991-9445-bb5f9028f47d  SubSenior Consumer
# 1      00116654-66ea-4582-a109-aacde13a620d            Consumer
# 2      001741db-98b4-409f-8646-32ed0ecf6331            Benefits
# 3      0018380f-cf12-40f5-b525-af190304c42b  SubSenior Benefits
# 4      0019d572-7f3e-4380-bc1f-274fc63edcb6    SubSenior Tenant
# ...                                     ...                 ...
# 11810  ffeb379a-6940-4a06-99bd-2c1e5082c251            Consumer
# 11811  ffeb818f-1c52-4845-817f-0b9ffe18f7c4             Housing
# 11812  ffeba08a-2298-40a2-8864-ecb0a414e7e8  SubSenior Benefits
# 11813  ffebd3d4-6fc7-4922-aa45-849790c12f6a  SubSenior Benefits
# 11814  fff898b5-9df2-40f4-a421-2dac3dc04194            Consumer
#
# [11815 rows x 2 columns]

# %%
queue_name_df['Contact Session ID'].nunique()
# Out:
# 11815

# %%
filtered_df['Activity Start Timestamp'] = pd.to_datetime(filtered_df['Activity Start Timestamp'])

# %%
queue_name_df['Queue Name'].value_counts()[lambda x: x > 500].index
# Out:
# Index(['Family', 'Consumer', 'SubSenior Other', 'Housing', 'Benefits',
#        'SubSenior Tenant', 'SubSenior Benefits', 'Employment',
#        'SubSenior Consumer'],
#       dtype='object', name='Queue Name')

# %%
queue_name_df['Queue Name'].value_counts()
# Out:
# Queue Name
# Family                      1936
# Consumer                    1446
# SubSenior Other             1187
# Housing                     1029
# Benefits                     785
# SubSenior Tenant             683
# SubSenior Benefits           682
# Employment                   510
# SubSenior Consumer           507
# SubSenior Family             481
# SubSenior Homeowner          452
# ADAPT                        377
# SubSenior ADAPT              260
# Family SP                    257
# Immigration SP               165
# SubSenior Employment         146
# Consumer SP                  119
# Benefits SP                   95
# Education                     82
# Employment SP                 81
# SubSenior Other SP            63
# Immigration                   55
# SubSenior Consumer SP         46
# SubSenior Benefits SP         45
# Other SubSeniors              33
# ADAPT SP                      29
# SubSenior Family SP           29
# SubSenior Homeowner SP        23
# ...

# %%
df['Contact Session ID'].nunique()
# Out:
# 248442

# %%
# For only large queue sizes find the time spent in each queue
large_queue_df = queue_name_df[queue_name_df['Queue Name'].isin(
    queue_name_df['Queue Name'].value_counts()[lambda x: x > 500].index
)]

# %%
# go through the filtered df and find the time spent in each queue for each contact session id
time_results = []

for contact_id in large_queue_df['Contact Session ID'].unique():
    temp = filtered_df.loc[filtered_df['Contact Session ID'] == contact_id].copy()
    temp = temp.sort_values('Activity Start Timestamp').reset_index(drop=True)
    
    for i in range(1, len(temp)):
        current_row = temp.iloc[i]
        prev_row = temp.iloc[i - 1]
        queue_name = current_row['Queue Name']
        if queue_name in large_queue_df['Queue Name'].values:
            # Calculate occurences of PlayMOH300s and QueueMenu1 in queue
            # Start if PreQueue in Activity Name
            # Count occurences of PlayMOH300s and QueueMenu1 in Activity Name
            # In order to find the time in queue, we take the time from the occurence of "PreQueue" that occurs after if we find the queue name and take it until the last occurence of "PlayMOH300s" or "QueueMenu1"
            time_in_queue = 0
            prequeue_indices = temp.index[temp['Activity Name'].str.contains('PreQueue', case=False, na=False)].tolist()
            end_queue_indices = temp.index[temp['Activity Name'].str.contains('PlayMOH300s|QueueMenu1', case=False, na=False)].tolist()
            if prequeue_indices and end_queue_indices:
                
                time_in_queue = temp.loc[end_queue_indices[-1], 'Activity Start Timestamp'] - temp.loc[prequeue_indices[0], 'Activity Start Timestamp']
                time_in_queue = time_in_queue.total_seconds()

            moh_count = temp['Activity Name'].str.contains('PlayMOH300s', case=False, na=False).sum()
            menu_count = temp['Activity Name'].str.contains('QueueMenu1', case=False, na=False).sum()
            total_count = moh_count + menu_count
            time_results.append({'Contact Session ID': contact_id, 'Queue Name': queue_name, 'Time in Queue (s)': time_in_queue, 'Time Count': total_count})
            break

# %%
prequeue_indices
# Out:
# [26, 32]

# %%
end_queue_indices
# Out:
# [33, 34, 35, 36, 37, 38]

# %%
end_queue_indices[-1]
# Out:
# 38

# %%
time_results_df = pd.DataFrame(time_results)
time_results_df.head()
# Out:
#                      Contact Session ID          Queue Name  \
# 0  000cce29-1c76-4991-9445-bb5f9028f47d  SubSenior Consumer
# 1  00116654-66ea-4582-a109-aacde13a620d            Consumer
# 2  001741db-98b4-409f-8646-32ed0ecf6331            Benefits
# 3  0018380f-cf12-40f5-b525-af190304c42b  SubSenior Benefits
# 4  0019d572-7f3e-4380-bc1f-274fc63edcb6    SubSenior Tenant
#
#    Time in Queue (s)  Time Count
# 0              371.0           2
# 1              370.0           2
# 2              371.0           2
# 3              699.0           4
# 4                0.0           0

# %%
740/60
# Out:
# 12.333333333333334

# %%
6*60
# Out:
# 360

# %%
13:16:01 - 13:22:12

# %%
df_main_check.loc[df_main_check['Contact Session ID'] == '000cce29-1c76-4991-9445-bb5f9028f47d',:]
# Out:
#                        Contact Session ID  \
# 535  000cce29-1c76-4991-9445-bb5f9028f47d
# 536  000cce29-1c76-4991-9445-bb5f9028f47d
# 537  000cce29-1c76-4991-9445-bb5f9028f47d
# 538  000cce29-1c76-4991-9445-bb5f9028f47d
# 539  000cce29-1c76-4991-9445-bb5f9028f47d
# 540  000cce29-1c76-4991-9445-bb5f9028f47d
# 541  000cce29-1c76-4991-9445-bb5f9028f47d
# 542  000cce29-1c76-4991-9445-bb5f9028f47d
# 543  000cce29-1c76-4991-9445-bb5f9028f47d
# 544  000cce29-1c76-4991-9445-bb5f9028f47d
# 545  000cce29-1c76-4991-9445-bb5f9028f47d
# 546  000cce29-1c76-4991-9445-bb5f9028f47d
# 547  000cce29-1c76-4991-9445-bb5f9028f47d
# 548  000cce29-1c76-4991-9445-bb5f9028f47d
# 549  000cce29-1c76-4991-9445-bb5f9028f47d
# 550  000cce29-1c76-4991-9445-bb5f9028f47d
# 551  000cce29-1c76-4991-9445-bb5f9028f47d
# 552  000cce29-1c76-4991-9445-bb5f9028f47d
# 553  000cce29-1c76-4991-9445-bb5f9028f47d
# 554  000cce29-1c76-4991-9445-bb5f9028f47d
# 555  000cce29-1c76-4991-9445-bb5f9028f47d
# ...

# %%
medium_queue_df = queue_name_df[(queue_name_df['Queue Name'].isin(
    queue_name_df['Queue Name'].value_counts()[lambda x: x > 200].index
)) & (queue_name_df['Queue Name'].isin(
    queue_name_df['Queue Name'].value_counts()[lambda x: x <= 500].index
))]

# go through the filtered df and find the time spent in each queue for each contact session id
time_results_med = []

for contact_id in medium_queue_df['Contact Session ID'].unique():
    temp = filtered_df.loc[filtered_df['Contact Session ID'] == contact_id].copy()
    temp = temp.sort_values('Activity Start Timestamp').reset_index(drop=True)
    
    for i in range(1, len(temp)):
        current_row = temp.iloc[i]
        prev_row = temp.iloc[i - 1]
        queue_name = current_row['Queue Name']
        if queue_name in medium_queue_df['Queue Name'].values:
            # Calculate occurences of PlayMOH300s and QueueMenu1 in queue
            # Start if PreQueue in Activity Name
            # Count occurences of PlayMOH300s and QueueMenu1 in Activity Name
            # In order to find the time in queue, we take the time from the occurence of "PreQueue" that occurs after if we find the queue name and take it until the last occurence of "PlayMOH300s" or "QueueMenu1"
            time_in_queue = 0
            prequeue_indices = temp.index[temp['Activity Name'].str.contains('PreQueue', case=False, na=False)].tolist()
            end_queue_indices = temp.index[temp['Activity Name'].str.contains('PlayMOH300s|QueueMenu1', case=False, na=False)].tolist()
            if prequeue_indices and end_queue_indices:
                
                time_in_queue = temp.loc[end_queue_indices[-1], 'Activity Start Timestamp'] - temp.loc[prequeue_indices[0], 'Activity Start Timestamp']
                time_in_queue = time_in_queue.total_seconds()

            moh_count = temp['Activity Name'].str.contains('PlayMOH300s', case=False, na=False).sum()
            menu_count = temp['Activity Name'].str.contains('QueueMenu1', case=False, na=False).sum()
            total_count = moh_count + menu_count
            time_results_med.append({'Contact Session ID': contact_id, 'Queue Name': queue_name, 'Time in Queue (s)': time_in_queue, 'Time Count': total_count})
            break

# %%
time_results_med_df = pd.DataFrame(time_results_med)
time_results_med_df.head()
# Out:
#                      Contact Session ID           Queue Name  \
# 0  001dc39d-2a9a-4f46-9a60-5890b1764c05            Family SP
# 1  003cd0a2-0f62-45e4-9a0a-d9631ed3b2c0     SubSenior Family
# 2  0056a873-dcbc-48a7-b9c6-4b42193f1bad                ADAPT
# 3  00f09507-0f91-47c6-bb8d-d643d985f5e5                ADAPT
# 4  01751e3f-73a2-4e36-a8d0-1972195a5f3e  SubSenior Homeowner
#
#    Time in Queue (s)  Time Count
# 0             2741.0          17
# 1               94.0           2
# 2              473.0           4
# 3               70.0           1
# 4             1231.0           8

# %%
for queue in time_results_df['Queue Name'].unique():
    print(queue, time_results_df.loc[time_results_df['Queue Name'] == queue, 'Time in Queue (s)'].median())
# Out:
# SubSenior Consumer 370.0
# Consumer 370.0
# Benefits 370.0
# SubSenior Benefits 370.0
# SubSenior Tenant 370.0
# Housing 370.0
# Employment 370.0
# Family 371.0
# SubSenior Other 370.0

# %%
for queue in time_results_med_df['Queue Name'].unique():
    print(queue, time_results_med_df.loc[time_results_med_df['Queue Name'] == queue, 'Time in Queue (s)'].median())
# Out:
# Family SP 390.0
# SubSenior Family 370.0
# ADAPT 370.0
# SubSenior Homeowner 370.0
# SubSenior ADAPT 370.0

# %%
for queue in time_results_df['Queue Name'].unique():
    print(queue, time_results_df.loc[time_results_df['Queue Name'] == queue, 'Time in Queue (s)'].mean())
# Out:
# SubSenior Consumer 438.3984220907298
# Consumer 812.9591977869986
# Benefits 888.9656050955414
# SubSenior Benefits 430.1231671554252
# SubSenior Tenant 512.4553440702782
# Housing 934.9727891156463
# Employment 774.8470588235294
# Family 942.1936983471074
# SubSenior Other 419.03875315922494

# %%
for queue in time_results_df['Queue Name'].unique():
    print(queue, time_results_df.loc[time_results_df['Queue Name'] == queue, 'Time in Queue (s)'].mean())

# %%
df_main['Activity Name'].value_counts()[0:15]
# Out:
# Activity Name
# LanguageSelectionMenu            267656
# MainMenu                         186138
# SeniorsMenu                      125748
# LegalMenu2                       110890
# LegalMenu1                        96331
# ClosedQueueMenu                   87903
# OtherLegalMenu                    31956
# SeniorsConfirmationMenu           30337
# SuburbsOrCityMenu                 28301
# StaffDirectoryEnglishTransfer     28035
# FamilyMenu                        27415
# PlayMOH300s                       25847
# ClinicVoicemailTransfer           25721
# QueueMenu1                        24299
# ClosedMenu                        23629
# Name: count, dtype: int64

# %%
df_main.loc[df_main['Activity Name'] == 'FamilyMenu','Contact Session ID'].nunique()
# Out:
# 24794

# %%
df_main['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    1239571
# Legal Menu Telephony EP                      245849
# Pre-Legal Menu Seniors Menu Telephony EP     232691
# Closed Queue Menu Telephony EP               174367
# All LAC Queues Telephony EP                  131109
# Courtesy Callback Telephony EP                88625
# Closed Hours-Holidays Menu Telephony EP       79720
# Other Legal Menu Telephony EP                 72372
# Legal Housing Menu Telephony EP               68447
# Intake Outdial EP                             65456
# Legal Family Menu Telephony EP                54772
# Farmworker Main Number Telephony EP           52968
# Legal Benefits Menu Telephony EP               9253
# Legal HIV Menu Telephony EP                    8463
# Legal Immigration Menu Telephony EP            7861
# Legal Employment Menu Telephony EP             5694
# Name: count, dtype: int64

# %%
familymenu_rows = df_main.loc[df_main['EP Name'] == 'Legal Family Menu Telephony EP',:]

# %%
familymenu_data = df_main.loc[df_main['Contact Session ID'].isin(familymenu_rows['Contact Session ID']),:]
