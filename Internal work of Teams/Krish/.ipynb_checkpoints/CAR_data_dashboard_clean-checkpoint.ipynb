# %% [markdown]
# Author: Krish

# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import date

# %%
data_path = "C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Spring 2025\\STAT390\\LegalAid\\Data\\CAR_-_EP_Flow_Activity_Queue__Agent_Names\\"
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))
df_main = pd.DataFrame(columns=['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name', 'Activity Start Timestamp', 
                                'Queue Name', 'Agent Name', 'Termination Reason'])
i=0
for f in files:
    i = i + 1
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=2, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=2, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
print("Data files read = ",i)
# Out:
# Data files read =  53

# %%
df_main["Activity Start Timestamp"] = df_main["Activity Start Timestamp"].apply(
    lambda x: datetime.strptime(x, "%Y/%m/%d %I:%M:%S %p"))

# %%
def custdata(id):
    return df_main.loc[df_main['Contact Session ID'] == id,:]

# %%
df_main.shape
# Out:
# (3328626, 8)

# %%
df_main.dtypes
# Out:
# Contact Session ID                  object
# EP Name                             object
# Flow Name                           object
# Activity Name                       object
# Activity Start Timestamp    datetime64[ns]
# Queue Name                          object
# Agent Name                          object
# Termination Reason                  object
# dtype: object

# %%
df_main["hour"] = df_main["Activity Start Timestamp"].dt.hour

# %%
df_main.sort_values(by = ['Contact Session ID', 'Activity Start Timestamp'], inplace=True)

# %%
df_main.reset_index(inplace = True, drop = True)

# %%
df_main['Date'] = df_main['Activity Start Timestamp'].dt.date

# %%
# Next activity and the one after that (per session), given rows are already sorted
def dash_data(ep_name, activity_name):
    familymenu_rows = df_main.loc[df_main['EP Name'] == ep_name,:]
    familymenu_data = df_main.loc[df_main['Contact Session ID'].isin(familymenu_rows['Contact Session ID']),:]
    familymenu_activity = familymenu_data[['Contact Session ID', 'Date', 'hour', 'Activity Name']]
    familymenu_activity.dropna(subset=["Activity Name"], inplace=True)
    
    df2 = familymenu_activity.copy()
    
    g = df2.groupby("Contact Session ID")
    df2["Second Activity"]      = g["Activity Name"].shift(-1)
    df2["Third Activity"]  = g["Activity Name"].shift(-2)
    
    out = (
        df2.loc[df2["Activity Name"].eq(activity_name),
                ["Contact Session ID", 'Date', 'hour', "Activity Name", "Second Activity", "Third Activity"]]
           .rename(columns={"Activity Name": "Current Activity"})
           .reset_index(drop=True)
    )
    # select the 3rd and 4th columns by position (0-based index → 2 and 3)
    cols = out.columns[3: 6]
    
    # do substring replacements, preserving NA values
    for c in cols:
        out[c] = (
            out[c].astype("string")  # use pandas StringDtype to keep <NA>
                  .str.replace("FamilySP", "Family", regex=False)
                  .str.replace("EducationSP", "Education", regex=False)
                  .str.replace("ConsumerSP", "Consumer", regex=False)
                  .str.replace("BenefitsSP", "Consumer", regex=False)
                  .str.replace("EmploymentSP", "Employment", regex=False)
                  .str.replace("ImmigrationSP", "Immigration", regex=False)
                  .str.replace("GetLoggedInBenefitsAgents", "Benefits Queue", regex=False)
                  .str.replace("VeteransBenefitsVoicemailTransfer", "Veterans Benefits Voicemail Transfer", regex=False)
                  .str.replace("GetLoggedInEducationAgents", "Education Queue", regex=False)
                  .str.replace("GetLoggedInFamilyAgents", "Family Queue", regex=False)
                  .str.replace("GetLoggedInConsumerAgents", "Consumer Queue", regex=False)
                  .str.replace("GetLoggedInImmigrationAgents", "Immigration Queue", regex=False)
                  .str.replace("GetLoggedInEmploymentAgents", "Employment Queue", regex=False)
                  .str.replace("WorkersCompMenu", "Workers Compensation", regex=False)
                  .str.replace("ImmigrationOtherMenu", "Immigration Other Menu", regex=False)
                  .str.replace("ImmigrationMenu", "Immigration Menu", regex=False)
                  .str.replace("TraffickingVoicemailTransfer", "Trafficking Voicemail Transfer", regex=False)
                  .str.replace("EmploymentMenu", "Employment Menu", regex=False)
                  .str.replace("HolidayPrompt", "Holiday Prompt", regex=False)
                  .str.replace("DivorceOrParentingMenu", "Divorce / Parenting", regex=False)
                  .str.replace("ClosedQueueMenu", "Closed Queue", regex=False)
                  .str.replace("ChildSupportMenu", "Child Support", regex=False)
                  .str.replace("SimpleDivorceMenu", "Simple Divorce", regex=False)
                  .str.replace("TransferToSafeHaven", "Safe Haven", regex=False)
        )
    return out

# %%
out_family = dash_data('Legal Family Menu Telephony EP', 'FamilyMenu')
out_housing = dash_data('Legal Housing Menu Telephony EP', 'HousingMenu')
out_benefits = dash_data('Legal Benefits Menu Telephony EP', 'BenefitsMenu')
out_hiv = dash_data('Legal HIV Menu Telephony EP', 'HIVMenu')
out_imm = dash_data('Legal Immigration Menu Telephony EP', 'ImmigrationMenu')
out_emp = dash_data('Legal Employment Menu Telephony EP', 'EmploymentMenu')

out_all = pd.concat([out_family, out_housing, out_benefits, out_hiv, out_imm, out_emp]).reset_index(drop = True)
out_all.loc[out_all['Second Activity'].isna(),'Second Activity'] = 'Abandoned / End of call'
out_all.loc[out_all['Third Activity'].isna(),'Third Activity'] = 'Abandoned / End of call'
out_all.to_csv(adhoc_data_path + 'family_dash.csv', index = False)

# %%
df_main['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    1239571
# Legal Menu Telephony EP                      245849
# Pre-Legal Menu Seniors Menu Telephony EP     232691
# Closed Queue Menu Telephony EP               174367
# All LAC Queues Telephony EP                  131109
# Courtesy Callback Telephony EP                88625
# Closed Hours-Holidays Menu Telephony EP       79720
# Other Legal Menu Telephony EP                 72372
# Legal Housing Menu Telephony EP               68447
# Intake Outdial EP                             65456
# Legal Family Menu Telephony EP                54772
# Farmworker Main Number Telephony EP           52968
# Legal Benefits Menu Telephony EP               9253
# Legal HIV Menu Telephony EP                    8463
# Legal Immigration Menu Telephony EP            7861
# Legal Employment Menu Telephony EP             5694
# Name: count, dtype: int64

# %%
df_main.loc[df_main['EP Name'] == 'Legal Employment Menu Telephony EP',:]
# Out:
#                            Contact Session ID  \
# 851      001332c7-04e3-4652-a307-3fdc97104809
# 1224     001a3748-8d50-4550-8461-33547983deb0
# 2650     00316ade-1790-4e3f-990d-68ebea618455
# 2710     0032db35-bb86-4e63-8c76-2c598b6f35cd
# 3877     004a28d2-e2bd-4392-88d3-89642586feea
# ...                                       ...
# 3325605  ffc8f728-d545-4637-ab2b-e5f44d5b55a4
# 3325901  ffcf4637-1dae-4a92-843c-824bccd3b69a
# 3326258  ffd6a116-21f5-431a-a93c-7a19fbbf1dae
# 3328038  fff415cd-6d25-4358-86a6-78ea558269f5
# 3328039  fff415cd-6d25-4358-86a6-78ea558269f5
#
#                                     EP Name Flow Name   Activity Name  \
# 851      Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 1224     Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 2650     Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 2710     Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 3877     Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# ...                                     ...       ...             ...
# 3325605  Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 3325901  Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 3326258  Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 3328038  Legal Employment Menu Telephony EP       NaN  EmploymentMenu
# 3328039  Legal Employment Menu Telephony EP       NaN             NaN
#
#         Activity Start Timestamp Queue Name Agent Name Termination Reason  \
# 851          2024-05-10 15:49:48        NaN        NaN                NaN
# 1224         2025-01-14 12:43:09        NaN        NaN                NaN
# 2650         2025-06-12 12:54:41        NaN        NaN                NaN
# 2710         2025-04-10 08:09:32        NaN        NaN                NaN
# 3877         2025-01-29 16:02:19        NaN        NaN                NaN
# ...                          ...        ...        ...                ...
# 3325605      2025-08-18 08:16:43        NaN        NaN                NaN
# 3325901      2025-08-22 12:27:25        NaN        NaN                NaN
# 3326258      2024-04-08 10:12:55        NaN        NaN                NaN
# 3328038      2025-03-18 13:10:41        NaN        NaN                NaN
# 3328039      2025-03-18 13:10:59        NaN        NaN      Customer Left
#
#          hour        Date
# 851        15  2024-05-10
# 1224       12  2025-01-14
# 2650       12  2025-06-12
# 2710        8  2025-04-10
# 3877       16  2025-01-29
# ...       ...         ...
# 3325605     8  2025-08-18
# 3325901    12  2025-08-22
# 3326258    10  2024-04-08
# 3328038    13  2025-03-18
# 3328039    13  2025-03-18
#
# [5694 rows x 10 columns]

# %%
out_all.loc[(out_all['Current Activity'] == 'Employment Menu') & (out_all['Second Activity'] == 'Holiday Prompt'),:]
# Out:
#                          Contact Session ID        Date Current Activity  \
# 67807  148686a2-a039-496d-ad37-a1357fb22dc3  2025-06-19  Employment Menu
#
#       Second Activity Third Activity
# 67807  Holiday Prompt     ClosedMenu

# %%
custdata('148686a2-a039-496d-ad37-a1357fb22dc3')
# Out:
#                           Contact Session ID  \
# 268342  148686a2-a039-496d-ad37-a1357fb22dc3
# 268343  148686a2-a039-496d-ad37-a1357fb22dc3
# 268344  148686a2-a039-496d-ad37-a1357fb22dc3
# 268345  148686a2-a039-496d-ad37-a1357fb22dc3
# 268346  148686a2-a039-496d-ad37-a1357fb22dc3
# 268347  148686a2-a039-496d-ad37-a1357fb22dc3
# 268348  148686a2-a039-496d-ad37-a1357fb22dc3
# 268349  148686a2-a039-496d-ad37-a1357fb22dc3
# 268350  148686a2-a039-496d-ad37-a1357fb22dc3
# 268351  148686a2-a039-496d-ad37-a1357fb22dc3
# 268352  148686a2-a039-496d-ad37-a1357fb22dc3
# 268353  148686a2-a039-496d-ad37-a1357fb22dc3
# 268354  148686a2-a039-496d-ad37-a1357fb22dc3
# 268355  148686a2-a039-496d-ad37-a1357fb22dc3
# 268356  148686a2-a039-496d-ad37-a1357fb22dc3
# 268357  148686a2-a039-496d-ad37-a1357fb22dc3
#
#                                          EP Name                Flow Name  \
# 268342                  Main Number Telephony EP                      NaN
# 268343                                       NaN                  LACMain
# 268344                                       NaN  PreLegalMenuSeniorsMenu
# 268345  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 268346  Pre-Legal Menu Seniors Menu Telephony EP  PreLegalMenuSeniorsMenu
# 268347                                       NaN                LegalMenu
# 268348                   Legal Menu Telephony EP                      NaN
# 268349                   Legal Menu Telephony EP                      NaN
# 268350                                       NaN      LegalEmploymentMenu
# 268351        Legal Employment Menu Telephony EP                      NaN
# 268352                                       NaN                   Queues
# 268353                                       NaN  ClosedHoursHolidaysMenu
# 268354   Closed Hours-Holidays Menu Telephony EP                      NaN
# 268355   Closed Hours-Holidays Menu Telephony EP                      NaN
# 268356   Closed Hours-Holidays Menu Telephony EP                      NaN
# 268357   Closed Hours-Holidays Menu Telephony EP                      NaN
#
#              Activity Name Activity Start Timestamp Queue Name Agent Name  \
# 268342                 NaN      2025-06-19 08:58:01        NaN        NaN
# 268343                 NaN      2025-06-19 08:58:01        NaN        NaN
# 268344                 NaN      2025-06-19 08:58:01        NaN        NaN
# 268345         SeniorsMenu      2025-06-19 08:58:01        NaN        NaN
# 268346                 NaN      2025-06-19 08:58:01        NaN        NaN
# 268347                 NaN      2025-06-19 08:58:06        NaN        NaN
# 268348          LegalMenu1      2025-06-19 08:58:06        NaN        NaN
# 268349          LegalMenu2      2025-06-19 08:58:43        NaN        NaN
# 268350                 NaN      2025-06-19 08:58:55        NaN        NaN
# 268351      EmploymentMenu      2025-06-19 08:58:55        NaN        NaN
# 268352                 NaN      2025-06-19 08:59:02        NaN        NaN
# 268353                 NaN      2025-06-19 08:59:02        NaN        NaN
# 268354       HolidayPrompt      2025-06-19 08:59:02        NaN        NaN
# 268355          ClosedMenu      2025-06-19 08:59:07        NaN        NaN
# 268356  DisconnectContact1      2025-06-19 08:59:28        NaN        NaN
# 268357                 NaN      2025-06-19 08:59:28        NaN        NaN
#
#        Termination Reason  hour        Date
# 268342                NaN     8  2025-06-19
# 268343                NaN     8  2025-06-19
# 268344                NaN     8  2025-06-19
# 268345                NaN     8  2025-06-19
# 268346                NaN     8  2025-06-19
# 268347                NaN     8  2025-06-19
# 268348                NaN     8  2025-06-19
# 268349                NaN     8  2025-06-19
# 268350                NaN     8  2025-06-19
# 268351                NaN     8  2025-06-19
# 268352                NaN     8  2025-06-19
# 268353                NaN     8  2025-06-19
# 268354                NaN     8  2025-06-19
# 268355                NaN     8  2025-06-19
# 268356                NaN     8  2025-06-19
# 268357      Customer Left     8  2025-06-19

# %%
out_all.loc[(out_all['Current Activity'] == 'Employment Menu'), 'Second Activity'].value_counts()
# Out:
# Second Activity
# Closed Queue               3591
# Employment Queue            757
# Employment Menu             378
# Workers Compensation        194
# Abandoned / End of call     183
# LegalMenu2                  167
# Holiday Prompt                1
# ClosedMenu                    1
# Name: count, dtype: Int64

# %%
out_all['Current Activity'].value_counts()
# Out:
# Current Activity
# FamilyMenu         27415
# HousingMenu        23145
# BenefitsMenu        8030
# ImmigrationMenu     5299
# Employment Menu     5272
# HIVMenu             3512
# Name: count, dtype: Int64

# %%
custdata('0035b5f4-1e5f-4359-b982-ddbf7df6f1dd')
# Out:
#                         Contact Session ID  \
# 2925  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2926  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2927  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2928  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2929  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2930  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2931  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2932  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2933  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2934  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2935  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2936  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2937  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2938  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2939  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2940  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2941  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
# 2942  0035b5f4-1e5f-4359-b982-ddbf7df6f1dd
#
#                                        EP Name                Flow Name  \
# 2925                  Main Number Telephony EP                      NaN
# 2926                                       NaN                  LACMain
# 2927                  Main Number Telephony EP                      NaN
# 2928                  Main Number Telephony EP                  LACMain
# 2929                  Main Number Telephony EP                      NaN
# 2930                                       NaN  PreLegalMenuSeniorsMenu
# 2931  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 2932  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 2933                                       NaN                LegalMenu
# 2934                   Legal Menu Telephony EP                      NaN
# 2935                   Legal Menu Telephony EP                      NaN
# 2936                                       NaN             LegalHIVMenu
# 2937               Legal HIV Menu Telephony EP                      NaN
# 2938               Legal HIV Menu Telephony EP                      NaN
# 2939               Legal HIV Menu Telephony EP                      NaN
# 2940               Legal HIV Menu Telephony EP                      NaN
# 2941               Legal HIV Menu Telephony EP                      NaN
# 2942               Legal HIV Menu Telephony EP                      NaN
#
#                 Activity Name Activity Start Timestamp  \
# 2925                      NaN      2024-07-05 11:16:16
# 2926                      NaN      2024-07-05 11:16:16
# 2927    LanguageSelectionMenu      2024-07-05 11:16:16
# 2928                      NaN      2024-07-05 11:16:16
# 2929                 MainMenu      2024-07-05 11:16:27
# 2930                      NaN      2024-07-05 11:16:50
# 2931              SeniorsMenu      2024-07-05 11:16:50
# 2932  SeniorsConfirmationMenu      2024-07-05 11:16:55
# 2933                      NaN      2024-07-05 11:17:11
# 2934               LegalMenu1      2024-07-05 11:17:11
# 2935               LegalMenu2      2024-07-05 11:17:47
# 2936                      NaN      2024-07-05 11:18:19
# 2937                  HIVMenu      2024-07-05 11:18:19
# 2938     HIVVoicemailTransfer      2024-07-05 11:18:51
# 2939                      NaN      2024-07-05 11:18:51
# 2940                      NaN      2024-07-05 11:18:52
# 2941                      NaN      2024-07-05 11:19:10
# 2942                      NaN      2024-07-05 11:20:29
#
#                   Queue Name Agent Name Termination Reason  hour        Date
# 2925                     NaN        NaN                NaN    11  2024-07-05
# 2926                     NaN        NaN                NaN    11  2024-07-05
# 2927                     NaN        NaN                NaN    11  2024-07-05
# 2928                     NaN        NaN                NaN    11  2024-07-05
# 2929                     NaN        NaN                NaN    11  2024-07-05
# 2930                     NaN        NaN                NaN    11  2024-07-05
# 2931                     NaN        NaN                NaN    11  2024-07-05
# 2932                     NaN        NaN                NaN    11  2024-07-05
# 2933                     NaN        NaN                NaN    11  2024-07-05
# 2934                     NaN        NaN                NaN    11  2024-07-05
# 2935                     NaN        NaN                NaN    11  2024-07-05
# 2936                     NaN        NaN                NaN    11  2024-07-05
# 2937                     NaN        NaN                NaN    11  2024-07-05
# 2938                     NaN        NaN                NaN    11  2024-07-05
# 2939                     NaN        NaN                NaN    11  2024-07-05
# 2940  HIV Voicemail Transfer  CBT Agent                NaN    11  2024-07-05
# 2941  HIV Voicemail Transfer  CBT Agent                NaN    11  2024-07-05
# 2942  HIV Voicemail Transfer  CBT Agent                NaN    11  2024-07-05

# %%
((out_all['Second Activity'] == 'Divorce / Parenting') & \
                                               (out_all['Third Activity'].isna())).sum()
# Out:
# 25

# %%
df_main.loc[df_main['Contact Session ID'].isin(out_all.loc[(out_all['Second Activity'] == 'Divorce / Parenting') & \
                                               (out_all['Third Activity'].isna()),
                                'Contact Session ID']),:].to_csv(adhoc_data_path+'chck2.csv')

# %%
out_all.loc[(out_all['Current Activity'] == 'FamilyMenu') & (out_all['Second Activity'].isna()),'Contact Session ID'].nunique()/387
# Out:
# 1.4031007751937985

# %%
out_all.loc[out_all['Contact Session ID'] == '178f6e5f-6c48-4e4c-bf50-e64eceb6b309',:]
# Out:
#                         Contact Session ID        Date Current Activity  \
# 2554  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2555  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2556  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2557  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2558  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2559  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
# 2560  178f6e5f-6c48-4e4c-bf50-e64eceb6b309  2025-09-11       FamilyMenu
#
#           Second Activity Third Activity
# 2554           LegalMenu2     FamilyMenu
# 2555           LegalMenu2     FamilyMenu
# 2556           LegalMenu2     FamilyMenu
# 2557           LegalMenu2     FamilyMenu
# 2558           LegalMenu2     FamilyMenu
# 2559           LegalMenu2     LegalMenu2
# 2560  Divorce / Parenting           <NA>

# %%
out_all['Contact Session ID'].nunique()
# Out:
# 42843

# %%
(out_all.groupby('Contact Session ID')['Contact Session ID'].count()>1).sum()
# Out:
# 5624

# %%
out_all.loc[out_all['Second Activity'] == 'Divorce / Parenting','Contact Session ID'].nunique()/387
# Out:
# 29.91731266149871

# %%
out_all['Second Activity'].value_counts()
# Out:
# Second Activity
# PreTenantMenu          14811
# Closed Queue           12690
# Divorce / Parenting    12330
# LegalMenu2              6298
# In Family Queue         1701
# In Consumer Queue        802
# Safe Haven               412
# In Education Queue       129
# ClosedMenu                 7
# Name: count, dtype: Int64

# %%
out_all['Current Activity'].isna().sum()
# Out:
# 0

# %%
out_all['Second Activity'].isna().sum()
# Out:
# 1380

# %%
out_all['Current Activity'].value_counts()
# Out:
# Current Activity
# FamilyMenu     27415
# HousingMenu    23145
# Name: count, dtype: Int64

# %%
out_all.loc[out_all['Current Activity'] == 'FamilyMenu','Contact Session ID'].nunique()/387
# Out:
# 64.0671834625323

# %%
out_all.loc[out_all['Current Activity'] == 'HousingMenu','Contact Session ID'].nunique()/387
# Out:
# 47.979328165374675

# %%
df_main['EP Name'].value_counts()
# Out:
# EP Name
# Main Number Telephony EP                    1239571
# Legal Menu Telephony EP                      245849
# Pre-Legal Menu Seniors Menu Telephony EP     232691
# Closed Queue Menu Telephony EP               174367
# All LAC Queues Telephony EP                  131109
# Courtesy Callback Telephony EP                88625
# Closed Hours-Holidays Menu Telephony EP       79720
# Other Legal Menu Telephony EP                 72372
# Legal Housing Menu Telephony EP               68447
# Intake Outdial EP                             65456
# Legal Family Menu Telephony EP                54772
# Farmworker Main Number Telephony EP           52968
# Legal Benefits Menu Telephony EP               9253
# Legal HIV Menu Telephony EP                    8463
# Legal Immigration Menu Telephony EP            7861
# Legal Employment Menu Telephony EP             5694
# Name: count, dtype: int64
