# %% [markdown]
# Author: Krish

# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import date

# %%
data_path = "C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Spring 2025\\STAT390\\LegalAid\\Data\\CAR_-_EP_Flow_Activity_Queue__Agent_Names\\"
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))
df_main = pd.DataFrame(columns=['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name', 'Activity Start Timestamp', 
                                'Queue Name', 'Agent Name', 'Termination Reason'])
df_main
# Out:
# Empty DataFrame
# Columns: [Contact Session ID, EP Name, Flow Name, Activity Name, Activity Start Timestamp, Queue Name, Agent Name, Termination Reason]
# Index: []

# %%
i=0
for f in files:
    i = i + 1
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=2, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=2, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df.shape)
# Out:
# 1 CAR - EP, Flow, Activity, Queue, & Agent Names (01-12-25 - 01-18-25) (52010, 7)
# 2 CAR - EP, Flow, Activity, Queue, & Agent Names (01-19-25 - 02-01-25) (95495, 7)
# 3 CAR - EP, Flow, Activity, Queue, & Agent Names (02-02-25 - 02-15-25) (90056, 7)
# 4 CAR - EP, Flow, Activity, Queue, & Agent Names (02-16-25 - 03-01-25) (88186, 7)
# 5 CAR - EP, Flow, Activity, Queue, & Agent Names (03-02-25 - 03-15-25) (86377, 7)
# 6 CAR - EP, Flow, Activity, Queue, & Agent Names (04-07-24 - 04-20-24) (88766, 7)
# 7 CAR - EP, Flow, Activity, Queue, & Agent Names (04-21-24 - 05-04-24) (89643, 7)
# 8 CAR - EP, Flow, Activity, Queue, & Agent Names (05-05-24 - 05-18-24) (82575, 7)
# 9 CAR - EP, Flow, Activity, Queue, & Agent Names (05-19-24 - 06-01-24) (71103, 7)
# 10 CAR - EP, Flow, Activity, Queue, & Agent Names (06-02-24 - 06-15-24) (84354, 7)
# 11 CAR - EP, Flow, Activity, Queue, & Agent Names (06-16-24 - 06-29-24) (82124, 7)
# 12 CAR - EP, Flow, Activity, Queue, & Agent Names (06-30-24 - 07-13-24) (79752, 7)
# 13 CAR - EP, Flow, Activity, Queue, & Agent Names (07-14-24 - 07-27-24) (85110, 7)
# 14 CAR - EP, Flow, Activity, Queue, & Agent Names (07-28-24 - 08-10-24) (84627, 7)
# 15 CAR - EP, Flow, Activity, Queue, & Agent Names (08-11-24 - 08-24-24) (91622, 7)
# 16 CAR - EP, Flow, Activity, Queue, & Agent Names (08-24-24 - 09-07-24) (90040, 7)
# 17 CAR - EP, Flow, Activity, Queue, & Agent Names (09-08-24 - 09-21-24) (96581, 7)
# 18 CAR - EP, Flow, Activity, Queue, & Agent Names (09-22-24 - 10-05-24) (89446, 7)
# 19 CAR - EP, Flow, Activity, Queue, & Agent Names (10-06-24 - 10-19-24) (81700, 7)
# 20 CAR - EP, Flow, Activity, Queue, & Agent Names (10-20-24 - 11-02-24) (88430, 7)
# 21 CAR - EP, Flow, Activity, Queue, & Agent Names (11-03-24 - 11-16-24) (81614, 7)
# 22 CAR - EP, Flow, Activity, Queue, & Agent Names (11-17-24 - 11-30-24) (66216, 7)
# 23 CAR - EP, Flow, Activity, Queue, & Agent Names (12-01-24 - 12-14-24) (92220, 7)
# 24 CAR - EP, Flow, Activity, Queue, & Agent Names (12-15-24 - 12-28-24) (62143, 7)
# 25 CAR - EP, Flow, Activity, Queue, & Agent Names (12-29-24 - 01-11-25) (75356, 7)
# 26 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-16 to 3-22-25 (45326, 8)
# 27 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-30 to 4-5-25 (45072, 8)
# 28 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-13 to 4-19-25 (41088, 8)
# 29 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-20 to 4-26-25 (46686, 8)
# 30 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-27 to 5-3-25 (44169, 8)
# 31 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-6 to 4-12-25 (46630, 8)
# 32 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-11 to 5-17-25 (43268, 8)
# 33 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-18 to 5-24-25 (45104, 8)
# 34 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-25 to 5-31-25 (36851, 8)
# 35 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-4 to 5-10-25 (43955, 8)
# 36 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-1 to 6-7-25 (44523, 8)
# 37 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-15 to 6-21-25 (37234, 8)
# 38 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-22 to 6-28-25 (45394, 8)
# 39 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-29 to 7-5-25 (38300, 8)
# 40 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-8 to 6-14-25 (46728, 8)
# 41 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-13 to 7-19-25 (45706, 8)
# 42 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-20 to 7-26-25 (45328, 8)
# 43 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-28 ro 8-2-25 (46237, 8)
# 44 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-6 to 7-12-25 (48707, 8)
# 45 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-10 to 8-16-25 (44095, 8)
# 46 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-17 to 8-23-25 (47062, 8)
# 47 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-24 to 8-30-25 (45113, 8)
# 48 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-3 to 8-9-25 (44706, 8)
# 49 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-31 to 9-6-25 (36177, 8)
# 50 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-14 to 9-20-25 (45958, 8)
# 51 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-21 to 9-30-25 (60381, 8)
# 52 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-7 to 9-13-25 (45304, 8)
# 53 CAR - EP, Flow, Activity, Queue, &amp; Agent Names3-23 to 3-29-25 (47978, 8)

# %%
df_main["Activity Start Timestamp"] = df_main["Activity Start Timestamp"].apply(
    lambda x: datetime.strptime(x, "%Y/%m/%d %I:%M:%S %p"))
df_main["hour"] = df_main["Activity Start Timestamp"].dt.hour
df_main.sort_values(by = ['Contact Session ID', 'Activity Start Timestamp'], inplace=True)
df_main.reset_index(inplace = True, drop = True)

# %%
def custdata(id):
    return df_main.loc[df_main['Contact Session ID'] == id,:]
def act_rows(act):
    return df_main.loc[df_main['Activity Name'] == act,:]
def act_data(act):
    get_act_rows = act_rows(act)
    return df_main.loc[df_main['Contact Session ID'].isin(get_act_rows['Contact Session ID']),:]
def data_rows(act, data):
    return data.loc[data['Activity Name'] == act,:]
def col_data(col, val):
    get_col_rows = df_main.loc[df_main[col] == val,:]
    return df_main.loc[df_main['Contact Session ID'].isin(get_col_rows['Contact Session ID']),:]
def col_rows(col, val):
    return df_main.loc[df_main[col] == val,:]
def calls_for_activity(act_name):
    return df_main.loc[df_main['Activity Name'] == act_name,'Contact Session ID'].nunique()
def tagging(data):     
    ids_already_present = data.loc[data['Contact Session ID'].isin(all_data['Contact Session ID']),'Contact Session ID'].nunique()
    print("IDs already present in the previously tagged data = ", ids_already_present)
    data = data.loc[~data['Contact Session ID'].isin(all_data['Contact Session ID']),:]
    print("IDs added = ", data['Contact Session ID'].nunique())    
    print("% IDs added = ", round(100*data['Contact Session ID'].nunique()/248422),"%")
    print("IDs per weekday = ", round(data['Contact Session ID'].nunique()/370))
    appended_data = pd.concat([all_data, data])
    print("IDs in tagged data = ", appended_data['Contact Session ID'].nunique())
    print("% data tagged = ", round(100*appended_data['Contact Session ID'].nunique()/248422),"%")
    return appended_data

# %%
df_main_copy = df_main.copy()
df_main_copy = df_main_copy.loc[~df_main['Activity Name'].isna(),:]

# %% [markdown]
# #### Main-menu only

# %%
num_EPs = df_main.groupby('Contact Session ID')['EP Name'].nunique()
one_ep_data = df_main.loc[df_main['Contact Session ID'].isin(num_EPs[num_EPs == 1].index),:]
main_menu_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Main Number Telephony EP',:]
main_menu_data = df_main.loc[df_main['Contact Session ID'].isin(main_menu_rows['Contact Session ID']),:]

num_acts = df_main.groupby('Contact Session ID')['Activity Name'].nunique()
no_acts_rem = df_main.loc[(df_main['Contact Session ID'].isin(num_acts[(num_acts == 0)].index)) & \
(df_main['EP Name'] == 'Pre-Legal Menu Seniors Menu Telephony EP'),:]
no_acts_rem_data = df_main.loc[df_main['Contact Session ID'].isin(no_acts_rem['Contact Session ID']),:]

main_menu_data = pd.concat([main_menu_data, no_acts_rem_data])
main_menu_data['caller_type'] = 'Main menu only'
print("% data = ", round(100*98352/248422),"%")
print("calls per day = ", round(98352/370))
print("calls per day = ",main_menu_data['Contact Session ID'].nunique())
# Out:
# % data =  40 %
# calls per day =  266
# calls per day =  98357

# %% [markdown]
# ## closed hours

# %%
closed_hours_data = col_data('EP Name', 'Closed Hours-Holidays Menu Telephony EP')
closed_hours_data['caller_type'] = 'Closed hours callers'
print(closed_hours_data['Contact Session ID'].nunique())

ids1 = set(main_menu_data["Contact Session ID"])
ids2 = set(closed_hours_data["Contact Session ID"])
common_12 = ids1 & ids2
if len(common_12) == 0:
    print("No overlap with the previously tagged data")

all_data = pd.concat([main_menu_data,closed_hours_data])
print("% data = ", round(100*closed_hours_data['Contact Session ID'].nunique()/248422),"%")
print("calls per day = ", round(closed_hours_data['Contact Session ID'].nunique()/370))
all_data['Contact Session ID'].nunique()
# Out:
# 21861
# No overlap with the previously tagged data
# % data =  9 %
# calls per day =  59
# 120218

# %% [markdown]
# ### Farmworker data
# calls already tagged as during closed hours excluded
# Removing farmworker data from analysis due to high abandonment rate

# %%
farm_data = act_data('FarmworkerMainMenu')
farmworker_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Farmworker Main Number Telephony EP',:]
farmworker_data = df_main.loc[df_main['Contact Session ID'].isin(farmworker_rows['Contact Session ID']),:]
more_farm_data = farmworker_data.loc[~farmworker_data['Contact Session ID'].isin(farm_data['Contact Session ID']),:]
farm_data = pd.concat([farm_data, more_farm_data])
farm_data['caller_type'] = 'Farmworker'
all_data = tagging(farm_data)
# Out:
# IDs already present in the previously tagged data =  90
# IDs added =  10310
# % IDs added =  4 %
# IDs per weekday =  28
# IDs in tagged data =  130528
# % data tagged =  53 %

# %% [markdown]
# ### Non-seniors legal menu
# Calls that reach LegalMenu2, but never reach SuburbsOrCityMenu

# %%
legmen2_data = act_data('LegalMenu1')
leg_senior_data_rows = data_rows('SuburbsOrCityMenu',legmen2_data)
#Non-seniors never reach the suburbs or city menu
leg_non_senior_data = legmen2_data.loc[~legmen2_data['Contact Session ID'].isin(leg_senior_data_rows['Contact Session ID']),:]
leg_non_senior_data['caller_type'] = 'Non-senior legal issue'
all_data = tagging(leg_non_senior_data)
# Out:
# IDs already present in the previously tagged data =  581
# IDs added =  79085
# % IDs added =  32 %
# IDs per weekday =  214
# IDs in tagged data =  209613
# % data tagged =  84 %

# %% [markdown]
# ## Seniors
# ### Suburban seniors
# Calls that reach SuburbanSeniorsMenu menu

# %%
suburban_seniors_data = act_data('SuburbanSeniorsMenu')
suburban_seniors_data['caller_type'] = 'Suburban senior'
all_data = tagging(suburban_seniors_data)
# Out:
# IDs already present in the previously tagged data =  14
# IDs added =  8305
# % IDs added =  3 %
# IDs per weekday =  22
# IDs in tagged data =  217918
# % data tagged =  88 %

# %% [markdown]
# ### City Seniors

# %%
city_seniors = act_data('SeniorsADAPTMenu')
city_seniors['caller_type'] = 'Chicago senior'
all_data = tagging(city_seniors)
# Out:
# IDs already present in the previously tagged data =  55
# IDs added =  17975
# % IDs added =  7 %
# IDs per weekday =  49
# IDs in tagged data =  235893
# % data tagged =  95 %

# %% [markdown]
# ### Non cook county seniors

# %%
noncook_seniors = act_data('SeniorNotCookCoMenu')
noncook_seniors['caller_type'] = 'Non-Cook County Senior'
all_data = tagging(noncook_seniors)
# Out:
# IDs already present in the previously tagged data =  10
# IDs added =  1302
# % IDs added =  1 %
# IDs per weekday =  4
# IDs in tagged data =  237195
# % data tagged =  95 %

# %% [markdown]
# ### Unclassified seniors

# %%
#unclassified_seniors = act_data('SuburbsOrCityMenu')
#unclassified_seniors['caller_type'] = 'Unclassified seniors'
#all_data = tagging(unclassified_seniors)

# %% [markdown]
# All these seniors abandoned call before making a choice

# %% [markdown]
# ## Intake outdial EP

# %%
intake_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Intake Outdial EP',:]
intake_outdial_data = df_main.loc[df_main['Contact Session ID'].isin(intake_rows['Contact Session ID']),:]
intake_outdial_data['caller_type'] = 'Intake Outdial'
all_data = tagging(intake_outdial_data)
# Out:
# IDs already present in the previously tagged data =  0
# IDs added =  9395
# % IDs added =  4 %
# IDs per weekday =  25
# IDs in tagged data =  246590
# % data tagged =  99 %

# %% [markdown]
# ### Rest

# %%
rest_data = df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),:]

# %%
rest_data_nomissact = rest_data.loc[~rest_data['Activity Name'].isna(),:]
last_act = rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Contact Session ID', 'Activity Name']]
rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Activity Name']].value_counts()
# Out:
# Activity Name
# SeniorsMenu                1197
# SuburbsOrCityMenu           443
# SeniorsConfirmationMenu     211
# MainMenu                      1
# Name: count, dtype: int64

# %% [markdown]
# All these calls are abandoned before information about the caller was obtained

# %%
rest_data['caller_type'] = 'unclassified (with access to legal issues menu)'
all_data = tagging(rest_data)
# Out:
# IDs already present in the previously tagged data =  0
# IDs added =  1852
# % IDs added =  1 %
# IDs per weekday =  5
# IDs in tagged data =  248442
# % data tagged =  100 %

# %% [markdown]
# ### caller type summary

# %%
call_type = pd.DataFrame({'calls':all_data.groupby('caller_type')['Contact Session ID'].nunique().sort_values(ascending = False)})
call_type['percent_calls'] = round(100*call_type['calls'] / 248442)
call_type['calls_per_weekday'] = round(call_type['calls'] / 370)
call_type
# Out:
#                                                  calls  percent_calls  \
# caller_type
# Main menu only                                   98357           40.0
# Non-senior legal issue                           79085           32.0
# Closed hours callers                             21861            9.0
# Chicago senior                                   17975            7.0
# Farmworker                                       10310            4.0
# Intake Outdial                                    9395            4.0
# Suburban senior                                   8305            3.0
# unclassified (with access to legal issues menu)   1852            1.0
# Non-Cook County Senior                            1302            1.0
#
#                                                  calls_per_weekday
# caller_type
# Main menu only                                               266.0
# Non-senior legal issue                                       214.0
# Closed hours callers                                          59.0
# Chicago senior                                                49.0
# Farmworker                                                    28.0
# Intake Outdial                                                25.0
# Suburban senior                                               22.0
# unclassified (with access to legal issues menu)                5.0
# Non-Cook County Senior                                         4.0

# %%
all_data['Overall_tag'] = "Legal issue"
all_data.loc[all_data['caller_type'].isin(['Farmworker','Intake Outdial','Closed hours callers']),'Overall_tag'] = 'Other'
all_data.loc[all_data['caller_type'] == 'Main menu only','Overall_tag'] = 'Main menu'
call_type = pd.DataFrame({'calls':all_data.groupby('Overall_tag')['Contact Session ID'].nunique().sort_values(ascending = False)})
call_type['percent_calls'] = round(100*call_type['calls'] / 248442)
call_type['calls_per_weekday'] = round(call_type['calls'] / 370)
call_type
# Out:
#               calls  percent_calls  calls_per_weekday
# Overall_tag
# Legal issue  108519           44.0              293.0
# Main menu     98357           40.0              266.0
# Other         41566           17.0              112.0

# %% [markdown]
# ### last activity

# %%
all_data.shape
# Out:
# (3328626, 11)

# %%
df_main.shape
# Out:
# (3328626, 9)

# %%
last_act = df_main_copy.groupby('Contact Session ID').tail(1)

# %%
last_act['Activity Name'].value_counts()
# Out:
# Activity Name
# ClosedQueueMenu                     39892
# StaffDirectoryEnglishTransfer       28035
# LanguageSelectionMenu               27545
# ClinicVoicemailTransfer             25721
# MainMenu                            13075
#                                     ...
# SubSeniorConsumerQueue                  1
# PlayCCBConfirmation                     1
# GetLoggedInOtherSubSeniorsAgents        1
# SubSeniorTenantQueue                    1
# ImmigrationSPQueue                      1
# Name: count, Length: 81, dtype: int64

# %%
last_act.loc[last_act['Activity Name'] == 'SetCallerID',:]['EP Name'].value_counts()
# Out:
# EP Name
# Intake Outdial EP    9358
# Name: count, dtype: int64

# %%
last_act.loc[(last_act['Activity Name'] == 'DisconnectContact1') & (last_act['EP Name'] == 'Courtesy Callback Telephony EP'),:]
# Out:
#                            Contact Session ID                         EP Name  \
# 794047   3ca933f7-d1c5-4b8c-ae2b-8f3500f79f1c  Courtesy Callback Telephony EP
# 2841437  da9f5fa1-2751-400e-9f1c-a8d112967149  Courtesy Callback Telephony EP
# 246804   12dc230d-c5e4-4f5a-86b5-a9e4d3637138  Courtesy Callback Telephony EP
#
#         Flow Name       Activity Name Activity Start Timestamp Queue Name  \
# 794047        NaN  DisconnectContact1      2025-09-30 09:16:34        NaN
# 2841437       NaN  DisconnectContact1      2025-09-30 09:25:27        NaN
# 246804        NaN  DisconnectContact1      2025-09-30 10:19:07        NaN
#
#         Agent Name Termination Reason  hour             caller_type  \
# 794047         NaN                NaN     9  Non-senior legal issue
# 2841437        NaN                NaN     9  Non-senior legal issue
# 246804         NaN                NaN    10          Chicago senior
#
#          Overall_tag
# 794047   Legal issue
# 2841437  Legal issue
# 246804   Legal issue

# %%
custdata('12dc230d-c5e4-4f5a-86b5-a9e4d3637138')
# Out:
#                           Contact Session ID  \
# 246752  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246753  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246754  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246755  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246756  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246757  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246758  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246759  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246760  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246761  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246762  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246763  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246764  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246765  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246766  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246767  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246768  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246769  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246770  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246771  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246772  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246773  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246774  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246775  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246776  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246777  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246778  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246779  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246780  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246781  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246782  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246783  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246784  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246785  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246786  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246787  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246788  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246789  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246790  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246791  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246792  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246793  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246794  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246795  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246796  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246797  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246798  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246799  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246800  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246801  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246802  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246803  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
# 246804  12dc230d-c5e4-4f5a-86b5-a9e4d3637138
#
#                                          EP Name                Flow Name  \
# 246752                  Main Number Telephony EP                      NaN
# 246753                                       NaN                  LACMain
# 246754                  Main Number Telephony EP                      NaN
# 246755                  Main Number Telephony EP                  LACMain
# 246756                  Main Number Telephony EP                      NaN
# 246757                                       NaN  PreLegalMenuSeniorsMenu
# 246758  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 246759  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 246760  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 246761  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 246762                                       NaN                LegalMenu
# 246763                   Legal Menu Telephony EP                      NaN
# 246764                   Legal Menu Telephony EP                      NaN
# 246765                                       NaN         LegalHousingMenu
# 246766           Legal Housing Menu Telephony EP                      NaN
# 246767                                       NaN                   Queues
# 246768               All LAC Queues Telephony EP                      NaN
# 246769               All LAC Queues Telephony EP                      NaN
# 246770               All LAC Queues Telephony EP                      NaN
# 246771                                       NaN                      NaN
# 246772               All LAC Queues Telephony EP                      NaN
# 246773               All LAC Queues Telephony EP                      NaN
# 246774               All LAC Queues Telephony EP                      NaN
# 246775               All LAC Queues Telephony EP                      NaN
# 246776               All LAC Queues Telephony EP                      NaN
# 246777               All LAC Queues Telephony EP                      NaN
# 246778               All LAC Queues Telephony EP                      NaN
# 246779               All LAC Queues Telephony EP                      NaN
# 246780               All LAC Queues Telephony EP                      NaN
# 246781               All LAC Queues Telephony EP                      NaN
# 246782               All LAC Queues Telephony EP                      NaN
# 246783               All LAC Queues Telephony EP                      NaN
# 246784               All LAC Queues Telephony EP                      NaN
# 246785               All LAC Queues Telephony EP                      NaN
# 246786               All LAC Queues Telephony EP                      NaN
# 246787               All LAC Queues Telephony EP                      NaN
# 246788               All LAC Queues Telephony EP                      NaN
# 246789               All LAC Queues Telephony EP                      NaN
# 246790               All LAC Queues Telephony EP                      NaN
# 246791               All LAC Queues Telephony EP                      NaN
# 246792               All LAC Queues Telephony EP                      NaN
# 246793               All LAC Queues Telephony EP                      NaN
# 246794               All LAC Queues Telephony EP                      NaN
# 246795               All LAC Queues Telephony EP                      NaN
# 246796               All LAC Queues Telephony EP                      NaN
# 246797               All LAC Queues Telephony EP                      NaN
# 246798               All LAC Queues Telephony EP                      NaN
# 246799                                       NaN         CourtesyCallback
# 246800            Courtesy Callback Telephony EP                      NaN
# 246801            Courtesy Callback Telephony EP                      NaN
# 246802                                       NaN                      NaN
# 246803            Courtesy Callback Telephony EP                      NaN
# 246804            Courtesy Callback Telephony EP                      NaN
#
#                     Activity Name Activity Start Timestamp Queue Name  \
# 246752                        NaN      2025-09-30 09:09:35        NaN
# 246753                        NaN      2025-09-30 09:09:35        NaN
# 246754      LanguageSelectionMenu      2025-09-30 09:09:35        NaN
# 246755                        NaN      2025-09-30 09:09:35        NaN
# 246756                   MainMenu      2025-09-30 09:09:45        NaN
# 246757                        NaN      2025-09-30 09:10:31        NaN
# 246758                SeniorsMenu      2025-09-30 09:10:31        NaN
# 246759    SeniorsConfirmationMenu      2025-09-30 09:10:36        NaN
# 246760          SuburbsOrCityMenu      2025-09-30 09:10:52        NaN
# 246761           SeniorsADAPTMenu      2025-09-30 09:11:11        NaN
# 246762                        NaN      2025-09-30 09:11:37        NaN
# 246763                 LegalMenu1      2025-09-30 09:11:37        NaN
# 246764                 LegalMenu2      2025-09-30 09:12:13        NaN
# 246765                        NaN      2025-09-30 09:13:02        NaN
# 246766                HousingMenu      2025-09-30 09:13:02        NaN
# 246767                        NaN      2025-09-30 09:13:11        NaN
# 246768  GetLoggedInConsumerAgents      2025-09-30 09:13:11        NaN
# 246769     IntakePreQueueMessage1      2025-09-30 09:13:11        NaN
# 246770              ConsumerQueue      2025-09-30 09:14:08        NaN
# 246771                        NaN      2025-09-30 09:14:08   Consumer
# 246772                        NaN      2025-09-30 09:14:08        NaN
# 246773                        NaN      2025-09-30 09:14:08   Consumer
# 246774           PreQueueMessage2      2025-09-30 09:14:08        NaN
# 246775                PlayMOH300s      2025-09-30 09:14:20        NaN
# 246776                 QueueMenu1      2025-09-30 09:19:20        NaN
# 246777                PlayMOH300s      2025-09-30 09:19:42        NaN
# 246778                 QueueMenu1      2025-09-30 09:24:43        NaN
# 246779                PlayMOH300s      2025-09-30 09:25:04        NaN
# 246780                 QueueMenu1      2025-09-30 09:30:05        NaN
# 246781                PlayMOH300s      2025-09-30 09:30:26        NaN
# 246782                 QueueMenu1      2025-09-30 09:35:27        NaN
# 246783                PlayMOH300s      2025-09-30 09:35:48        NaN
# 246784                 QueueMenu1      2025-09-30 09:40:50        NaN
# 246785                PlayMOH300s      2025-09-30 09:41:11        NaN
# 246786                 QueueMenu1      2025-09-30 09:46:12        NaN
# 246787                PlayMOH300s      2025-09-30 09:46:33        NaN
# 246788                 QueueMenu1      2025-09-30 09:51:34        NaN
# 246789                PlayMOH300s      2025-09-30 09:51:56        NaN
# 246790                 QueueMenu1      2025-09-30 09:56:57        NaN
# 246791                PlayMOH300s      2025-09-30 09:57:18        NaN
# 246792                 QueueMenu1      2025-09-30 10:02:19        NaN
# 246793                PlayMOH300s      2025-09-30 10:02:41        NaN
# 246794                 QueueMenu1      2025-09-30 10:07:42        NaN
# 246795                PlayMOH300s      2025-09-30 10:08:03        NaN
# 246796                 QueueMenu1      2025-09-30 10:13:04        NaN
# 246797                PlayMOH300s      2025-09-30 10:13:26        NaN
# 246798                 QueueMenu1      2025-09-30 10:18:27        NaN
# 246799                        NaN      2025-09-30 10:18:42        NaN
# 246800                    ReadANI      2025-09-30 10:18:42        NaN
# 246801                        CCB      2025-09-30 10:18:57        NaN
# 246802                        NaN      2025-09-30 10:18:57   Consumer
# 246803        PlayCCBConfirmation      2025-09-30 10:18:58        NaN
# 246804         DisconnectContact1      2025-09-30 10:19:07        NaN
#
#        Agent Name Termination Reason  hour
# 246752        NaN                NaN     9
# 246753        NaN                NaN     9
# 246754        NaN                NaN     9
# 246755        NaN                NaN     9
# 246756        NaN                NaN     9
# 246757        NaN                NaN     9
# 246758        NaN                NaN     9
# 246759        NaN                NaN     9
# 246760        NaN                NaN     9
# 246761        NaN                NaN     9
# 246762        NaN                NaN     9
# 246763        NaN                NaN     9
# 246764        NaN                NaN     9
# 246765        NaN                NaN     9
# 246766        NaN                NaN     9
# 246767        NaN                NaN     9
# 246768        NaN                NaN     9
# 246769        NaN                NaN     9
# 246770        NaN                NaN     9
# 246771        NaN                NaN     9
# 246772        NaN                NaN     9
# 246773        NaN                NaN     9
# 246774        NaN                NaN     9
# 246775        NaN                NaN     9
# 246776        NaN                NaN     9
# 246777        NaN                NaN     9
# 246778        NaN                NaN     9
# 246779        NaN                NaN     9
# 246780        NaN                NaN     9
# 246781        NaN                NaN     9
# 246782        NaN                NaN     9
# 246783        NaN                NaN     9
# 246784        NaN                NaN     9
# 246785        NaN                NaN     9
# 246786        NaN                NaN     9
# 246787        NaN                NaN     9
# 246788        NaN                NaN     9
# 246789        NaN                NaN     9
# 246790        NaN                NaN     9
# 246791        NaN                NaN     9
# 246792        NaN                NaN    10
# 246793        NaN                NaN    10
# 246794        NaN                NaN    10
# 246795        NaN                NaN    10
# 246796        NaN                NaN    10
# 246797        NaN                NaN    10
# 246798        NaN                NaN    10
# 246799        NaN                NaN    10
# 246800        NaN                NaN    10
# 246801        NaN                NaN    10
# 246802        NaN                NaN    10
# 246803        NaN                NaN    10
# 246804        NaN                NaN    10

# %%
screenpop_data = act_data('LegalServerScreenPop')

# %%
screenpop_data['Contact Session ID'].nunique()
# Out:
# 9673

# %%
screenpop_data.loc[~screenpop_data['Agent Name'].isna(),:]['Contact Session ID'].nunique()
# Out:
# 9673

# %%
screenpop_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 screenpop_data
#
# NameError: name 'screenpop_data' is not defined

# %%
# 1. First occurrence of LegalServerScreenPop per Contact Session ID
df = df_main.copy()
mask_lsp = df["Activity Name"].eq("LegalServerScreenPop")
first_lsp = (
    df.loc[mask_lsp]
      .groupby("Contact Session ID")["Activity Start Timestamp"]
      .first()
)

# 2. Last row with non-missing Agent Name per Contact Session ID
mask_agent = df["Agent Name"].notna()
last_agent = (
    df.loc[mask_agent]
      .groupby("Contact Session ID")["Activity Start Timestamp"]
      .last()
)

# 3. Combine into a single DataFrame
call_times = pd.DataFrame({
    "start_time": first_lsp,
    "end_time": last_agent
}).dropna()  # keep only sessions that have both

# 4. Keep only where end_time is after (or equal to) start_time
call_times = call_times[call_times["end_time"] >= call_times["start_time"]]

# 5. Duration from first LegalServerScreenPop to last non-missing Agent Name
call_times["duration_seconds"] = (
    call_times["end_time"] - call_times["start_time"]
).dt.total_seconds()

# Optional: reset index to have Contact Session ID as a column
call_times = call_times.reset_index()

print(call_times.head())

# %%
import matplotlib.pyplot as plt

# Histogram
plt.figure(figsize=(8, 4))
plt.hist(call_times["duration_seconds"], bins=30)
plt.xlabel("Duration (seconds)")
plt.ylabel("Frequency")
plt.title("Histogram of Call Duration")
plt.show()

# Boxplot
plt.figure(figsize=(6, 3))
plt.boxplot(call_times["duration_seconds"], vert=False)
plt.xlabel("Duration (seconds)")
plt.title("Boxplot of Call Duration")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 # Histogram
#       4 plt.figure(figsize=(8, 4))
# ----> 5 plt.hist(call_times["duration_seconds"], bins=30)
#       6 plt.xlabel("Duration (seconds)")
#       7 plt.ylabel("Frequency")
#
# NameError: name 'call_times' is not defined
