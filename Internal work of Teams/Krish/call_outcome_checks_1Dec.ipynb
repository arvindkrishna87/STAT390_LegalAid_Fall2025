# %% [markdown]
# Author: Krish

# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from datetime import date

# %%
data_path = "C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Spring 2025\\STAT390\\LegalAid\\Data\\CAR_-_EP_Flow_Activity_Queue__Agent_Names\\"
adhoc_data_path = 'C:\\Users\\akl0407\\OneDrive - Northwestern University\\Back up\\2025-26\\Fall 2025\\LegalAid\\Adhoc\\Adhoc datasets\\'

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))
df_main = pd.DataFrame(columns=['Contact Session ID', 'EP Name', 'Flow Name', 'Activity Name', 'Activity Start Timestamp', 
                                'Queue Name', 'Agent Name', 'Termination Reason'])
df_main
# Out:
# Empty DataFrame
# Columns: [Contact Session ID, EP Name, Flow Name, Activity Name, Activity Start Timestamp, Queue Name, Agent Name, Termination Reason]
# Index: []

# %%
i=0
for f in files:
    i = i + 1
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=2, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=2, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df.shape)
# Out:
# 1 CAR - EP, Flow, Activity, Queue, & Agent Names (01-12-25 - 01-18-25) (52010, 7)
# 2 CAR - EP, Flow, Activity, Queue, & Agent Names (01-19-25 - 02-01-25) (95495, 7)
# 3 CAR - EP, Flow, Activity, Queue, & Agent Names (02-02-25 - 02-15-25) (90056, 7)
# 4 CAR - EP, Flow, Activity, Queue, & Agent Names (02-16-25 - 03-01-25) (88186, 7)
# 5 CAR - EP, Flow, Activity, Queue, & Agent Names (03-02-25 - 03-15-25) (86377, 7)
# 6 CAR - EP, Flow, Activity, Queue, & Agent Names (04-07-24 - 04-20-24) (88766, 7)
# 7 CAR - EP, Flow, Activity, Queue, & Agent Names (04-21-24 - 05-04-24) (89643, 7)
# 8 CAR - EP, Flow, Activity, Queue, & Agent Names (05-05-24 - 05-18-24) (82575, 7)
# 9 CAR - EP, Flow, Activity, Queue, & Agent Names (05-19-24 - 06-01-24) (71103, 7)
# 10 CAR - EP, Flow, Activity, Queue, & Agent Names (06-02-24 - 06-15-24) (84354, 7)
# 11 CAR - EP, Flow, Activity, Queue, & Agent Names (06-16-24 - 06-29-24) (82124, 7)
# 12 CAR - EP, Flow, Activity, Queue, & Agent Names (06-30-24 - 07-13-24) (79752, 7)
# 13 CAR - EP, Flow, Activity, Queue, & Agent Names (07-14-24 - 07-27-24) (85110, 7)
# 14 CAR - EP, Flow, Activity, Queue, & Agent Names (07-28-24 - 08-10-24) (84627, 7)
# 15 CAR - EP, Flow, Activity, Queue, & Agent Names (08-11-24 - 08-24-24) (91622, 7)
# 16 CAR - EP, Flow, Activity, Queue, & Agent Names (08-24-24 - 09-07-24) (90040, 7)
# 17 CAR - EP, Flow, Activity, Queue, & Agent Names (09-08-24 - 09-21-24) (96581, 7)
# 18 CAR - EP, Flow, Activity, Queue, & Agent Names (09-22-24 - 10-05-24) (89446, 7)
# 19 CAR - EP, Flow, Activity, Queue, & Agent Names (10-06-24 - 10-19-24) (81700, 7)
# 20 CAR - EP, Flow, Activity, Queue, & Agent Names (10-20-24 - 11-02-24) (88430, 7)
# 21 CAR - EP, Flow, Activity, Queue, & Agent Names (11-03-24 - 11-16-24) (81614, 7)
# 22 CAR - EP, Flow, Activity, Queue, & Agent Names (11-17-24 - 11-30-24) (66216, 7)
# 23 CAR - EP, Flow, Activity, Queue, & Agent Names (12-01-24 - 12-14-24) (92220, 7)
# 24 CAR - EP, Flow, Activity, Queue, & Agent Names (12-15-24 - 12-28-24) (62143, 7)
# 25 CAR - EP, Flow, Activity, Queue, & Agent Names (12-29-24 - 01-11-25) (75356, 7)
# 26 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-16 to 3-22-25 (45326, 8)
# 27 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 3-30 to 4-5-25 (45072, 8)
# 28 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-13 to 4-19-25 (41088, 8)
# 29 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-20 to 4-26-25 (46686, 8)
# 30 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-27 to 5-3-25 (44169, 8)
# 31 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 4-6 to 4-12-25 (46630, 8)
# 32 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-11 to 5-17-25 (43268, 8)
# 33 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-18 to 5-24-25 (45104, 8)
# 34 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-25 to 5-31-25 (36851, 8)
# 35 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 5-4 to 5-10-25 (43955, 8)
# 36 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-1 to 6-7-25 (44523, 8)
# 37 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-15 to 6-21-25 (37234, 8)
# 38 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-22 to 6-28-25 (45394, 8)
# 39 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-29 to 7-5-25 (38300, 8)
# 40 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 6-8 to 6-14-25 (46728, 8)
# 41 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-13 to 7-19-25 (45706, 8)
# 42 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-20 to 7-26-25 (45328, 8)
# 43 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-28 ro 8-2-25 (46237, 8)
# 44 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 7-6 to 7-12-25 (48707, 8)
# 45 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-10 to 8-16-25 (44095, 8)
# 46 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-17 to 8-23-25 (47062, 8)
# 47 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-24 to 8-30-25 (45113, 8)
# 48 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-3 to 8-9-25 (44706, 8)
# 49 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 8-31 to 9-6-25 (36177, 8)
# 50 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-14 to 9-20-25 (45958, 8)
# 51 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-21 to 9-30-25 (60381, 8)
# 52 CAR - EP, Flow, Activity, Queue, &amp; Agent Names 9-7 to 9-13-25 (45304, 8)
# 53 CAR - EP, Flow, Activity, Queue, &amp; Agent Names3-23 to 3-29-25 (47978, 8)

# %%
df_main["Activity Start Timestamp"] = df_main["Activity Start Timestamp"].apply(
    lambda x: datetime.strptime(x, "%Y/%m/%d %I:%M:%S %p"))
df_main["hour"] = df_main["Activity Start Timestamp"].dt.hour
df_main.sort_values(by = ['Contact Session ID', 'Activity Start Timestamp'], inplace=True)
df_main.reset_index(inplace = True, drop = True)

# %%
def custdata(id):
    return df_main.loc[df_main['Contact Session ID'] == id,:]
def act_rows(act):
    return df_main.loc[df_main['Activity Name'] == act,:]
def act_data(act):
    get_act_rows = act_rows(act)
    return df_main.loc[df_main['Contact Session ID'].isin(get_act_rows['Contact Session ID']),:]
def data_rows(act, data):
    return data.loc[data['Activity Name'] == act,:]
def col_data(col, val):
    get_col_rows = df_main.loc[df_main[col] == val,:]
    return df_main.loc[df_main['Contact Session ID'].isin(get_col_rows['Contact Session ID']),:]
def col_rows(col, val):
    return df_main.loc[df_main[col] == val,:]
def calls_for_activity(act_name):
    return df_main.loc[df_main['Activity Name'] == act_name,'Contact Session ID'].nunique()
def tagging(data):     
    ids_already_present = data.loc[data['Contact Session ID'].isin(all_data['Contact Session ID']),'Contact Session ID'].nunique()
    print("IDs already present in the previously tagged data = ", ids_already_present)
    data = data.loc[~data['Contact Session ID'].isin(all_data['Contact Session ID']),:]
    print("IDs added = ", data['Contact Session ID'].nunique())    
    print("% IDs added = ", round(100*data['Contact Session ID'].nunique()/248422),"%")
    print("IDs per weekday = ", round(data['Contact Session ID'].nunique()/370))
    appended_data = pd.concat([all_data, data])
    print("IDs in tagged data = ", appended_data['Contact Session ID'].nunique())
    print("% data tagged = ", round(100*appended_data['Contact Session ID'].nunique()/248422),"%")
    return appended_data

# %%
df_main_copy = df_main.copy()
df_main_copy = df_main_copy.loc[~df_main['Activity Name'].isna(),:]

# %% [markdown]
# #### Main-menu only

# %%
num_EPs = df_main.groupby('Contact Session ID')['EP Name'].nunique()
one_ep_data = df_main.loc[df_main['Contact Session ID'].isin(num_EPs[num_EPs == 1].index),:]
main_menu_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Main Number Telephony EP',:]
main_menu_data = df_main.loc[df_main['Contact Session ID'].isin(main_menu_rows['Contact Session ID']),:]

num_acts = df_main.groupby('Contact Session ID')['Activity Name'].nunique()
no_acts_rem = df_main.loc[(df_main['Contact Session ID'].isin(num_acts[(num_acts == 0)].index)) & \
(df_main['EP Name'] == 'Pre-Legal Menu Seniors Menu Telephony EP'),:]
no_acts_rem_data = df_main.loc[df_main['Contact Session ID'].isin(no_acts_rem['Contact Session ID']),:]

main_menu_data = pd.concat([main_menu_data, no_acts_rem_data])
main_menu_data['caller_type'] = 'Main menu only'
print("% data = ", round(100*98352/248422),"%")
print("calls per day = ", round(98352/370))
print("calls per day = ",main_menu_data['Contact Session ID'].nunique())
# Out:
# % data =  40 %
# calls per day =  266
# calls per day =  98357

# %% [markdown]
# ## closed hours

# %%
closed_hours_data = col_data('EP Name', 'Closed Hours-Holidays Menu Telephony EP')
closed_hours_data['caller_type'] = 'Closed hours callers'
print(closed_hours_data['Contact Session ID'].nunique())

ids1 = set(main_menu_data["Contact Session ID"])
ids2 = set(closed_hours_data["Contact Session ID"])
common_12 = ids1 & ids2
if len(common_12) == 0:
    print("No overlap with the previously tagged data")

all_data = pd.concat([main_menu_data,closed_hours_data])
print("% data = ", round(100*closed_hours_data['Contact Session ID'].nunique()/248422),"%")
print("calls per day = ", round(closed_hours_data['Contact Session ID'].nunique()/370))
all_data['Contact Session ID'].nunique()
# Out:
# 21861
# No overlap with the previously tagged data
# % data =  9 %
# calls per day =  59
# 120218

# %% [markdown]
# ### Farmworker data
# calls already tagged as during closed hours excluded
# Removing farmworker data from analysis due to high abandonment rate

# %%
farm_data = act_data('FarmworkerMainMenu')
farmworker_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Farmworker Main Number Telephony EP',:]
farmworker_data = df_main.loc[df_main['Contact Session ID'].isin(farmworker_rows['Contact Session ID']),:]
more_farm_data = farmworker_data.loc[~farmworker_data['Contact Session ID'].isin(farm_data['Contact Session ID']),:]
farm_data = pd.concat([farm_data, more_farm_data])
farm_data['caller_type'] = 'Farmworker'
all_data = tagging(farm_data)
# Out:
# IDs already present in the previously tagged data =  90
# IDs added =  10310
# % IDs added =  4 %
# IDs per weekday =  28
# IDs in tagged data =  130528
# % data tagged =  53 %

# %% [markdown]
# ### Non-seniors legal menu
# Calls that reach LegalMenu2, but never reach SuburbsOrCityMenu

# %%
legmen2_data = act_data('LegalMenu1')
leg_senior_data_rows = data_rows('SuburbsOrCityMenu',legmen2_data)
#Non-seniors never reach the suburbs or city menu
leg_non_senior_data = legmen2_data.loc[~legmen2_data['Contact Session ID'].isin(leg_senior_data_rows['Contact Session ID']),:]
leg_non_senior_data['caller_type'] = 'Non-senior legal issue'
all_data = tagging(leg_non_senior_data)
# Out:
# IDs already present in the previously tagged data =  581
# IDs added =  79085
# % IDs added =  32 %
# IDs per weekday =  214
# IDs in tagged data =  209613
# % data tagged =  84 %

# %% [markdown]
# ## Seniors
# ### Suburban seniors
# Calls that reach SuburbanSeniorsMenu menu

# %%
suburban_seniors_data = act_data('SuburbanSeniorsMenu')
suburban_seniors_data['caller_type'] = 'Suburban senior'
all_data = tagging(suburban_seniors_data)
# Out:
# IDs already present in the previously tagged data =  14
# IDs added =  8305
# % IDs added =  3 %
# IDs per weekday =  22
# IDs in tagged data =  217918
# % data tagged =  88 %

# %% [markdown]
# ### City Seniors

# %%
city_seniors = act_data('SeniorsADAPTMenu')
city_seniors['caller_type'] = 'Chicago senior'
all_data = tagging(city_seniors)
# Out:
# IDs already present in the previously tagged data =  55
# IDs added =  17975
# % IDs added =  7 %
# IDs per weekday =  49
# IDs in tagged data =  235893
# % data tagged =  95 %

# %% [markdown]
# ### Non cook county seniors

# %%
noncook_seniors = act_data('SeniorNotCookCoMenu')
noncook_seniors['caller_type'] = 'Non-Cook County Senior'
all_data = tagging(noncook_seniors)
# Out:
# IDs already present in the previously tagged data =  10
# IDs added =  1302
# % IDs added =  1 %
# IDs per weekday =  4
# IDs in tagged data =  237195
# % data tagged =  95 %

# %% [markdown]
# ### Unclassified seniors

# %%
#unclassified_seniors = act_data('SuburbsOrCityMenu')
#unclassified_seniors['caller_type'] = 'Unclassified seniors'
#all_data = tagging(unclassified_seniors)

# %% [markdown]
# All these seniors abandoned call before making a choice

# %% [markdown]
# ## Intake outdial EP

# %%
intake_rows = one_ep_data.loc[one_ep_data['EP Name'] == 'Intake Outdial EP',:]
intake_outdial_data = df_main.loc[df_main['Contact Session ID'].isin(intake_rows['Contact Session ID']),:]
intake_outdial_data['caller_type'] = 'Intake Outdial'
all_data = tagging(intake_outdial_data)
# Out:
# IDs already present in the previously tagged data =  0
# IDs added =  9395
# % IDs added =  4 %
# IDs per weekday =  25
# IDs in tagged data =  246590
# % data tagged =  99 %

# %% [markdown]
# ### Rest

# %%
rest_data = df_main.loc[~df_main['Contact Session ID'].isin(all_data['Contact Session ID']),:]

# %%
rest_data_nomissact = rest_data.loc[~rest_data['Activity Name'].isna(),:]
last_act = rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Contact Session ID', 'Activity Name']]
rest_data_nomissact.groupby('Contact Session ID').tail(1)[['Activity Name']].value_counts()
# Out:
# Activity Name
# SeniorsMenu                1197
# SuburbsOrCityMenu           443
# SeniorsConfirmationMenu     211
# MainMenu                      1
# Name: count, dtype: int64

# %% [markdown]
# All these calls are abandoned before information about the caller was obtained

# %%
rest_data['caller_type'] = 'unclassified (with access to legal issues menu)'
all_data = tagging(rest_data)
# Out:
# IDs already present in the previously tagged data =  0
# IDs added =  1852
# % IDs added =  1 %
# IDs per weekday =  5
# IDs in tagged data =  248442
# % data tagged =  100 %

# %% [markdown]
# ### caller type summary

# %%
call_type = pd.DataFrame({'calls':all_data.groupby('caller_type')['Contact Session ID'].nunique().sort_values(ascending = False)})
call_type['percent_calls'] = round(100*call_type['calls'] / 248442)
call_type['calls_per_weekday'] = round(call_type['calls'] / 370)
call_type
# Out:
#                                                  calls  percent_calls  \
# caller_type
# Main menu only                                   98357           40.0
# Non-senior legal issue                           79085           32.0
# Closed hours callers                             21861            9.0
# Chicago senior                                   17975            7.0
# Farmworker                                       10310            4.0
# Intake Outdial                                    9395            4.0
# Suburban senior                                   8305            3.0
# unclassified (with access to legal issues menu)   1852            1.0
# Non-Cook County Senior                            1302            1.0
#
#                                                  calls_per_weekday
# caller_type
# Main menu only                                               266.0
# Non-senior legal issue                                       214.0
# Closed hours callers                                          59.0
# Chicago senior                                                49.0
# Farmworker                                                    28.0
# Intake Outdial                                                25.0
# Suburban senior                                               22.0
# unclassified (with access to legal issues menu)                5.0
# Non-Cook County Senior                                         4.0

# %%
all_data['Overall_tag'] = "Legal issue"
all_data.loc[all_data['caller_type'].isin(['Farmworker','Intake Outdial','Closed hours callers']),'Overall_tag'] = 'Other'
all_data.loc[all_data['caller_type'] == 'Main menu only','Overall_tag'] = 'Main menu'
call_type = pd.DataFrame({'calls':all_data.groupby('Overall_tag')['Contact Session ID'].nunique().sort_values(ascending = False)})
call_type['percent_calls'] = round(100*call_type['calls'] / 248442)
call_type['calls_per_weekday'] = round(call_type['calls'] / 370)
call_type
# Out:
#               calls  percent_calls  calls_per_weekday
# Overall_tag
# Legal issue  108519           44.0              293.0
# Main menu     98357           40.0              266.0
# Other         41566           17.0              112.0

# %% [markdown]
# ### last activity

# %%
all_data.shape
# Out:
# (3328626, 11)

# %%
df_main.shape
# Out:
# (3328626, 9)

# %%
last_act = df_main_copy.groupby('Contact Session ID').tail(1)

# %%
last_act['Activity Name'].value_counts()
# Out:
# Activity Name
# ClosedQueueMenu                     39892
# StaffDirectoryEnglishTransfer       28035
# LanguageSelectionMenu               27545
# ClinicVoicemailTransfer             25721
# MainMenu                            13075
#                                     ...
# SubSeniorConsumerQueue                  1
# PlayCCBConfirmation                     1
# GetLoggedInOtherSubSeniorsAgents        1
# SubSeniorTenantQueue                    1
# ImmigrationSPQueue                      1
# Name: count, Length: 81, dtype: int64

# %%
act_data('GetLoggedInSubSeniorTenantAgents')['Termination Reason'].value_counts()
# Out:
# Termination Reason
# Customer Left                       584
# Agent Left                          124
# RONA_TIMER_EXPIRED                   89
# NO_ANSWER_FROM_AGENT                 74
# RONA Timer Expired                   53
# NO_ANSWER_FROM_CUSTOMER              30
# System disconnected the contact      14
# CUSTOMER_UNAVAILABLE                  6
# Queue Timeout                         4
# AGENT_ENDS                            2
# MAX_CALLBACK_RETRY_LIMIT_REACHED      1
# Name: count, dtype: int64

# %%
last_act.loc[last_act['Activity Name'] == 'GetLoggedInSubSeniorOtherAgents',:]
# Out:
#                            Contact Session ID                      EP Name  \
# 140569   0ad4f161-b292-46cf-ae4c-629a1ceadee3  All LAC Queues Telephony EP
# 508777   26cf155d-de03-4743-86df-43fd10d3d692  All LAC Queues Telephony EP
# 873567   42e78285-152e-41c2-87d8-c3af61c548de  All LAC Queues Telephony EP
# 978019   4ace4198-cf92-468b-a955-367fcd27bea8  All LAC Queues Telephony EP
# 1365850  68ab1230-66e2-42dc-911a-cc0a2defebd8  All LAC Queues Telephony EP
# 2359718  b548e4e6-aa11-49f5-83fb-8befb88a6267  All LAC Queues Telephony EP
# 2644415  cb52f012-9a5c-4bb4-a72d-5b641e50f996  All LAC Queues Telephony EP
# 2780857  d5fa4023-f53b-4977-8997-d483a2158e68  All LAC Queues Telephony EP
#
#         Flow Name                    Activity Name Activity Start Timestamp  \
# 140569        NaN  GetLoggedInSubSeniorOtherAgents      2024-10-24 09:32:55
# 508777        NaN  GetLoggedInSubSeniorOtherAgents      2024-11-04 13:31:18
# 873567        NaN  GetLoggedInSubSeniorOtherAgents      2024-10-08 10:29:18
# 978019        NaN  GetLoggedInSubSeniorOtherAgents      2025-05-29 15:08:00
# 1365850       NaN  GetLoggedInSubSeniorOtherAgents      2024-06-04 09:50:46
# 2359718       NaN  GetLoggedInSubSeniorOtherAgents      2024-11-27 09:57:36
# 2644415       NaN  GetLoggedInSubSeniorOtherAgents      2025-01-09 08:26:52
# 2780857       NaN  GetLoggedInSubSeniorOtherAgents      2024-08-21 11:27:56
#
#         Queue Name Agent Name Termination Reason  hour
# 140569         NaN        NaN                NaN     9
# 508777         NaN        NaN                NaN    13
# 873567         NaN        NaN                NaN    10
# 978019         NaN        NaN                NaN    15
# 1365850        NaN        NaN                NaN     9
# 2359718        NaN        NaN                NaN     9
# 2644415        NaN        NaN                NaN     8
# 2780857        NaN        NaN                NaN    11

# %%
custdata(last_act.loc[last_act['Activity Name'] == 'GetLoggedInSubSeniorOtherAgents','Contact Session ID'].unique()[1])
# Out:
#                           Contact Session ID  \
# 508765  26cf155d-de03-4743-86df-43fd10d3d692
# 508766  26cf155d-de03-4743-86df-43fd10d3d692
# 508767  26cf155d-de03-4743-86df-43fd10d3d692
# 508768  26cf155d-de03-4743-86df-43fd10d3d692
# 508769  26cf155d-de03-4743-86df-43fd10d3d692
# 508770  26cf155d-de03-4743-86df-43fd10d3d692
# 508771  26cf155d-de03-4743-86df-43fd10d3d692
# 508772  26cf155d-de03-4743-86df-43fd10d3d692
# 508773  26cf155d-de03-4743-86df-43fd10d3d692
# 508774  26cf155d-de03-4743-86df-43fd10d3d692
# 508775  26cf155d-de03-4743-86df-43fd10d3d692
# 508776  26cf155d-de03-4743-86df-43fd10d3d692
# 508777  26cf155d-de03-4743-86df-43fd10d3d692
#
#                                          EP Name                Flow Name  \
# 508765                  Main Number Telephony EP                      NaN
# 508766                                       NaN                  LACMain
# 508767                  Main Number Telephony EP                      NaN
# 508768                  Main Number Telephony EP                  LACMain
# 508769                  Main Number Telephony EP                      NaN
# 508770                                       NaN  PreLegalMenuSeniorsMenu
# 508771  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 508772  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 508773  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 508774  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 508775  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 508776               All LAC Queues Telephony EP                      NaN
# 508777               All LAC Queues Telephony EP                      NaN
#
#                           Activity Name Activity Start Timestamp Queue Name  \
# 508765                              NaN      2024-11-04 13:27:53        NaN
# 508766                              NaN      2024-11-04 13:27:53        NaN
# 508767            LanguageSelectionMenu      2024-11-04 13:27:53        NaN
# 508768                              NaN      2024-11-04 13:27:53        NaN
# 508769                         MainMenu      2024-11-04 13:28:06        NaN
# 508770                              NaN      2024-11-04 13:28:33        NaN
# 508771                      SeniorsMenu      2024-11-04 13:28:33        NaN
# 508772          SeniorsConfirmationMenu      2024-11-04 13:28:39        NaN
# 508773                SuburbsOrCityMenu      2024-11-04 13:28:56        NaN
# 508774              SuburbanSeniorsMenu      2024-11-04 13:29:15        NaN
# 508775              SuburbanSeniorsMenu      2024-11-04 13:30:59        NaN
# 508776                              NaN      2024-11-04 13:31:18        NaN
# 508777  GetLoggedInSubSeniorOtherAgents      2024-11-04 13:31:18        NaN
#
#        Agent Name Termination Reason  hour
# 508765        NaN                NaN    13
# 508766        NaN                NaN    13
# 508767        NaN                NaN    13
# 508768        NaN                NaN    13
# 508769        NaN                NaN    13
# 508770        NaN                NaN    13
# 508771        NaN                NaN    13
# 508772        NaN                NaN    13
# 508773        NaN                NaN    13
# 508774        NaN                NaN    13
# 508775        NaN                NaN    13
# 508776        NaN                NaN    13
# 508777        NaN                NaN    13

# %%
last_act.loc[last_act['Activity Name'] == 'GetLoggedInSubSeniorTenantAgents',:]
# Out:
#                            Contact Session ID                      EP Name  \
# 133105   0a42d1fb-9eec-4de9-ae24-2f606fd9d15f  All LAC Queues Telephony EP
# 267012   146bf46f-fcb1-4548-a028-e2e3d606f0fd  All LAC Queues Telephony EP
# 276045   15171307-e676-4f00-90f1-419cfbe7004e  All LAC Queues Telephony EP
# 276290   151b0bb4-8f45-4da9-81a5-4c33d1c8ba29  All LAC Queues Telephony EP
# 289675   16259a6e-822d-4099-8fdb-30d1f7860d7d  All LAC Queues Telephony EP
# 301065   16ff8dc6-4bed-463d-a181-e3fe290b4fde  All LAC Queues Telephony EP
# 666358   32de9798-4a5b-45ae-bbda-5d62100b4d7a  All LAC Queues Telephony EP
# 700201   3585a8ba-8adb-44a5-9838-c4399f131989  All LAC Queues Telephony EP
# 841784   406d47d0-19b8-4e27-96a9-38dec0048863  All LAC Queues Telephony EP
# 960751   4984f420-b1d7-40a9-ac9d-f1e22f6ac0a1  All LAC Queues Telephony EP
# 1113670  553268d5-8b71-434f-9f83-3f4db5b54a50  All LAC Queues Telephony EP
# 1327783  65c07c04-2a50-4a6d-bcdd-15d5978bf549  All LAC Queues Telephony EP
# 1467009  70667e5d-d614-4d64-8f30-e4a00039ca51  All LAC Queues Telephony EP
# 1531676  756ac0b8-7ec1-45b6-b8e2-dbb5a5661488  All LAC Queues Telephony EP
# 1537689  75e0281f-6c9a-4e83-8af0-ac633cd03e0e  All LAC Queues Telephony EP
# 1669263  7fd98ae2-b123-4b75-b7c2-d0583c4f0a6b  All LAC Queues Telephony EP
# 1707430  82bbf055-6949-44fb-b1aa-7f10cecf1f11  All LAC Queues Telephony EP
# 1752724  862fbcaf-953c-4b39-b82d-37e9cf3a3367  All LAC Queues Telephony EP
# 1803583  8a28bf3d-214b-4853-90af-f755419dc6d2  All LAC Queues Telephony EP
# 1982068  97f50aa7-76c3-4725-be4e-fff9fd9315d4  All LAC Queues Telephony EP
# 1986892  984ddc6d-522d-470f-9a7a-58fcafbb6433  All LAC Queues Telephony EP
# 2234986  ab97697e-1f26-49d9-ad25-d998fb18e4fc  All LAC Queues Telephony EP
# 2323333  b27c49b1-761e-4da9-b0f1-239700682786  All LAC Queues Telephony EP
# 2368913  b5f952f3-9292-45e3-9a8c-93539690c7df  All LAC Queues Telephony EP
# 2445122  bbbfa231-a603-4a17-816f-5d95c3c48405  All LAC Queues Telephony EP
# 2488373  bf1b3761-0c49-47cd-b063-559739afe159  All LAC Queues Telephony EP
# 3085985  ed3e6cf0-0a99-4e23-8722-4dd064e8e29e  All LAC Queues Telephony EP
#
#         Flow Name                     Activity Name Activity Start Timestamp  \
# 133105        NaN  GetLoggedInSubSeniorTenantAgents      2025-07-24 10:23:12
# 267012        NaN  GetLoggedInSubSeniorTenantAgents      2025-05-06 13:00:24
# 276045        NaN  GetLoggedInSubSeniorTenantAgents      2025-07-16 13:40:43
# 276290        NaN  GetLoggedInSubSeniorTenantAgents      2024-05-03 14:18:23
# 289675        NaN  GetLoggedInSubSeniorTenantAgents      2025-07-09 12:17:37
# 301065        NaN  GetLoggedInSubSeniorTenantAgents      2024-08-08 16:03:43
# 666358        NaN  GetLoggedInSubSeniorTenantAgents      2024-10-11 12:54:20
# 700201        NaN  GetLoggedInSubSeniorTenantAgents      2025-07-15 14:08:20
# 841784        NaN  GetLoggedInSubSeniorTenantAgents      2024-06-21 12:43:13
# 960751        NaN  GetLoggedInSubSeniorTenantAgents      2025-04-23 13:15:40
# 1113670       NaN  GetLoggedInSubSeniorTenantAgents      2024-10-16 09:50:12
# 1327783       NaN  GetLoggedInSubSeniorTenantAgents      2024-07-23 12:12:34
# 1467009       NaN  GetLoggedInSubSeniorTenantAgents      2025-01-08 08:29:24
# 1531676       NaN  GetLoggedInSubSeniorTenantAgents      2024-08-07 11:58:46
# 1537689       NaN  GetLoggedInSubSeniorTenantAgents      2025-01-14 11:53:10
# 1669263       NaN  GetLoggedInSubSeniorTenantAgents      2024-08-16 14:02:02
# 1707430       NaN  GetLoggedInSubSeniorTenantAgents      2024-08-12 10:33:49
# 1752724       NaN  GetLoggedInSubSeniorTenantAgents      2025-03-24 14:50:42
# 1803583       NaN  GetLoggedInSubSeniorTenantAgents      2025-07-07 10:27:56
# 1982068       NaN  GetLoggedInSubSeniorTenantAgents      2024-06-12 11:38:40
# 1986892       NaN  GetLoggedInSubSeniorTenantAgents      2025-06-12 12:30:45
# 2234986       NaN  GetLoggedInSubSeniorTenantAgents      2025-04-21 09:56:49
# 2323333       NaN  GetLoggedInSubSeniorTenantAgents      2024-07-17 11:37:04
# 2368913       NaN  GetLoggedInSubSeniorTenantAgents      2024-08-20 15:21:06
# 2445122       NaN  GetLoggedInSubSeniorTenantAgents      2025-01-13 12:16:39
# 2488373       NaN  GetLoggedInSubSeniorTenantAgents      2025-01-15 13:31:50
# 3085985       NaN  GetLoggedInSubSeniorTenantAgents      2025-05-13 11:18:41
#
#         Queue Name Agent Name Termination Reason  hour
# 133105         NaN        NaN                NaN    10
# 267012         NaN        NaN                NaN    13
# 276045         NaN        NaN                NaN    13
# 276290         NaN        NaN                NaN    14
# 289675         NaN        NaN                NaN    12
# 301065         NaN        NaN                NaN    16
# 666358         NaN        NaN                NaN    12
# 700201         NaN        NaN                NaN    14
# 841784         NaN        NaN                NaN    12
# 960751         NaN        NaN                NaN    13
# 1113670        NaN        NaN                NaN     9
# 1327783        NaN        NaN                NaN    12
# 1467009        NaN        NaN                NaN     8
# 1531676        NaN        NaN                NaN    11
# 1537689        NaN        NaN                NaN    11
# 1669263        NaN        NaN                NaN    14
# 1707430        NaN        NaN                NaN    10
# 1752724        NaN        NaN                NaN    14
# 1803583        NaN        NaN                NaN    10
# 1982068        NaN        NaN                NaN    11
# 1986892        NaN        NaN                NaN    12
# 2234986        NaN        NaN                NaN     9
# 2323333        NaN        NaN                NaN    11
# 2368913        NaN        NaN                NaN    15
# 2445122        NaN        NaN                NaN    12
# 2488373        NaN        NaN                NaN    13
# 3085985        NaN        NaN                NaN    11

# %%
last_act.loc[(last_act['Activity Name'] == 'DisconnectContact1') & (last_act['EP Name'] == 'Courtesy Callback Telephony EP'),:]
# Out:
#                            Contact Session ID                         EP Name  \
# 6851     00813898-077a-4e98-b20d-25c743b78fa8  Courtesy Callback Telephony EP
# 67153    052f5e0b-8ac9-42a0-82bf-c3a548e1e2ac  Courtesy Callback Telephony EP
# 158095   0c307156-d011-4483-9bb2-3012c79480a3  Courtesy Callback Telephony EP
# 246804   12dc230d-c5e4-4f5a-86b5-a9e4d3637138  Courtesy Callback Telephony EP
# 794047   3ca933f7-d1c5-4b8c-ae2b-8f3500f79f1c  Courtesy Callback Telephony EP
# 881389   4382f7c5-4a31-46ee-b1bd-f8b519867f11  Courtesy Callback Telephony EP
# 1069528  51ce5bb7-6a6a-49e7-ac04-7298e5ddf912  Courtesy Callback Telephony EP
# 1721968  83d08515-a415-4f9b-934b-f32acb85dec9  Courtesy Callback Telephony EP
# 1950393  958fc50a-885f-40a3-8617-a4d376088169  Courtesy Callback Telephony EP
# 2080647  9fbdea51-8b09-471a-8566-c0aba78704b1  Courtesy Callback Telephony EP
# 2158392  a5d36359-0b1f-47b3-8dd9-989acb227025  Courtesy Callback Telephony EP
# 2419073  b9ccc9ff-0344-4b7e-bcca-2bcfa8ac8bce  Courtesy Callback Telephony EP
# 2446079  bbcf9e37-94d2-42c5-ba63-576ddd58076a  Courtesy Callback Telephony EP
# 2454597  bc7b105d-db81-47fb-b307-76d5e22fdb46  Courtesy Callback Telephony EP
# 2490322  bf3f0098-ecb0-47b7-8302-5d0cc8d11d96  Courtesy Callback Telephony EP
# 2595756  c785a865-c8a4-45c9-85e5-47fed72df9b0  Courtesy Callback Telephony EP
# 2841437  da9f5fa1-2751-400e-9f1c-a8d112967149  Courtesy Callback Telephony EP
# 3257003  fa740470-3250-4eb8-a713-8442aef228d5  Courtesy Callback Telephony EP
#
#         Flow Name       Activity Name Activity Start Timestamp Queue Name  \
# 6851          NaN  DisconnectContact1      2025-07-31 08:42:35        NaN
# 67153         NaN  DisconnectContact1      2025-07-29 10:05:59        NaN
# 158095        NaN  DisconnectContact1      2025-07-29 12:28:12        NaN
# 246804        NaN  DisconnectContact1      2025-09-30 10:19:07        NaN
# 794047        NaN  DisconnectContact1      2025-09-30 09:16:34        NaN
# 881389        NaN  DisconnectContact1      2025-07-29 08:08:23        NaN
# 1069528       NaN  DisconnectContact1      2025-07-28 08:13:39        NaN
# 1721968       NaN  DisconnectContact1      2025-07-29 12:14:09        NaN
# 1950393       NaN  DisconnectContact1      2024-07-25 08:47:20        NaN
# 2080647       NaN  DisconnectContact1      2025-07-30 10:49:55        NaN
# 2158392       NaN  DisconnectContact1      2025-07-28 08:24:23        NaN
# 2419073       NaN  DisconnectContact1      2025-07-28 08:14:04        NaN
# 2446079       NaN  DisconnectContact1      2025-07-30 12:12:32        NaN
# 2454597       NaN  DisconnectContact1      2025-07-31 09:06:43        NaN
# 2490322       NaN  DisconnectContact1      2025-07-28 13:45:41        NaN
# 2595756       NaN  DisconnectContact1      2025-07-29 11:22:16        NaN
# 2841437       NaN  DisconnectContact1      2025-09-30 09:25:27        NaN
# 3257003       NaN  DisconnectContact1      2025-07-30 08:30:02        NaN
#
#         Agent Name Termination Reason  hour
# 6851           NaN                NaN     8
# 67153          NaN                NaN    10
# 158095         NaN                NaN    12
# 246804         NaN                NaN    10
# 794047         NaN                NaN     9
# 881389         NaN                NaN     8
# 1069528        NaN                NaN     8
# 1721968        NaN                NaN    12
# 1950393        NaN                NaN     8
# 2080647        NaN                NaN    10
# 2158392        NaN                NaN     8
# 2419073        NaN                NaN     8
# 2446079        NaN                NaN    12
# 2454597        NaN                NaN     9
# 2490322        NaN                NaN    13
# 2595756        NaN                NaN    11
# 2841437        NaN                NaN     9
# 3257003        NaN                NaN     8

# %%
screenpop_data = act_data('ScreenPopProcessComplete')

# %%
screenpop_data['Contact Session ID'].nunique()
# Out:
# 758

# %%
screenpop_data.loc[~screenpop_data['Agent Name'].isna(),:]['Contact Session ID'].nunique()
# Out:
# 758

# %%
screenpop_data
# Out:
#                            Contact Session ID                      EP Name  \
# 7957     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7958     0095d75b-7e36-43bd-90a9-965e3c4722ed                          NaN
# 7959     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7960     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# 7961     0095d75b-7e36-43bd-90a9-965e3c4722ed     Main Number Telephony EP
# ...                                       ...                          ...
# 3327617  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327618  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327619  ffeba08a-2298-40a2-8864-ecb0a414e7e8  All LAC Queues Telephony EP
# 3327620  ffeba08a-2298-40a2-8864-ecb0a414e7e8                          NaN
# 3327621  ffeba08a-2298-40a2-8864-ecb0a414e7e8                          NaN
#
#         Flow Name             Activity Name Activity Start Timestamp  \
# 7957          NaN                       NaN      2024-06-12 15:05:39
# 7958      LACMain                       NaN      2024-06-12 15:05:39
# 7959          NaN     LanguageSelectionMenu      2024-06-12 15:05:39
# 7960      LACMain                       NaN      2024-06-12 15:05:40
# 7961          NaN                  MainMenu      2024-06-12 15:05:50
# ...           ...                       ...                      ...
# 3327617       NaN  ScreenPopProcessComplete      2025-05-29 12:27:26
# 3327618       NaN                       NaN      2025-05-29 12:27:30
# 3327619       NaN                       NaN      2025-05-29 12:40:53
# 3327620       NaN                       NaN      2025-05-29 12:40:53
# 3327621       NaN                       NaN      2025-05-29 12:40:55
#
#                  Queue Name  Agent Name Termination Reason  hour
# 7957                    NaN         NaN                NaN    15
# 7958                    NaN         NaN                NaN    15
# 7959                    NaN         NaN                NaN    15
# 7960                    NaN         NaN                NaN    15
# 7961                    NaN         NaN                NaN    15
# ...                     ...         ...                ...   ...
# 3327617                 NaN         NaN                NaN    12
# 3327618  SubSenior Benefits  Flora Fell                NaN    12
# 3327619  SubSenior Benefits  Flora Fell      Customer Left    12
# 3327620  SubSenior Benefits  Flora Fell                NaN    12
# 3327621  SubSenior Benefits  Flora Fell                NaN    12
#
# [30357 rows x 9 columns]

# %%
# 1. First occurrence of LegalServerScreenPop per Contact Session ID
df = df_main.copy()
mask_lsp = df["Activity Name"].eq("ScreenPopProcessComplete")
first_lsp = (
    df.loc[mask_lsp]
      .groupby("Contact Session ID")["Activity Start Timestamp"]
      .first()
)

# 2. Last row with non-missing Agent Name per Contact Session ID
mask_agent = df["Agent Name"].notna()
last_agent = (
    df.loc[mask_agent]
      .groupby("Contact Session ID")["Activity Start Timestamp"]
      .last()
)

# 3. Combine into a single DataFrame
call_times = pd.DataFrame({
    "start_time": first_lsp,
    "end_time": last_agent
}).dropna()  # keep only sessions that have both

# 4. Keep only where end_time is after (or equal to) start_time
call_times = call_times[call_times["end_time"] >= call_times["start_time"]]

# 5. Duration from first LegalServerScreenPop to last non-missing Agent Name
call_times["duration_seconds"] = (
    call_times["end_time"] - call_times["start_time"]
).dt.total_seconds()

# Optional: reset index to have Contact Session ID as a column
call_times = call_times.reset_index()

print(call_times.head())
# Out:
#                      Contact Session ID          start_time  \
# 0  0095d75b-7e36-43bd-90a9-965e3c4722ed 2024-06-12 15:15:43
# 1  00d7e8e4-863b-41ce-ad69-2609bfe799de 2025-04-09 15:34:16
# 2  014de6cb-f912-4c78-8e3e-dd5288af51eb 2025-04-18 08:03:01
# 3  0223c263-3afa-4df6-856f-598d90911f40 2025-08-28 09:36:56
# 4  02400a1b-c865-4c86-928e-67a0ba56e1f1 2024-12-27 08:52:41
#
#              end_time  duration_seconds
# 0 2024-06-12 15:17:18              95.0
# 1 2025-04-09 15:41:13             417.0
# 2 2025-04-18 08:14:47             706.0
# 3 2025-08-28 09:48:11             675.0
# 4 2024-12-27 08:55:26             165.0

# %%
np.percentile(call_times["duration_seconds"],1)
# Out:
# 14.0

# %%
#import matplotlib.pyplot as plt

# Histogram
plt.figure(figsize=(8, 4))
plt.hist(call_times["duration_seconds"], bins=30)
plt.xlabel("Duration (seconds)")
plt.ylabel("Frequency")
plt.title("Histogram of Call Duration")
plt.show()

# Boxplot
plt.figure(figsize=(6, 3))
plt.boxplot(call_times["duration_seconds"], vert=False)
plt.xlabel("Duration (seconds)")
plt.title("Boxplot of Call Duration")
plt.show()

# %%
call_times
# Out:
#                         Contact Session ID          start_time  \
# 0     000cce29-1c76-4991-9445-bb5f9028f47d 2024-05-29 15:02:22
# 1     00116654-66ea-4582-a109-aacde13a620d 2024-07-25 15:52:42
# 2     001741db-98b4-409f-8646-32ed0ecf6331 2025-07-23 09:13:50
# 3     0018380f-cf12-40f5-b525-af190304c42b 2024-08-20 13:57:19
# 4     0019d572-7f3e-4380-bc1f-274fc63edcb6 2025-09-17 10:52:42
# ...                                    ...                 ...
# 9665  ffeb379a-6940-4a06-99bd-2c1e5082c251 2024-05-24 12:51:44
# 9666  ffeb818f-1c52-4845-817f-0b9ffe18f7c4 2024-05-28 12:43:26
# 9667  ffeba08a-2298-40a2-8864-ecb0a414e7e8 2025-05-29 12:10:15
# 9668  ffebd3d4-6fc7-4922-aa45-849790c12f6a 2024-07-10 12:46:37
# 9669  fff898b5-9df2-40f4-a421-2dac3dc04194 2025-08-01 14:25:11
#
#                 end_time  duration_seconds
# 0    2024-05-29 15:04:13             111.0
# 1    2024-07-25 15:52:56              14.0
# 2    2025-07-23 09:23:39             589.0
# 3    2024-08-20 14:00:46             207.0
# 4    2025-09-17 11:20:05            1643.0
# ...                  ...               ...
# 9665 2024-05-24 13:22:41            1857.0
# 9666 2024-05-28 12:44:46              80.0
# 9667 2025-05-29 12:40:55            1840.0
# 9668 2024-07-10 12:47:54              77.0
# 9669 2025-08-01 14:50:59            1548.0
#
# [9670 rows x 4 columns]

# %%
df = df_main_copy.copy()
# 1. Activity immediately above (previous activity)
df["Prev Activity 1"] = df.groupby("Contact Session ID")["Activity Name"].shift(1)

# 2. Activity two rows above
df["Prev Activity 2"] = df.groupby("Contact Session ID")["Activity Name"].shift(2)

# Filter only the rows where current activity is DisconnectContact2
out = df.loc[df["Activity Name"].eq("DisconnectContact2"),
             ["Contact Session ID",
              "Activity Start Timestamp",
              "Prev Activity 1",
              "Prev Activity 2"]]

out
# Out:
#                            Contact Session ID Activity Start Timestamp  \
# 13540    0109f306-78ca-46c8-b5ec-b5704f205761      2025-02-12 09:16:47
# 29587    0252b263-791e-4a77-bc03-16e13c0963aa      2025-02-11 15:13:58
# 56084    04548de3-001a-45cd-a79f-fbc872b2fad3      2024-06-06 09:30:57
# 65202    05015f23-38a9-4f3e-b286-fae210c20f68      2025-07-01 11:40:38
# 96310    0767a951-c045-497c-9e52-3473ac9ffc67      2025-09-11 10:22:10
# ...                                       ...                      ...
# 3205059  f6608e7f-d2e7-45c1-ba9f-237e10f99ec7      2025-01-21 12:22:08
# 3229973  f8575f41-f3e3-45fc-a02f-39ea67d024b8      2024-09-16 11:38:53
# 3253462  fa25a9f8-fa87-4199-9048-49cb2a52bdf2      2025-02-20 10:47:04
# 3275244  fbe19511-82d2-4619-b8f2-ca9634609f65      2025-08-01 11:55:10
# 3313943  feeabe85-0f25-40e8-bfb0-deac3d5355e3      2025-03-20 10:40:21
#
#              Prev Activity 1      Prev Activity 2
# 13540    OtherLegalOtherMenu  SuburbanSeniorsMenu
# 29587    OtherLegalOtherMenu  SuburbanSeniorsMenu
# 56084    OtherLegalOtherMenu  SuburbanSeniorsMenu
# 65202    OtherLegalOtherMenu  SuburbanSeniorsMenu
# 96310    OtherLegalOtherMenu  SuburbanSeniorsMenu
# ...                      ...                  ...
# 3205059  OtherLegalOtherMenu  SuburbanSeniorsMenu
# 3229973  OtherLegalOtherMenu  SuburbanSeniorsMenu
# 3253462  OtherLegalOtherMenu  SuburbanSeniorsMenu
# 3275244  OtherLegalOtherMenu  SuburbanSeniorsMenu
# 3313943  OtherLegalOtherMenu  SuburbanSeniorsMenu
#
# [158 rows x 4 columns]

# %%
out['Prev Activity 1'].value_counts()
# Out:
# Prev Activity 1
# OtherLegalOtherMenu    158
# Name: count, dtype: int64

# %%
discallback_data = act_data('DisconnectContact')

# %%
discallback_data['Contact Session ID'].nunique()
# Out:
# 9390

# %%
custdata('02f3875b-ceae-4836-9786-1daf78f2841b')
# Out:
#                          Contact Session ID  \
# 37505  02f3875b-ceae-4836-9786-1daf78f2841b
# 37506  02f3875b-ceae-4836-9786-1daf78f2841b
# 37507  02f3875b-ceae-4836-9786-1daf78f2841b
# 37508  02f3875b-ceae-4836-9786-1daf78f2841b
# 37509  02f3875b-ceae-4836-9786-1daf78f2841b
# 37510  02f3875b-ceae-4836-9786-1daf78f2841b
# 37511  02f3875b-ceae-4836-9786-1daf78f2841b
# 37512  02f3875b-ceae-4836-9786-1daf78f2841b
# 37513  02f3875b-ceae-4836-9786-1daf78f2841b
# 37514  02f3875b-ceae-4836-9786-1daf78f2841b
# 37515  02f3875b-ceae-4836-9786-1daf78f2841b
# 37516  02f3875b-ceae-4836-9786-1daf78f2841b
# 37517  02f3875b-ceae-4836-9786-1daf78f2841b
# 37518  02f3875b-ceae-4836-9786-1daf78f2841b
# 37519  02f3875b-ceae-4836-9786-1daf78f2841b
# 37520  02f3875b-ceae-4836-9786-1daf78f2841b
# 37521  02f3875b-ceae-4836-9786-1daf78f2841b
# 37522  02f3875b-ceae-4836-9786-1daf78f2841b
# 37523  02f3875b-ceae-4836-9786-1daf78f2841b
# 37524  02f3875b-ceae-4836-9786-1daf78f2841b
# 37525  02f3875b-ceae-4836-9786-1daf78f2841b
# 37526  02f3875b-ceae-4836-9786-1daf78f2841b
# 37527  02f3875b-ceae-4836-9786-1daf78f2841b
# 37528  02f3875b-ceae-4836-9786-1daf78f2841b
# 37529  02f3875b-ceae-4836-9786-1daf78f2841b
# 37530  02f3875b-ceae-4836-9786-1daf78f2841b
# 37531  02f3875b-ceae-4836-9786-1daf78f2841b
# 37532  02f3875b-ceae-4836-9786-1daf78f2841b
# 37533  02f3875b-ceae-4836-9786-1daf78f2841b
# 37534  02f3875b-ceae-4836-9786-1daf78f2841b
# 37535  02f3875b-ceae-4836-9786-1daf78f2841b
# 37536  02f3875b-ceae-4836-9786-1daf78f2841b
# 37537  02f3875b-ceae-4836-9786-1daf78f2841b
# 37538  02f3875b-ceae-4836-9786-1daf78f2841b
# 37539  02f3875b-ceae-4836-9786-1daf78f2841b
# 37540  02f3875b-ceae-4836-9786-1daf78f2841b
# 37541  02f3875b-ceae-4836-9786-1daf78f2841b
# 37542  02f3875b-ceae-4836-9786-1daf78f2841b
# 37543  02f3875b-ceae-4836-9786-1daf78f2841b
# 37544  02f3875b-ceae-4836-9786-1daf78f2841b
# 37545  02f3875b-ceae-4836-9786-1daf78f2841b
# 37546  02f3875b-ceae-4836-9786-1daf78f2841b
# 37547  02f3875b-ceae-4836-9786-1daf78f2841b
# 37548  02f3875b-ceae-4836-9786-1daf78f2841b
# 37549  02f3875b-ceae-4836-9786-1daf78f2841b
# 37550  02f3875b-ceae-4836-9786-1daf78f2841b
# 37551  02f3875b-ceae-4836-9786-1daf78f2841b
# 37552  02f3875b-ceae-4836-9786-1daf78f2841b
# 37553  02f3875b-ceae-4836-9786-1daf78f2841b
# 37554  02f3875b-ceae-4836-9786-1daf78f2841b
# 37555  02f3875b-ceae-4836-9786-1daf78f2841b
# 37556  02f3875b-ceae-4836-9786-1daf78f2841b
# 37557  02f3875b-ceae-4836-9786-1daf78f2841b
# 37558  02f3875b-ceae-4836-9786-1daf78f2841b
# 37559  02f3875b-ceae-4836-9786-1daf78f2841b
# 37560  02f3875b-ceae-4836-9786-1daf78f2841b
# 37561  02f3875b-ceae-4836-9786-1daf78f2841b
# 37562  02f3875b-ceae-4836-9786-1daf78f2841b
# 37563  02f3875b-ceae-4836-9786-1daf78f2841b
#
#                                         EP Name                Flow Name  \
# 37505                  Main Number Telephony EP                      NaN
# 37506                                       NaN                  LACMain
# 37507                  Main Number Telephony EP                      NaN
# 37508                  Main Number Telephony EP                  LACMain
# 37509                  Main Number Telephony EP                      NaN
# 37510                                       NaN  PreLegalMenuSeniorsMenu
# 37511  Pre-Legal Menu Seniors Menu Telephony EP                      NaN
# 37512                                       NaN                LegalMenu
# 37513                   Legal Menu Telephony EP                      NaN
# 37514                   Legal Menu Telephony EP                      NaN
# 37515                                       NaN                   Queues
# 37516               All LAC Queues Telephony EP                      NaN
# 37517               All LAC Queues Telephony EP                      NaN
# 37518               All LAC Queues Telephony EP                      NaN
# 37519                                       NaN                      NaN
# 37520               All LAC Queues Telephony EP                      NaN
# 37521               All LAC Queues Telephony EP                      NaN
# 37522               All LAC Queues Telephony EP                      NaN
# 37523               All LAC Queues Telephony EP                      NaN
# 37524                                       NaN         CourtesyCallback
# 37525            Courtesy Callback Telephony EP                      NaN
# 37526            Courtesy Callback Telephony EP                      NaN
# 37527                                       NaN                      NaN
# 37528            Courtesy Callback Telephony EP                      NaN
# 37529            Courtesy Callback Telephony EP                      NaN
# 37530                                       NaN                      NaN
# 37531                                       NaN                      NaN
# 37532            Courtesy Callback Telephony EP                      NaN
# 37533                                       NaN                      NaN
# 37534                                       NaN                      NaN
# 37535            Courtesy Callback Telephony EP                      NaN
# 37536                                       NaN                      NaN
# 37537                                       NaN                      NaN
# 37538            Courtesy Callback Telephony EP                      NaN
# 37539                                       NaN                      NaN
# 37540                                       NaN                      NaN
# 37541            Courtesy Callback Telephony EP                      NaN
# 37542                                       NaN                      NaN
# 37543                                       NaN                      NaN
# 37544            Courtesy Callback Telephony EP                      NaN
# 37545                                       NaN                      NaN
# 37546                                       NaN                      NaN
# 37547            Courtesy Callback Telephony EP                      NaN
# 37548                                       NaN                      NaN
# 37549                                       NaN                      NaN
# 37550            Courtesy Callback Telephony EP                      NaN
# 37551                                       NaN                      NaN
# 37552                                       NaN                      NaN
# 37553            Courtesy Callback Telephony EP                      NaN
# 37554                                       NaN                      NaN
# 37555                                       NaN                      NaN
# 37556            Courtesy Callback Telephony EP                      NaN
# 37557                                       NaN                      NaN
# 37558                                       NaN                      NaN
# 37559            Courtesy Callback Telephony EP                      NaN
# 37560                                       NaN                      NaN
# 37561                                       NaN                      NaN
# 37562            Courtesy Callback Telephony EP                      NaN
# 37563            Courtesy Callback Telephony EP                      NaN
#
#                    Activity Name Activity Start Timestamp Queue Name  \
# 37505                        NaN      2025-01-17 08:01:09        NaN
# 37506                        NaN      2025-01-17 08:01:09        NaN
# 37507      LanguageSelectionMenu      2025-01-17 08:01:09        NaN
# 37508                        NaN      2025-01-17 08:01:09        NaN
# 37509                   MainMenu      2025-01-17 08:01:21        NaN
# 37510                        NaN      2025-01-17 08:01:45        NaN
# 37511                SeniorsMenu      2025-01-17 08:01:45        NaN
# 37512                        NaN      2025-01-17 08:01:53        NaN
# 37513                 LegalMenu1      2025-01-17 08:01:53        NaN
# 37514                 LegalMenu2      2025-01-17 08:02:29        NaN
# 37515                        NaN      2025-01-17 08:03:48        NaN
# 37516  GetLoggedInConsumerAgents      2025-01-17 08:03:48        NaN
# 37517     IntakePreQueueMessage1      2025-01-17 08:03:48        NaN
# 37518              ConsumerQueue      2025-01-17 08:04:51        NaN
# 37519                        NaN      2025-01-17 08:04:51   Consumer
# 37520                        NaN      2025-01-17 08:04:51   Consumer
# 37521           PreQueueMessage2      2025-01-17 08:04:51        NaN
# 37522                PlayMOH300s      2025-01-17 08:05:03        NaN
# 37523                 QueueMenu1      2025-01-17 08:10:04        NaN
# 37524                        NaN      2025-01-17 08:10:20        NaN
# 37525                    ReadANI      2025-01-17 08:10:20        NaN
# 37526                        CCB      2025-01-17 08:10:35        NaN
# 37527                        NaN      2025-01-17 08:10:35   Consumer
# 37528        PlayCCBConfirmation      2025-01-17 08:10:35        NaN
# 37529         DisconnectContact1      2025-01-17 08:10:50        NaN
# 37530                        NaN      2025-01-18 05:04:51   Consumer
# 37531                        NaN      2025-01-18 05:04:51   Consumer
# 37532              CallbackRetry      2025-01-18 05:05:02        NaN
# 37533                        NaN      2025-01-18 05:05:02   Consumer
# 37534                        NaN      2025-01-18 05:05:02   Consumer
# 37535                        NaN      2025-01-18 05:05:02   Consumer
# 37536                        NaN      2025-01-19 02:05:02   Consumer
# 37537                        NaN      2025-01-19 02:05:02   Consumer
# 37538              CallbackRetry      2025-01-19 02:05:12        NaN
# 37539                        NaN      2025-01-19 02:05:12   Consumer
# 37540                        NaN      2025-01-19 02:05:12   Consumer
# 37541                        NaN      2025-01-19 02:05:12   Consumer
# 37542                        NaN      2025-01-19 23:05:12   Consumer
# 37543                        NaN      2025-01-19 23:05:12   Consumer
# 37544              CallbackRetry      2025-01-19 23:05:22        NaN
# 37545                        NaN      2025-01-19 23:05:22   Consumer
# 37546                        NaN      2025-01-19 23:05:22   Consumer
# 37547                        NaN      2025-01-19 23:05:22   Consumer
# 37548                        NaN      2025-01-20 20:05:22   Consumer
# 37549                        NaN      2025-01-20 20:05:22   Consumer
# 37550              CallbackRetry      2025-01-20 20:05:32        NaN
# 37551                        NaN      2025-01-20 20:05:32   Consumer
# 37552                        NaN      2025-01-20 20:05:32   Consumer
# 37553                        NaN      2025-01-20 20:05:32   Consumer
# 37554                        NaN      2025-01-21 17:05:32   Consumer
# 37555                        NaN      2025-01-21 17:05:32   Consumer
# 37556              CallbackRetry      2025-01-21 17:05:42        NaN
# 37557                        NaN      2025-01-21 17:05:42   Consumer
# 37558                        NaN      2025-01-21 17:05:42   Consumer
# 37559                        NaN      2025-01-21 17:05:42   Consumer
# 37560                        NaN      2025-01-22 14:05:42   Consumer
# 37561                        NaN      2025-01-22 14:05:42   Consumer
# 37562  DisconnectCallbackContact      2025-01-22 14:05:43        NaN
# 37563                        NaN      2025-01-22 14:05:43   Consumer
#
#       Agent Name Termination Reason  hour
# 37505        NaN                NaN     8
# 37506        NaN                NaN     8
# 37507        NaN                NaN     8
# 37508        NaN                NaN     8
# 37509        NaN                NaN     8
# 37510        NaN                NaN     8
# 37511        NaN                NaN     8
# 37512        NaN                NaN     8
# 37513        NaN                NaN     8
# 37514        NaN                NaN     8
# 37515        NaN                NaN     8
# 37516        NaN                NaN     8
# 37517        NaN                NaN     8
# 37518        NaN                NaN     8
# 37519        NaN                NaN     8
# 37520        NaN                NaN     8
# 37521        NaN                NaN     8
# 37522        NaN                NaN     8
# 37523        NaN                NaN     8
# 37524        NaN                NaN     8
# 37525        NaN                NaN     8
# 37526        NaN                NaN     8
# 37527        NaN                NaN     8
# 37528        NaN                NaN     8
# 37529        NaN                NaN     8
# 37530        NaN                NaN     5
# 37531        NaN                NaN     5
# 37532        NaN                NaN     5
# 37533        NaN                NaN     5
# 37534        NaN                NaN     5
# 37535        NaN                NaN     5
# 37536        NaN                NaN     2
# 37537        NaN                NaN     2
# 37538        NaN                NaN     2
# 37539        NaN                NaN     2
# 37540        NaN                NaN     2
# 37541        NaN                NaN     2
# 37542        NaN                NaN    23
# 37543        NaN                NaN    23
# 37544        NaN                NaN    23
# 37545        NaN                NaN    23
# 37546        NaN                NaN    23
# 37547        NaN                NaN    23
# 37548        NaN                NaN    20
# 37549        NaN                NaN    20
# 37550        NaN                NaN    20
# 37551        NaN                NaN    20
# 37552        NaN                NaN    20
# 37553        NaN                NaN    20
# 37554        NaN                NaN    17
# 37555        NaN                NaN    17
# 37556        NaN                NaN    17
# 37557        NaN                NaN    17
# 37558        NaN                NaN    17
# 37559        NaN                NaN    17
# 37560        NaN                NaN    14
# 37561        NaN                NaN    14
# 37562        NaN                NaN    14
# 37563        NaN                NaN    14

# %%
discallback_data
# Out:
#                            Contact Session ID                         EP Name  \
# 37505    02f3875b-ceae-4836-9786-1daf78f2841b        Main Number Telephony EP
# 37506    02f3875b-ceae-4836-9786-1daf78f2841b                             NaN
# 37507    02f3875b-ceae-4836-9786-1daf78f2841b        Main Number Telephony EP
# 37508    02f3875b-ceae-4836-9786-1daf78f2841b        Main Number Telephony EP
# 37509    02f3875b-ceae-4836-9786-1daf78f2841b        Main Number Telephony EP
# ...                                       ...                             ...
# 3269660  fb739a00-cb9d-43de-b149-0f6c00ccfff8  Courtesy Callback Telephony EP
# 3269661  fb739a00-cb9d-43de-b149-0f6c00ccfff8                             NaN
# 3269662  fb739a00-cb9d-43de-b149-0f6c00ccfff8                             NaN
# 3269663  fb739a00-cb9d-43de-b149-0f6c00ccfff8  Courtesy Callback Telephony EP
# 3269664  fb739a00-cb9d-43de-b149-0f6c00ccfff8  Courtesy Callback Telephony EP
#
#         Flow Name              Activity Name Activity Start Timestamp  \
# 37505         NaN                        NaN      2025-01-17 08:01:09
# 37506     LACMain                        NaN      2025-01-17 08:01:09
# 37507         NaN      LanguageSelectionMenu      2025-01-17 08:01:09
# 37508     LACMain                        NaN      2025-01-17 08:01:09
# 37509         NaN                   MainMenu      2025-01-17 08:01:21
# ...           ...                        ...                      ...
# 3269660       NaN                        NaN      2024-07-26 16:00:19
# 3269661       NaN                        NaN      2024-07-27 16:00:19
# 3269662       NaN                        NaN      2024-07-27 16:00:19
# 3269663       NaN  DisconnectCallbackContact      2024-07-27 16:00:19
# 3269664       NaN                        NaN      2024-07-27 16:00:19
#
#         Queue Name Agent Name Termination Reason  hour
# 37505          NaN        NaN                NaN     8
# 37506          NaN        NaN                NaN     8
# 37507          NaN        NaN                NaN     8
# 37508          NaN        NaN                NaN     8
# 37509          NaN        NaN                NaN     8
# ...            ...        ...                ...   ...
# 3269660   Consumer        NaN                NaN    16
# 3269661   Consumer        NaN                NaN    16
# 3269662   Consumer        NaN                NaN    16
# 3269663        NaN        NaN                NaN    16
# 3269664   Consumer        NaN                NaN    16
#
# [4556 rows x 9 columns]
