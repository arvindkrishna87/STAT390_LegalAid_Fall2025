# %% [markdown]
# Author: Krish

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.api.types import CategoricalDtype
from pathlib import Path
from functools import reduce

# %% [markdown]
# ### User input required
# Put the data path on your system in the cell below

# %%
# Enter data path
data_path = "C:/Users/adams/Desktop/data/All Calls by Month"

# %% [markdown]
# ### User input ends

# %% [markdown]
# ### Reading all filenames in the data folder

# %%
folder = Path(data_path)
files = sorted(list(folder.glob("*.csv")) + list(folder.glob("*.xlsx")))

# %% [markdown]
# ### Reading first 5 rows of all data files
# The code chunk below reads the first 5 rows of all data files. This is to check the columns that are present in all the data files.

# %%
i=0; df = []
for f in files:
    if f.suffix.lower() == ".csv":
        df.append(pd.read_csv(f, header=0, dtype=str, engine="python", skip_blank_lines=False, nrows = 5))
    else:  # .xlsx
        df.append(pd.read_excel(f, sheet_name=0, header=0, dtype=str, nrows = 5))
    #df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df[i].shape)
    i = i + 1
# Out:
# 0 April 2024 (5, 63)
# 1 April 2025 (5, 63)
# 2 August 2024 (5, 57)
# 3 August 2025 (5, 63)
# 4 December 2024 (5, 55)
# 5 February 2025 (5, 63)
# 6 January 2025 (5, 64)
# 7 July 2024 (5, 55)
# 8 July 2025 (5, 63)
# 9 June 2024 (5, 63)
# 10 June 2025 (5, 63)
# 11 March 2025 (5, 65)
# 12 May 2024 (5, 63)
# 13 May 2025 (5, 63)
# 14 November 2024 (5, 63)
# 15 October 2024 (5, 55)
# 16 September 2024 (5, 55)

# %% [markdown]
# The code chunk below identifies the columns missing in at least one DataFrame.

# %%
all_cols = reduce(lambda x, y: x | set(y.columns), df[1:], set(df[0].columns))
common_cols = reduce(lambda x, y: x & set(y.columns), df[1:], set(df[0].columns))
common_cols
not_in_all = all_cols - common_cols
print("Columns missing from at least one dataframe:", not_in_all)
# Out:
# Columns missing from at least one dataframe: {'Call Recording Trigger', 'Column1', 'Original reason2', 'External caller ID number', 'Call Recording Result', 'Call Recording Platform Name', 'Public Calling IP Address', 'User', 'Redirecting party UUID', 'Device owner UUID', 'PSTN vendor name2', 'Public Called IP Address'}

# %% [markdown]
# The code chunk below prints the columns present in all the data files.

# %%
print(common_cols)
# Out:
# {'Outbound trunk', 'Called number', 'Authorization code', 'PSTN provider ID', 'Call ID', 'Network call ID', 'Correlation ID', 'Route group', 'User UUID', 'Direction', 'Report ID', 'Call outcome', 'Release time', 'Original reason', 'User type', 'Remote SessionID', 'User number', 'OS type', 'Site main number', 'PSTN vendor name', 'Location', 'Answer Indicator', 'PSTN vendor Org ID', 'Local SessionID', 'Remote call ID', 'Report time', 'Redirect reason', 'Device Mac', 'Final local sessionID', 'Releasing party', 'Answer time', 'Final remote sessionID', 'PSTN legal entity', 'Client version', 'Site timezone', 'Related call ID', 'Org UUID', 'Call type', 'Client type', 'Duration', 'Sub client type', 'Model', 'International Country', 'Local call ID', 'Inbound trunk', 'Department ID', 'Related reason', 'Call outcome reason', 'Answered', 'Transfer related call ID', 'Start time', 'Redirecting number', 'Ring duration', 'Call transfer time', 'Site UUID'}

# %% [markdown]
# ### Reading all the data files
# All the datafiles are read with the common columns read first.

# %%
df_main = pd.DataFrame(columns=list(common_cols))

# %%
i=0; 
for f in files:
    if f.suffix.lower() == ".csv":
        df = pd.read_csv(f, header=0, dtype=str, engine="python", skip_blank_lines=False)
    else:  # .xlsx
        df = pd.read_excel(f, sheet_name=0, header=0, dtype=str)
    df_main = pd.concat([df_main, df], ignore_index=True)
    print(i, f.stem, df.shape)
    i = i + 1
# Out:
# 0 April 2024 (56662, 63)
# 1 April 2025 (63636, 63)
# 2 August 2024 (63262, 57)
# 3 August 2025 (57071, 63)
# 4 December 2024 (49445, 55)
# 5 February 2025 (63669, 63)
# 6 January 2025 (62623, 64)
# 7 July 2024 (62292, 55)
# 8 July 2025 (60438, 63)
# 9 June 2024 (56763, 63)
# 10 June 2025 (54598, 63)
# 11 March 2025 (59149, 65)
# 12 May 2024 (62944, 63)
# 13 May 2025 (55428, 63)
# 14 November 2024 (49953, 63)
# 15 October 2024 (62354, 55)
# 16 September 2024 (61250, 55)

# %% [markdown]
# ### Converting date to datetime format

# %%
df_main["Start time"] = pd.to_datetime(df_main["Start time"], utc=True)

# %%
import os

save_path = "C:/Users/adams/Desktop/data/All Calls by Month"

# Create the folder if it doesn’t exist
os.makedirs(save_path, exist_ok=True)

# Define full file name (edit the filename as needed)
file_name = "all_calls.csv"
full_path = os.path.join(save_path, file_name)

# Save the DataFrame as a CSV
df.to_csv(full_path, index=False)

print(f"File saved successfully to: {full_path}")
# Out:
# File saved successfully to: C:/Users/adams/Desktop/data/All Calls by Month\all_calls.csv
