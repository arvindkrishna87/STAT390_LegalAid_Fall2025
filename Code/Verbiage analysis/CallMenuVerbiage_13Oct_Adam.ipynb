# %%
import os
import numpy as np
import pandas as pd

# %%
# start with All Calls data, merged - I took this from Krish's provided code, and then put the following code chunk to
# save the file to my desired path

# FILL IN DESIRED PATH TO SAVE THE DATA TO HERE
save_path = "--------------------------------"

# Create the folder if it doesn’t exist
os.makedirs(save_path, exist_ok=True)

# Define full file name
file_name = "all_calls.csv"
full_path = os.path.join(save_path, file_name)

# Save the DataFrame as a CSV
df.to_csv(full_path, index=False)

print(f"File saved successfully to: {full_path}")

# %%
# Once your All Calls data is on your local drive, start here

data = "C:/Users/adams/Desktop/data/All Calls by Month/all_calls.csv" # Replace this as needed to access your data!

data = pd.read_csv(data)

# %%
data.head()
# For presentation 1, I foucsed on a full verbiage analysis and went into detail about the findings I had. I plan
# to conduct data analyses to test my hypotheses in Presentation 2.
# Out:
#                  Start time               Answer time  Duration Called number  \
# 0  2024-09-30T23:57:59.308Z                       NaN         0   13123478373
# 1  2024-09-30T23:57:27.182Z  2024-09-30T23:57:27.232Z       103          2302
# 2  2024-09-30T23:57:27.182Z  2024-09-30T23:57:27.232Z       103          2302
# 3  2024-09-30T23:57:13.341Z  2024-09-30T23:57:13.479Z       117   13123411070
# 4  2024-09-30T23:54:18.721Z  2024-09-30T23:54:19.009Z        25   13123411070
#
#                          Correlation ID Location               Inbound trunk  \
# 0  11ddca5b-14b3-4d16-85ff-bcc3dad11cf6       HQ                         NaN
# 1  a9c4613a-5f59-49d8-9f25-c2c6b03dfd5e       HQ  wcc_Pc_tp-ipRwm_ku064NHZiw
# 2  a9c4613a-5f59-49d8-9f25-c2c6b03dfd5e       HQ                         NaN
# 3  a9c4613a-5f59-49d8-9f25-c2c6b03dfd5e       HQ                         NaN
# 4  27f4c79f-8574-4cea-814f-5beb5a964e1f       HQ                         NaN
#
# ...
