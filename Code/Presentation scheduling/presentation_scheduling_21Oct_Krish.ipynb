# %%
import random

# %%
random.randint(0, 1000)
# Out:
# 105

# %%
random.seed(105)

teams = {
    "Aggregate Trends 1": ["Ella", "Liv", "Tatum", "Edwin"],
    "Time Trends 1": ["Julia", "Sophia", "Varun"],
    "Advanced EDA": ["Will", "Vincent", "Yi-Hyun"],
    "Simple EDA 2": ["Sabrina", "Vivienne", "Caroline", "Hailee, Nikole"]
}

selected_team = random.choice(list(teams.keys()))

print("The team selected to present outside of class hours is:")
print(f"Team: {selected_team}")
print("Members:", ", ".join(teams[selected_team]))
# Out:
# The team selected to present outside of class hours is:
# Team: Advanced EDA
# Members: Will, Vincent, Yi-Hyun
